# %% [markdown]
# ### This notebook generates Paragraph Vector models with many several configurations and performs classification with randorm forest and 5 fold cross validation.

# %%
import os
import json
import statistics
import gensim
import datetime
import numpy as np
import pandas as pd
from collections import Counter
from collections import namedtuple
from collections import OrderedDict
from collections import defaultdict
from smart_open import smart_open
from gensim.models import doc2vec
import multiprocessing
from gensim.models.doc2vec import TaggedDocument
from gensim.test.test_doc2vec import ConcatenatedDoc2Vec

# %%
cores = multiprocessing.cpu_count()
assert gensim.models.doc2vec.FAST_VERSION > -1, "This will be painfully slow otherwise"
print('num of cores', cores)
# Out:
# num of cores 32

# %%
def load_label(partition=True, verbose=False):
    """load the labels (age, gender, YMRS)
    """
    # para partition: whether to partition labels into train/dev sets
    # para verbose: whether or not to output more statistical results
    # return: YMRS score and Mania level for train/dev set
    # return: YMRS score and Mania level for all dataset (if not partition)
    label = pd.read_csv("/home/ceccarelli/Work/Bipolar/labels_metadata.csv")
    id_list = label['SubjectID'].tolist()

    id_set = set()
    age_list = list()
    for id in id_list:
        id_set.add(id)
        age_list.extend(label[label.SubjectID == id]['Age'].tolist())

    gender_list = list()
    for sub in id_set:
        gender_list.append(sub[:1])
        if verbose:
            print("%s subject have %d instances" % (sub, id_list.count(sub)))
    
    classes_stats = Counter(label['ManiaLevel'].tolist())

    if verbose:
        print("All subjects", len(id_set))
        print("Male subjects ", gender_list.count('M'))
        print("Female subjects", gender_list.count('F'))
        print("Age range (%d, %d), Age median %d" % (min(age_list), max(age_list), statistics.median(age_list)))
        print("Class distribution stats", classes_stats)

    ymrs_score = pd.concat([label.iloc[:, 0], label.iloc[:, 4]], axis=1)
    mania_level = pd.concat([label.iloc[:, 0], label.iloc[:, 5]], axis=1)
    if partition:
        ymrs_dev = ymrs_score.iloc[:60, :]
        ymrs_train = ymrs_score.iloc[60:, :]
        level_dev = mania_level.iloc[:60, :]
        level_train = mania_level.iloc[60:, :]
        return ymrs_dev.values[:, 1], ymrs_train.values[:, 1], level_dev.values[:, 1], level_train.values[:, 1]
    else:
        return ymrs_score, mania_level, 0, 0

# %%
def infer_embedding(model, partition):
      
    save_dir = '../RESULTS/PV-DBOW' 
    name = str(model.vector_size)+'_'+str(model.window)+'_'+str(model.negative)+'_'+str(model.hs)
    save_dir = os.path.join(save_dir, name)
    if not os.path.exists(save_dir):
        os.mkdir(save_dir)
        print("Directory " , save_dir ,  " Created ")
    else:    
        print("Directory " , save_dir ,  " already exists")
    
    infer_docs = []
    labels = dict()
    _, _, level_dev, level_train = load_label()
    labels['train'] = level_train
    labels['dev'] = level_dev
    in_path = '/home/ceccarelli/Work/Bipolar/transcripts_processed/'
    if (partition=='train'):
        doc = os.path.join(in_path, 'Train_transcripts.txt')
    else:
        doc = os.path.join(in_path, 'Dev_transcripts.txt')
        
    with smart_open(doc, 'rb', encoding='utf-8') as all_data:
        for line_no, line in enumerate(all_data):
            tokens = gensim.utils.to_unicode(line).split()
            words = tokens
            tags = [line_no]
            sentiment = [labels[partition][line_no]]
            infer_docs.append(interview_transcript(words, tags, sentiment))
        
    infer_vecs = [model.infer_vector(doc.words, alpha=.1) for doc in infer_docs]
    infer_labels = [doc.sentiment for doc in infer_docs]

    # save inferred vectors and labels
    print("\nsaving inferred vectors and labels to file")
    if os.path.isdir(save_dir):
            np.save(os.path.join(save_dir, 'vectors_%s' % partition), infer_vecs)
            np.save(os.path.join(save_dir, 'labels_%s' % partition), infer_labels)

# %%
def infer_embedding_combined(model, model1, partition, path):
    
      
    save_dir = '../RESULTS/'+path
    name = str(model1.vector_size)+'_'+str(model1.window)+'_'+str(model1.negative)+'_'+str(model1.hs)
    save_dir = os.path.join(save_dir, name)
    if not os.path.exists(save_dir):
        os.mkdir(save_dir)
        print("Directory " , save_dir ,  " Created ")
    else:    
        print("Directory " , save_dir ,  " already exists")
    
    infer_docs = []
    labels = dict()
    _, _, level_dev, level_train = load_label()
    labels['train'] = level_train
    labels['dev'] = level_dev
    in_path = '/home/ceccarelli/Work/Bipolar/transcripts_processed/'
    if (partition=='train'):
        doc = os.path.join(in_path, 'Train_transcripts.txt')
    else:
        doc = os.path.join(in_path, 'Dev_transcripts.txt')
        
    with smart_open(doc, 'rb', encoding='utf-8') as all_data:
        for line_no, line in enumerate(all_data):
            tokens = gensim.utils.to_unicode(line).split()
            words = tokens
            tags = [line_no]
            sentiment = [labels[partition][line_no]]
            infer_docs.append(interview_transcript(words, tags, sentiment))
        
    infer_vecs = [model.infer_vector(doc.words, alpha=.1) for doc in infer_docs]
    infer_labels = [doc.sentiment for doc in infer_docs]

    # save inferred vectors and labels
    print("\nsaving inferred vectors and labels to file")
    if os.path.isdir(save_dir):
            np.save(os.path.join(save_dir, 'vectors_%s' % partition), infer_vecs)
            np.save(os.path.join(save_dir, 'labels_%s' % partition), infer_labels)

# %%
interview_transcript = namedtuple('Interview_Transcript', 'words tags sentiment')
labels = dict()
_, _, level_dev, level_train = load_label()
labels['train'] = level_train
labels['dev'] = level_dev

# %%
in_path = '/home/ceccarelli/Work/Bipolar/transcripts_processed/'
all_docs = []
for partition in ['train', 'dev']:
    if (partition=='train'):
        doc = os.path.join(in_path, 'Train_transcripts.txt')
    else:
        doc = os.path.join(in_path, 'Dev_transcripts.txt')
    with smart_open(doc, 'rb', encoding='utf-8') as all_data:
        for line_no, line in enumerate(all_data):
            tokens = gensim.utils.to_unicode(line).split()
            words = tokens
            tags = [line_no]
            sentiment = [labels[partition][line_no]] if partition != 'test' else [None]
            all_docs.append(interview_transcript(words, tags, sentiment))
            
corpus = False
if (corpus == True):
    corpus_path = '/storage/gluster/vol1/SHARED/HOMEFOLDERS/ceccarelli/Work/Bipolar/turkish_corpus.txt'
    with smart_open(corpus_path, 'rb', encoding='utf-8') as all_data:
        for line_no, line in enumerate(all_data):
            tokens = gensim.utils.to_unicode(line).split()
            words = tokens
            tags = [line_no]
            sentiment = [None]
            all_docs.append(interview_transcript(words, tags, sentiment))
# Out:
# /home/ceccarelli/.local/lib/python3.6/site-packages/smart_open/smart_open_lib.py:402: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %%
#vector_size [25,50,75,100]
#window [5,10]
#negative [5,10]
#hs [0,1]
len(all_docs)
# Out:
# 164

# %%
#dm averaging
models = [
    doc2vec.Doc2Vec(dm=1, vector_size=25, window=5, negative=5, hs=0, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=1, vector_size=25, window=5, negative=10, hs=0, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=1, vector_size=25, window=5, negative=0, hs=1, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=1, vector_size=25, window=10, negative=5, hs=0, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=1, vector_size=25, window=10, negative=10, hs=0, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=1, vector_size=25, window=10, negative=0, hs=1, min_count=2, epochs=100, workers=cores,sample=0),
    
    doc2vec.Doc2Vec(dm=1, vector_size=50, window=5, negative=5, hs=0, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=1, vector_size=50, window=5, negative=10, hs=0, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=1, vector_size=50, window=5, negative=0, hs=1, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=1, vector_size=50, window=10, negative=5, hs=0, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=1, vector_size=50, window=10, negative=10, hs=0, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=1, vector_size=50, window=10, negative=0, hs=1, min_count=2, epochs=100, workers=cores,sample=0),
    
    doc2vec.Doc2Vec(dm=1, vector_size=75, window=5, negative=5, hs=0, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=1, vector_size=75, window=5, negative=10, hs=0, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=1, vector_size=75, window=5, negative=0, hs=1, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=1, vector_size=75, window=10, negative=5, hs=0, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=1, vector_size=75, window=10, negative=10, hs=0, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=1, vector_size=75, window=10, negative=0, hs=1, min_count=2, epochs=100, workers=cores,sample=0),
    
    doc2vec.Doc2Vec(dm=1, vector_size=100, window=5, negative=5, hs=0, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=1, vector_size=100, window=5, negative=10, hs=0, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=1, vector_size=100, window=5, negative=0, hs=1, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=1, vector_size=100, window=10, negative=5, hs=0, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=1, vector_size=100, window=10, negative=10, hs=0, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=1, vector_size=100, window=10, negative=0, hs=1, min_count=2, epochs=100, workers=cores,sample=0)
]

# %%
count = 0
for model in models:
    print("\nbuilding vocabulary for doc2vec model %i" %count)
    model.build_vocab(all_docs)
    print("\nvocabulary scanned & built.")
    count += 1
# Out:
# building vocabulary for doc2vec model 0
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 1
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 2
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 3
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 4
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 5
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 6
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 7
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 8
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 9
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 10
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 11
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 12
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 13
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 14
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 15
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 16
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 17
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 18
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 19
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 20
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 21
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 22
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 23
#
# vocabulary scanned & built.

# %%
from gensim.models.callbacks import CallbackAny2Vec
class EpochLogger(CallbackAny2Vec):
    '''Callback to log information about training'''
    
    def __init__(self):
        self.epoch = 0
    
    def on_epoch_begin(self, model):
        print("Epoch #{} start".format(self.epoch))
    
    def on_epoch_end(self, model):
        print("Epoch #{} end".format(self.epoch))
        self.epoch += 1

# %%
epoch_logger = EpochLogger()
count = 0
for model in models:
    model.train(all_docs, total_examples=len(all_docs), epochs=model.epochs,callbacks=[epoch_logger])
    print("\nmodel %i trained" %count)
    count += 1
# Out:
# Epoch #0 start
# Epoch #0 end
# Epoch #1 start
# Epoch #1 end
# Epoch #2 start
# Epoch #2 end
# Epoch #3 start
# Epoch #3 end
# Epoch #4 start
# Epoch #4 end
# Epoch #5 start
# Epoch #5 end
# Epoch #6 start
# Epoch #6 end
# Epoch #7 start
# Epoch #7 end
# Epoch #8 start
# Epoch #8 end
# Epoch #9 start
# Epoch #9 end
# Epoch #10 start
# Epoch #10 end
# Epoch #11 start
# Epoch #11 end
# Epoch #12 start
# Epoch #12 end
# Epoch #13 start
# Epoch #13 end
# Epoch #14 start
# Epoch #14 end
# Epoch #15 start
# Epoch #15 end
# Epoch #16 start
# Epoch #16 end
# Epoch #17 start
# Epoch #17 end
# Epoch #18 start
# Epoch #18 end
# Epoch #19 start
# Epoch #19 end
# Epoch #20 start
# Epoch #20 end
# Epoch #21 start
# Epoch #21 end
# Epoch #22 start
# Epoch #22 end
# Epoch #23 start
# Epoch #23 end
# Epoch #24 start
# Epoch #24 end
# Epoch #25 start
# Epoch #25 end
# Epoch #26 start
# Epoch #26 end
# Epoch #27 start
# Epoch #27 end
# Epoch #28 start
# Epoch #28 end
# Epoch #29 start
# Epoch #29 end
# Epoch #30 start
# Epoch #30 end
# Epoch #31 start
# Epoch #31 end
# Epoch #32 start
# Epoch #32 end
# Epoch #33 start
# Epoch #33 end
# Epoch #34 start
# Epoch #34 end
# Epoch #35 start
# Epoch #35 end
# Epoch #36 start
# Epoch #36 end
# Epoch #37 start
# Epoch #37 end
# Epoch #38 start
# Epoch #38 end
# Epoch #39 start
# Epoch #39 end
# Epoch #40 start
# Epoch #40 end
# Epoch #41 start
# Epoch #41 end
# Epoch #42 start
# Epoch #42 end
# Epoch #43 start
# Epoch #43 end
# Epoch #44 start
# Epoch #44 end
# Epoch #45 start
# Epoch #45 end
# Epoch #46 start
# Epoch #46 end
# Epoch #47 start
# Epoch #47 end
# Epoch #48 start
# Epoch #48 end
# Epoch #49 start
# Epoch #49 end
# Epoch #50 start
# Epoch #50 end
# Epoch #51 start
# Epoch #51 end
# Epoch #52 start
# Epoch #52 end
# Epoch #53 start
# Epoch #53 end
# Epoch #54 start
# Epoch #54 end
# Epoch #55 start
# Epoch #55 end
# Epoch #56 start
# Epoch #56 end
# Epoch #57 start
# Epoch #57 end
# Epoch #58 start
# Epoch #58 end
# Epoch #59 start
# Epoch #59 end
# Epoch #60 start
# Epoch #60 end
# Epoch #61 start
# Epoch #61 end
# Epoch #62 start
# Epoch #62 end
# Epoch #63 start
# Epoch #63 end
# Epoch #64 start
# Epoch #64 end
# Epoch #65 start
# Epoch #65 end
# Epoch #66 start
# Epoch #66 end
# Epoch #67 start
# Epoch #67 end
# Epoch #68 start
# Epoch #68 end
# Epoch #69 start
# Epoch #69 end
# Epoch #70 start
# Epoch #70 end
# Epoch #71 start
# Epoch #71 end
# Epoch #72 start
# Epoch #72 end
# Epoch #73 start
# Epoch #73 end
# Epoch #74 start
# Epoch #74 end
# Epoch #75 start
# Epoch #75 end
# Epoch #76 start
# Epoch #76 end
# Epoch #77 start
# Epoch #77 end
# Epoch #78 start
# Epoch #78 end
# Epoch #79 start
# Epoch #79 end
# Epoch #80 start
# Epoch #80 end
# Epoch #81 start
# Epoch #81 end
# Epoch #82 start
# Epoch #82 end
# Epoch #83 start
# Epoch #83 end
# Epoch #84 start
# Epoch #84 end
# Epoch #85 start
# Epoch #85 end
# Epoch #86 start
# Epoch #86 end
# Epoch #87 start
# Epoch #87 end
# Epoch #88 start
# Epoch #88 end
# Epoch #89 start
# Epoch #89 end
# Epoch #90 start
# Epoch #90 end
# Epoch #91 start
# Epoch #91 end
# Epoch #92 start
# Epoch #92 end
# Epoch #93 start
# Epoch #93 end
# Epoch #94 start
# Epoch #94 end
# Epoch #95 start
# Epoch #95 end
# Epoch #96 start
# Epoch #96 end
# Epoch #97 start
# Epoch #97 end
# Epoch #98 start
# Epoch #98 end
# Epoch #99 start
# Epoch #99 end
#
# model 0 trained
# Epoch #100 start
# Epoch #100 end
# Epoch #101 start
# Epoch #101 end
# Epoch #102 start
# Epoch #102 end
# Epoch #103 start
# Epoch #103 end
# Epoch #104 start
# Epoch #104 end
# Epoch #105 start
# Epoch #105 end
# Epoch #106 start
# Epoch #106 end
# Epoch #107 start
# Epoch #107 end
# Epoch #108 start
# Epoch #108 end
# Epoch #109 start
# Epoch #109 end
# Epoch #110 start
# Epoch #110 end
# Epoch #111 start
# Epoch #111 end
# Epoch #112 start
# Epoch #112 end
# Epoch #113 start
# Epoch #113 end
# Epoch #114 start
# Epoch #114 end
# Epoch #115 start
# Epoch #115 end
# Epoch #116 start
# Epoch #116 end
# Epoch #117 start
# Epoch #117 end
# Epoch #118 start
# Epoch #118 end
# Epoch #119 start
# Epoch #119 end
# Epoch #120 start
# Epoch #120 end
# Epoch #121 start
# Epoch #121 end
# Epoch #122 start
# Epoch #122 end
# Epoch #123 start
# Epoch #123 end
# Epoch #124 start
# Epoch #124 end
# Epoch #125 start
# Epoch #125 end
# Epoch #126 start
# Epoch #126 end
# Epoch #127 start
# Epoch #127 end
# Epoch #128 start
# Epoch #128 end
# Epoch #129 start
# Epoch #129 end
# Epoch #130 start
# Epoch #130 end
# Epoch #131 start
# Epoch #131 end
# Epoch #132 start
# Epoch #132 end
# Epoch #133 start
# Epoch #133 end
# Epoch #134 start
# Epoch #134 end
# Epoch #135 start
# Epoch #135 end
# Epoch #136 start
# Epoch #136 end
# Epoch #137 start
# Epoch #137 end
# Epoch #138 start
# Epoch #138 end
# Epoch #139 start
# Epoch #139 end
# Epoch #140 start
# Epoch #140 end
# Epoch #141 start
# Epoch #141 end
# Epoch #142 start
# Epoch #142 end
# Epoch #143 start
# Epoch #143 end
# Epoch #144 start
# Epoch #144 end
# Epoch #145 start
# Epoch #145 end
# Epoch #146 start
# Epoch #146 end
# Epoch #147 start
# Epoch #147 end
# Epoch #148 start
# Epoch #148 end
# Epoch #149 start
# Epoch #149 end
# Epoch #150 start
# Epoch #150 end
# Epoch #151 start
# Epoch #151 end
# Epoch #152 start
# Epoch #152 end
# Epoch #153 start
# Epoch #153 end
# Epoch #154 start
# Epoch #154 end
# Epoch #155 start
# Epoch #155 end
# Epoch #156 start
# Epoch #156 end
# Epoch #157 start
# Epoch #157 end
# Epoch #158 start
# Epoch #158 end
# Epoch #159 start
# Epoch #159 end
# Epoch #160 start
# Epoch #160 end
# Epoch #161 start
# Epoch #161 end
# Epoch #162 start
# Epoch #162 end
# Epoch #163 start
# Epoch #163 end
# Epoch #164 start
# Epoch #164 end
# Epoch #165 start
# Epoch #165 end
# Epoch #166 start
# Epoch #166 end
# Epoch #167 start
# Epoch #167 end
# Epoch #168 start
# Epoch #168 end
# Epoch #169 start
# Epoch #169 end
# Epoch #170 start
# Epoch #170 end
# Epoch #171 start
# Epoch #171 end
# Epoch #172 start
# Epoch #172 end
# Epoch #173 start
# Epoch #173 end
# Epoch #174 start
# Epoch #174 end
# Epoch #175 start
# Epoch #175 end
# Epoch #176 start
# Epoch #176 end
# Epoch #177 start
# Epoch #177 end
# Epoch #178 start
# Epoch #178 end
# Epoch #179 start
# Epoch #179 end
# Epoch #180 start
# Epoch #180 end
# Epoch #181 start
# Epoch #181 end
# Epoch #182 start
# Epoch #182 end
# Epoch #183 start
# Epoch #183 end
# Epoch #184 start
# Epoch #184 end
# Epoch #185 start
# Epoch #185 end
# Epoch #186 start
# Epoch #186 end
# Epoch #187 start
# Epoch #187 end
# Epoch #188 start
# Epoch #188 end
# Epoch #189 start
# Epoch #189 end
# Epoch #190 start
# Epoch #190 end
# Epoch #191 start
# Epoch #191 end
# Epoch #192 start
# Epoch #192 end
# Epoch #193 start
# Epoch #193 end
# Epoch #194 start
# Epoch #194 end
# Epoch #195 start
# Epoch #195 end
# Epoch #196 start
# Epoch #196 end
# Epoch #197 start
# Epoch #197 end
# Epoch #198 start
# Epoch #198 end
# Epoch #199 start
# Epoch #199 end
#
# model 1 trained
# Epoch #200 start
# Epoch #200 end
# Epoch #201 start
# Epoch #201 end
# Epoch #202 start
# Epoch #202 end
# Epoch #203 start
# Epoch #203 end
# Epoch #204 start
# Epoch #204 end
# Epoch #205 start
# Epoch #205 end
# Epoch #206 start
# Epoch #206 end
# Epoch #207 start
# Epoch #207 end
# Epoch #208 start
# Epoch #208 end
# Epoch #209 start
# Epoch #209 end
# Epoch #210 start
# Epoch #210 end
# Epoch #211 start
# Epoch #211 end
# Epoch #212 start
# Epoch #212 end
# Epoch #213 start
# Epoch #213 end
# Epoch #214 start
# Epoch #214 end
# Epoch #215 start
# Epoch #215 end
# Epoch #216 start
# Epoch #216 end
# Epoch #217 start
# Epoch #217 end
# Epoch #218 start
# Epoch #218 end
# Epoch #219 start
# Epoch #219 end
# Epoch #220 start
# Epoch #220 end
# Epoch #221 start
# Epoch #221 end
# Epoch #222 start
# Epoch #222 end
# Epoch #223 start
# Epoch #223 end
# Epoch #224 start
# Epoch #224 end
# Epoch #225 start
# Epoch #225 end
# Epoch #226 start
# Epoch #226 end
# Epoch #227 start
# Epoch #227 end
# Epoch #228 start
# Epoch #228 end
# Epoch #229 start
# Epoch #229 end
# Epoch #230 start
# Epoch #230 end
# Epoch #231 start
# Epoch #231 end
# Epoch #232 start
# Epoch #232 end
# Epoch #233 start
# Epoch #233 end
# Epoch #234 start
# Epoch #234 end
# Epoch #235 start
# Epoch #235 end
# Epoch #236 start
# Epoch #236 end
# Epoch #237 start
# Epoch #237 end
# Epoch #238 start
# Epoch #238 end
# Epoch #239 start
# Epoch #239 end
# Epoch #240 start
# Epoch #240 end
# Epoch #241 start
# Epoch #241 end
# Epoch #242 start
# Epoch #242 end
# Epoch #243 start
# Epoch #243 end
# Epoch #244 start
# Epoch #244 end
# Epoch #245 start
# Epoch #245 end
# Epoch #246 start
# Epoch #246 end
# Epoch #247 start
# Epoch #247 end
# Epoch #248 start
# Epoch #248 end
# Epoch #249 start
# Epoch #249 end
# Epoch #250 start
# Epoch #250 end
# Epoch #251 start
# Epoch #251 end
# Epoch #252 start
# Epoch #252 end
# Epoch #253 start
# Epoch #253 end
# Epoch #254 start
# Epoch #254 end
# Epoch #255 start
# Epoch #255 end
# Epoch #256 start
# Epoch #256 end
# Epoch #257 start
# Epoch #257 end
# Epoch #258 start
# Epoch #258 end
# Epoch #259 start
# Epoch #259 end
# Epoch #260 start
# Epoch #260 end
# Epoch #261 start
# Epoch #261 end
# Epoch #262 start
# Epoch #262 end
# Epoch #263 start
# Epoch #263 end
# Epoch #264 start
# Epoch #264 end
# Epoch #265 start
# Epoch #265 end
# Epoch #266 start
# Epoch #266 end
# Epoch #267 start
# Epoch #267 end
# Epoch #268 start
# Epoch #268 end
# Epoch #269 start
# Epoch #269 end
# Epoch #270 start
# Epoch #270 end
# Epoch #271 start
# Epoch #271 end
# Epoch #272 start
# Epoch #272 end
# Epoch #273 start
# Epoch #273 end
# Epoch #274 start
# Epoch #274 end
# Epoch #275 start
# Epoch #275 end
# Epoch #276 start
# Epoch #276 end
# Epoch #277 start
# Epoch #277 end
# Epoch #278 start
# Epoch #278 end
# Epoch #279 start
# Epoch #279 end
# Epoch #280 start
# Epoch #280 end
# Epoch #281 start
# Epoch #281 end
# Epoch #282 start
# Epoch #282 end
# Epoch #283 start
# Epoch #283 end
# Epoch #284 start
# Epoch #284 end
# Epoch #285 start
# Epoch #285 end
# Epoch #286 start
# Epoch #286 end
# Epoch #287 start
# Epoch #287 end
# Epoch #288 start
# Epoch #288 end
# Epoch #289 start
# Epoch #289 end
# Epoch #290 start
# Epoch #290 end
# Epoch #291 start
# Epoch #291 end
# Epoch #292 start
# Epoch #292 end
# Epoch #293 start
# Epoch #293 end
# Epoch #294 start
# Epoch #294 end
# Epoch #295 start
# Epoch #295 end
# Epoch #296 start
# Epoch #296 end
# Epoch #297 start
# Epoch #297 end
# Epoch #298 start
# Epoch #298 end
# Epoch #299 start
# Epoch #299 end
#
# model 2 trained
# Epoch #300 start
# Epoch #300 end
# Epoch #301 start
# Epoch #301 end
# Epoch #302 start
# Epoch #302 end
# Epoch #303 start
# Epoch #303 end
# Epoch #304 start
# Epoch #304 end
# Epoch #305 start
# Epoch #305 end
# Epoch #306 start
# Epoch #306 end
# Epoch #307 start
# Epoch #307 end
# Epoch #308 start
# Epoch #308 end
# Epoch #309 start
# Epoch #309 end
# Epoch #310 start
# Epoch #310 end
# Epoch #311 start
# Epoch #311 end
# Epoch #312 start
# Epoch #312 end
# Epoch #313 start
# Epoch #313 end
# Epoch #314 start
# Epoch #314 end
# Epoch #315 start
# Epoch #315 end
# Epoch #316 start
# Epoch #316 end
# Epoch #317 start
# Epoch #317 end
# Epoch #318 start
# Epoch #318 end
# Epoch #319 start
# Epoch #319 end
# Epoch #320 start
# Epoch #320 end
# Epoch #321 start
# Epoch #321 end
# Epoch #322 start
# Epoch #322 end
# Epoch #323 start
# Epoch #323 end
# Epoch #324 start
# Epoch #324 end
# Epoch #325 start
# Epoch #325 end
# Epoch #326 start
# Epoch #326 end
# Epoch #327 start
# Epoch #327 end
# Epoch #328 start
# Epoch #328 end
# Epoch #329 start
# Epoch #329 end
# Epoch #330 start
# Epoch #330 end
# Epoch #331 start
# Epoch #331 end
# Epoch #332 start
# Epoch #332 end
# Epoch #333 start
# Epoch #333 end
# Epoch #334 start
# Epoch #334 end
# Epoch #335 start
# Epoch #335 end
# Epoch #336 start
# Epoch #336 end
# Epoch #337 start
# Epoch #337 end
# Epoch #338 start
# Epoch #338 end
# Epoch #339 start
# Epoch #339 end
# Epoch #340 start
# Epoch #340 end
# Epoch #341 start
# Epoch #341 end
# Epoch #342 start
# Epoch #342 end
# Epoch #343 start
# Epoch #343 end
# Epoch #344 start
# Epoch #344 end
# Epoch #345 start
# Epoch #345 end
# Epoch #346 start
# Epoch #346 end
# Epoch #347 start
# Epoch #347 end
# Epoch #348 start
# Epoch #348 end
# Epoch #349 start
# Epoch #349 end
# Epoch #350 start
# Epoch #350 end
# Epoch #351 start
# Epoch #351 end
# Epoch #352 start
# Epoch #352 end
# Epoch #353 start
# Epoch #353 end
# Epoch #354 start
# Epoch #354 end
# Epoch #355 start
# Epoch #355 end
# Epoch #356 start
# Epoch #356 end
# Epoch #357 start
# Epoch #357 end
# Epoch #358 start
# Epoch #358 end
# Epoch #359 start
# Epoch #359 end
# Epoch #360 start
# Epoch #360 end
# Epoch #361 start
# Epoch #361 end
# Epoch #362 start
# Epoch #362 end
# Epoch #363 start
# Epoch #363 end
# Epoch #364 start
# Epoch #364 end
# Epoch #365 start
# Epoch #365 end
# Epoch #366 start
# Epoch #366 end
# Epoch #367 start
# Epoch #367 end
# Epoch #368 start
# Epoch #368 end
# Epoch #369 start
# Epoch #369 end
# Epoch #370 start
# Epoch #370 end
# Epoch #371 start
# Epoch #371 end
# Epoch #372 start
# Epoch #372 end
# Epoch #373 start
# Epoch #373 end
# Epoch #374 start
# Epoch #374 end
# Epoch #375 start
# Epoch #375 end
# Epoch #376 start
# Epoch #376 end
# Epoch #377 start
# Epoch #377 end
# Epoch #378 start
# Epoch #378 end
# Epoch #379 start
# Epoch #379 end
# Epoch #380 start
# Epoch #380 end
# Epoch #381 start
# Epoch #381 end
# Epoch #382 start
# Epoch #382 end
# Epoch #383 start
# Epoch #383 end
# Epoch #384 start
# Epoch #384 end
# Epoch #385 start
# Epoch #385 end
# Epoch #386 start
# Epoch #386 end
# Epoch #387 start
# Epoch #387 end
# Epoch #388 start
# Epoch #388 end
# Epoch #389 start
# Epoch #389 end
# Epoch #390 start
# Epoch #390 end
# Epoch #391 start
# Epoch #391 end
# Epoch #392 start
# Epoch #392 end
# Epoch #393 start
# Epoch #393 end
# Epoch #394 start
# Epoch #394 end
# Epoch #395 start
# Epoch #395 end
# Epoch #396 start
# Epoch #396 end
# Epoch #397 start
# Epoch #397 end
# Epoch #398 start
# Epoch #398 end
# Epoch #399 start
# Epoch #399 end
#
# model 3 trained
# Epoch #400 start
# Epoch #400 end
# Epoch #401 start
# Epoch #401 end
# Epoch #402 start
# Epoch #402 end
# Epoch #403 start
# Epoch #403 end
# Epoch #404 start
# Epoch #404 end
# Epoch #405 start
# Epoch #405 end
# Epoch #406 start
# Epoch #406 end
# Epoch #407 start
# Epoch #407 end
# Epoch #408 start
# Epoch #408 end
# Epoch #409 start
# Epoch #409 end
# Epoch #410 start
# Epoch #410 end
# Epoch #411 start
# Epoch #411 end
# Epoch #412 start
# Epoch #412 end
# Epoch #413 start
# Epoch #413 end
# Epoch #414 start
# Epoch #414 end
# Epoch #415 start
# Epoch #415 end
# Epoch #416 start
# Epoch #416 end
# Epoch #417 start
# Epoch #417 end
# Epoch #418 start
# Epoch #418 end
# Epoch #419 start
# Epoch #419 end
# Epoch #420 start
# Epoch #420 end
# Epoch #421 start
# Epoch #421 end
# Epoch #422 start
# Epoch #422 end
# Epoch #423 start
# Epoch #423 end
# Epoch #424 start
# Epoch #424 end
# Epoch #425 start
# Epoch #425 end
# Epoch #426 start
# Epoch #426 end
# Epoch #427 start
# Epoch #427 end
# Epoch #428 start
# Epoch #428 end
# Epoch #429 start
# Epoch #429 end
# Epoch #430 start
# Epoch #430 end
# Epoch #431 start
# Epoch #431 end
# Epoch #432 start
# Epoch #432 end
# Epoch #433 start
# Epoch #433 end
# Epoch #434 start
# Epoch #434 end
# Epoch #435 start
# Epoch #435 end
# Epoch #436 start
# Epoch #436 end
# Epoch #437 start
# Epoch #437 end
# Epoch #438 start
# Epoch #438 end
# Epoch #439 start
# Epoch #439 end
# Epoch #440 start
# Epoch #440 end
# Epoch #441 start
# Epoch #441 end
# Epoch #442 start
# Epoch #442 end
# Epoch #443 start
# Epoch #443 end
# Epoch #444 start
# Epoch #444 end
# Epoch #445 start
# Epoch #445 end
# Epoch #446 start
# Epoch #446 end
# Epoch #447 start
# Epoch #447 end
# Epoch #448 start
# Epoch #448 end
# Epoch #449 start
# Epoch #449 end
# Epoch #450 start
# Epoch #450 end
# Epoch #451 start
# Epoch #451 end
# Epoch #452 start
# Epoch #452 end
# Epoch #453 start
# Epoch #453 end
# Epoch #454 start
# Epoch #454 end
# Epoch #455 start
# Epoch #455 end
# Epoch #456 start
# Epoch #456 end
# Epoch #457 start
# Epoch #457 end
# Epoch #458 start
# Epoch #458 end
# Epoch #459 start
# Epoch #459 end
# Epoch #460 start
# Epoch #460 end
# Epoch #461 start
# Epoch #461 end
# Epoch #462 start
# Epoch #462 end
# Epoch #463 start
# Epoch #463 end
# Epoch #464 start
# Epoch #464 end
# Epoch #465 start
# Epoch #465 end
# Epoch #466 start
# Epoch #466 end
# Epoch #467 start
# Epoch #467 end
# Epoch #468 start
# Epoch #468 end
# Epoch #469 start
# Epoch #469 end
# Epoch #470 start
# Epoch #470 end
# Epoch #471 start
# Epoch #471 end
# Epoch #472 start
# Epoch #472 end
# Epoch #473 start
# Epoch #473 end
# Epoch #474 start
# Epoch #474 end
# Epoch #475 start
# Epoch #475 end
# Epoch #476 start
# Epoch #476 end
# Epoch #477 start
# Epoch #477 end
# Epoch #478 start
# Epoch #478 end
# Epoch #479 start
# Epoch #479 end
# Epoch #480 start
# Epoch #480 end
# Epoch #481 start
# Epoch #481 end
# Epoch #482 start
# Epoch #482 end
# Epoch #483 start
# Epoch #483 end
# Epoch #484 start
# Epoch #484 end
# Epoch #485 start
# Epoch #485 end
# Epoch #486 start
# Epoch #486 end
# Epoch #487 start
# Epoch #487 end
# Epoch #488 start
# Epoch #488 end
# Epoch #489 start
# Epoch #489 end
# Epoch #490 start
# Epoch #490 end
# Epoch #491 start
# Epoch #491 end
# Epoch #492 start
# Epoch #492 end
# Epoch #493 start
# Epoch #493 end
# Epoch #494 start
# Epoch #494 end
# Epoch #495 start
# Epoch #495 end
# Epoch #496 start
# Epoch #496 end
# Epoch #497 start
# Epoch #497 end
# Epoch #498 start
# Epoch #498 end
# Epoch #499 start
# Epoch #499 end
#
# model 4 trained
# Epoch #500 start
# Epoch #500 end
# Epoch #501 start
# Epoch #501 end
# Epoch #502 start
# Epoch #502 end
# Epoch #503 start
# Epoch #503 end
# Epoch #504 start
# Epoch #504 end
# Epoch #505 start
# Epoch #505 end
# Epoch #506 start
# Epoch #506 end
# Epoch #507 start
# Epoch #507 end
# Epoch #508 start
# Epoch #508 end
# Epoch #509 start
# Epoch #509 end
# Epoch #510 start
# Epoch #510 end
# Epoch #511 start
# Epoch #511 end
# Epoch #512 start
# Epoch #512 end
# Epoch #513 start
# Epoch #513 end
# Epoch #514 start
# Epoch #514 end
# Epoch #515 start
# Epoch #515 end
# Epoch #516 start
# Epoch #516 end
# Epoch #517 start
# Epoch #517 end
# Epoch #518 start
# Epoch #518 end
# Epoch #519 start
# Epoch #519 end
# Epoch #520 start
# Epoch #520 end
# Epoch #521 start
# Epoch #521 end
# Epoch #522 start
# Epoch #522 end
# Epoch #523 start
# Epoch #523 end
# Epoch #524 start
# Epoch #524 end
# Epoch #525 start
# Epoch #525 end
# Epoch #526 start
# Epoch #526 end
# Epoch #527 start
# Epoch #527 end
# Epoch #528 start
# Epoch #528 end
# Epoch #529 start
# Epoch #529 end
# Epoch #530 start
# Epoch #530 end
# Epoch #531 start
# Epoch #531 end
# Epoch #532 start
# Epoch #532 end
# Epoch #533 start
# Epoch #533 end
# Epoch #534 start
# Epoch #534 end
# Epoch #535 start
# Epoch #535 end
# Epoch #536 start
# Epoch #536 end
# Epoch #537 start
# Epoch #537 end
# Epoch #538 start
# Epoch #538 end
# Epoch #539 start
# Epoch #539 end
# Epoch #540 start
# Epoch #540 end
# Epoch #541 start
# Epoch #541 end
# Epoch #542 start
# Epoch #542 end
# Epoch #543 start
# Epoch #543 end
# Epoch #544 start
# Epoch #544 end
# Epoch #545 start
# Epoch #545 end
# Epoch #546 start
# Epoch #546 end
# Epoch #547 start
# Epoch #547 end
# Epoch #548 start
# Epoch #548 end
# Epoch #549 start
# Epoch #549 end
# Epoch #550 start
# Epoch #550 end
# Epoch #551 start
# Epoch #551 end
# Epoch #552 start
# Epoch #552 end
# Epoch #553 start
# Epoch #553 end
# Epoch #554 start
# Epoch #554 end
# Epoch #555 start
# Epoch #555 end
# Epoch #556 start
# Epoch #556 end
# Epoch #557 start
# Epoch #557 end
# Epoch #558 start
# Epoch #558 end
# Epoch #559 start
# Epoch #559 end
# Epoch #560 start
# Epoch #560 end
# Epoch #561 start
# Epoch #561 end
# Epoch #562 start
# Epoch #562 end
# Epoch #563 start
# Epoch #563 end
# Epoch #564 start
# Epoch #564 end
# Epoch #565 start
# Epoch #565 end
# Epoch #566 start
# Epoch #566 end
# Epoch #567 start
# Epoch #567 end
# Epoch #568 start
# Epoch #568 end
# Epoch #569 start
# Epoch #569 end
# Epoch #570 start
# Epoch #570 end
# Epoch #571 start
# Epoch #571 end
# Epoch #572 start
# Epoch #572 end
# Epoch #573 start
# Epoch #573 end
# Epoch #574 start
# Epoch #574 end
# Epoch #575 start
# Epoch #575 end
# Epoch #576 start
# Epoch #576 end
# Epoch #577 start
# Epoch #577 end
# Epoch #578 start
# Epoch #578 end
# Epoch #579 start
# Epoch #579 end
# Epoch #580 start
# Epoch #580 end
# Epoch #581 start
# Epoch #581 end
# Epoch #582 start
# Epoch #582 end
# Epoch #583 start
# Epoch #583 end
# Epoch #584 start
# Epoch #584 end
# Epoch #585 start
# Epoch #585 end
# Epoch #586 start
# Epoch #586 end
# Epoch #587 start
# Epoch #587 end
# Epoch #588 start
# Epoch #588 end
# Epoch #589 start
# Epoch #589 end
# Epoch #590 start
# Epoch #590 end
# Epoch #591 start
# Epoch #591 end
# Epoch #592 start
# Epoch #592 end
# Epoch #593 start
# Epoch #593 end
# Epoch #594 start
# Epoch #594 end
# Epoch #595 start
# Epoch #595 end
# Epoch #596 start
# Epoch #596 end
# Epoch #597 start
# Epoch #597 end
# Epoch #598 start
# Epoch #598 end
# Epoch #599 start
# Epoch #599 end
#
# model 5 trained
# Epoch #600 start
# Epoch #600 end
# Epoch #601 start
# Epoch #601 end
# Epoch #602 start
# Epoch #602 end
# Epoch #603 start
# Epoch #603 end
# Epoch #604 start
# Epoch #604 end
# Epoch #605 start
# Epoch #605 end
# Epoch #606 start
# Epoch #606 end
# Epoch #607 start
# Epoch #607 end
# Epoch #608 start
# Epoch #608 end
# Epoch #609 start
# Epoch #609 end
# Epoch #610 start
# Epoch #610 end
# Epoch #611 start
# Epoch #611 end
# Epoch #612 start
# Epoch #612 end
# Epoch #613 start
# Epoch #613 end
# Epoch #614 start
# Epoch #614 end
# Epoch #615 start
# Epoch #615 end
# Epoch #616 start
# Epoch #616 end
# Epoch #617 start
# Epoch #617 end
# Epoch #618 start
# Epoch #618 end
# Epoch #619 start
# Epoch #619 end
# Epoch #620 start
# Epoch #620 end
# Epoch #621 start
# Epoch #621 end
# Epoch #622 start
# Epoch #622 end
# Epoch #623 start
# Epoch #623 end
# Epoch #624 start
# Epoch #624 end
# Epoch #625 start
# Epoch #625 end
# Epoch #626 start
# Epoch #626 end
# Epoch #627 start
# Epoch #627 end
# Epoch #628 start
# Epoch #628 end
# Epoch #629 start
# Epoch #629 end
# Epoch #630 start
# Epoch #630 end
# Epoch #631 start
# Epoch #631 end
# Epoch #632 start
# Epoch #632 end
# Epoch #633 start
# Epoch #633 end
# Epoch #634 start
# Epoch #634 end
# Epoch #635 start
# Epoch #635 end
# Epoch #636 start
# Epoch #636 end
# Epoch #637 start
# Epoch #637 end
# Epoch #638 start
# Epoch #638 end
# Epoch #639 start
# Epoch #639 end
# Epoch #640 start
# Epoch #640 end
# Epoch #641 start
# Epoch #641 end
# Epoch #642 start
# Epoch #642 end
# Epoch #643 start
# Epoch #643 end
# Epoch #644 start
# Epoch #644 end
# Epoch #645 start
# Epoch #645 end
# Epoch #646 start
# Epoch #646 end
# Epoch #647 start
# Epoch #647 end
# Epoch #648 start
# Epoch #648 end
# Epoch #649 start
# Epoch #649 end
# Epoch #650 start
# Epoch #650 end
# Epoch #651 start
# Epoch #651 end
# Epoch #652 start
# Epoch #652 end
# Epoch #653 start
# Epoch #653 end
# Epoch #654 start
# Epoch #654 end
# Epoch #655 start
# Epoch #655 end
# Epoch #656 start
# Epoch #656 end
# Epoch #657 start
# Epoch #657 end
# Epoch #658 start
# Epoch #658 end
# Epoch #659 start
# Epoch #659 end
# Epoch #660 start
# Epoch #660 end
# Epoch #661 start
# Epoch #661 end
# Epoch #662 start
# Epoch #662 end
# Epoch #663 start
# Epoch #663 end
# Epoch #664 start
# Epoch #664 end
# Epoch #665 start
# Epoch #665 end
# Epoch #666 start
# Epoch #666 end
# Epoch #667 start
# Epoch #667 end
# Epoch #668 start
# Epoch #668 end
# Epoch #669 start
# Epoch #669 end
# Epoch #670 start
# Epoch #670 end
# Epoch #671 start
# Epoch #671 end
# Epoch #672 start
# Epoch #672 end
# Epoch #673 start
# Epoch #673 end
# Epoch #674 start
# Epoch #674 end
# Epoch #675 start
# Epoch #675 end
# Epoch #676 start
# Epoch #676 end
# Epoch #677 start
# Epoch #677 end
# Epoch #678 start
# Epoch #678 end
# Epoch #679 start
# Epoch #679 end
# Epoch #680 start
# Epoch #680 end
# Epoch #681 start
# Epoch #681 end
# Epoch #682 start
# Epoch #682 end
# Epoch #683 start
# Epoch #683 end
# Epoch #684 start
# Epoch #684 end
# Epoch #685 start
# Epoch #685 end
# Epoch #686 start
# Epoch #686 end
# Epoch #687 start
# Epoch #687 end
# Epoch #688 start
# Epoch #688 end
# Epoch #689 start
# Epoch #689 end
# Epoch #690 start
# Epoch #690 end
# Epoch #691 start
# Epoch #691 end
# Epoch #692 start
# Epoch #692 end
# Epoch #693 start
# Epoch #693 end
# Epoch #694 start
# Epoch #694 end
# Epoch #695 start
# Epoch #695 end
# Epoch #696 start
# Epoch #696 end
# Epoch #697 start
# Epoch #697 end
# Epoch #698 start
# Epoch #698 end
# Epoch #699 start
# Epoch #699 end
#
# model 6 trained
# Epoch #700 start
# Epoch #700 end
# Epoch #701 start
# Epoch #701 end
# Epoch #702 start
# Epoch #702 end
# Epoch #703 start
# Epoch #703 end
# Epoch #704 start
# Epoch #704 end
# Epoch #705 start
# Epoch #705 end
# Epoch #706 start
# Epoch #706 end
# Epoch #707 start
# Epoch #707 end
# Epoch #708 start
# Epoch #708 end
# Epoch #709 start
# Epoch #709 end
# Epoch #710 start
# Epoch #710 end
# Epoch #711 start
# Epoch #711 end
# Epoch #712 start
# Epoch #712 end
# Epoch #713 start
# Epoch #713 end
# Epoch #714 start
# Epoch #714 end
# Epoch #715 start
# Epoch #715 end
# Epoch #716 start
# Epoch #716 end
# Epoch #717 start
# Epoch #717 end
# Epoch #718 start
# Epoch #718 end
# Epoch #719 start
# Epoch #719 end
# Epoch #720 start
# Epoch #720 end
# Epoch #721 start
# Epoch #721 end
# Epoch #722 start
# Epoch #722 end
# Epoch #723 start
# Epoch #723 end
# Epoch #724 start
# Epoch #724 end
# Epoch #725 start
# Epoch #725 end
# Epoch #726 start
# Epoch #726 end
# Epoch #727 start
# Epoch #727 end
# Epoch #728 start
# Epoch #728 end
# Epoch #729 start
# Epoch #729 end
# Epoch #730 start
# Epoch #730 end
# Epoch #731 start
# Epoch #731 end
# Epoch #732 start
# Epoch #732 end
# Epoch #733 start
# Epoch #733 end
# Epoch #734 start
# Epoch #734 end
# Epoch #735 start
# Epoch #735 end
# Epoch #736 start
# Epoch #736 end
# Epoch #737 start
# Epoch #737 end
# Epoch #738 start
# Epoch #738 end
# Epoch #739 start
# Epoch #739 end
# Epoch #740 start
# Epoch #740 end
# Epoch #741 start
# Epoch #741 end
# Epoch #742 start
# Epoch #742 end
# Epoch #743 start
# Epoch #743 end
# Epoch #744 start
# Epoch #744 end
# Epoch #745 start
# Epoch #745 end
# Epoch #746 start
# Epoch #746 end
# Epoch #747 start
# Epoch #747 end
# Epoch #748 start
# Epoch #748 end
# Epoch #749 start
# Epoch #749 end
# Epoch #750 start
# Epoch #750 end
# Epoch #751 start
# Epoch #751 end
# Epoch #752 start
# Epoch #752 end
# Epoch #753 start
# Epoch #753 end
# Epoch #754 start
# Epoch #754 end
# Epoch #755 start
# Epoch #755 end
# Epoch #756 start
# Epoch #756 end
# Epoch #757 start
# Epoch #757 end
# Epoch #758 start
# Epoch #758 end
# Epoch #759 start
# Epoch #759 end
# Epoch #760 start
# Epoch #760 end
# Epoch #761 start
# Epoch #761 end
# Epoch #762 start
# Epoch #762 end
# Epoch #763 start
# Epoch #763 end
# Epoch #764 start
# Epoch #764 end
# Epoch #765 start
# Epoch #765 end
# Epoch #766 start
# Epoch #766 end
# Epoch #767 start
# Epoch #767 end
# Epoch #768 start
# Epoch #768 end
# Epoch #769 start
# Epoch #769 end
# Epoch #770 start
# Epoch #770 end
# Epoch #771 start
# Epoch #771 end
# Epoch #772 start
# Epoch #772 end
# Epoch #773 start
# Epoch #773 end
# Epoch #774 start
# Epoch #774 end
# Epoch #775 start
# Epoch #775 end
# Epoch #776 start
# Epoch #776 end
# Epoch #777 start
# Epoch #777 end
# Epoch #778 start
# Epoch #778 end
# Epoch #779 start
# Epoch #779 end
# Epoch #780 start
# Epoch #780 end
# Epoch #781 start
# Epoch #781 end
# Epoch #782 start
# Epoch #782 end
# Epoch #783 start
# Epoch #783 end
# Epoch #784 start
# Epoch #784 end
# Epoch #785 start
# Epoch #785 end
# Epoch #786 start
# Epoch #786 end
# Epoch #787 start
# Epoch #787 end
# Epoch #788 start
# Epoch #788 end
# Epoch #789 start
# Epoch #789 end
# Epoch #790 start
# Epoch #790 end
# Epoch #791 start
# Epoch #791 end
# Epoch #792 start
# Epoch #792 end
# Epoch #793 start
# Epoch #793 end
# Epoch #794 start
# Epoch #794 end
# Epoch #795 start
# Epoch #795 end
# Epoch #796 start
# Epoch #796 end
# Epoch #797 start
# Epoch #797 end
# Epoch #798 start
# Epoch #798 end
# Epoch #799 start
# Epoch #799 end
#
# model 7 trained
# Epoch #800 start
# Epoch #800 end
# Epoch #801 start
# Epoch #801 end
# Epoch #802 start
# Epoch #802 end
# Epoch #803 start
# Epoch #803 end
# Epoch #804 start
# Epoch #804 end
# Epoch #805 start
# Epoch #805 end
# Epoch #806 start
# Epoch #806 end
# Epoch #807 start
# Epoch #807 end
# Epoch #808 start
# Epoch #808 end
# Epoch #809 start
# Epoch #809 end
# Epoch #810 start
# Epoch #810 end
# Epoch #811 start
# Epoch #811 end
# Epoch #812 start
# Epoch #812 end
# Epoch #813 start
# Epoch #813 end
# Epoch #814 start
# Epoch #814 end
# Epoch #815 start
# Epoch #815 end
# Epoch #816 start
# Epoch #816 end
# Epoch #817 start
# Epoch #817 end
# Epoch #818 start
# Epoch #818 end
# Epoch #819 start
# Epoch #819 end
# Epoch #820 start
# Epoch #820 end
# Epoch #821 start
# Epoch #821 end
# Epoch #822 start
# Epoch #822 end
# Epoch #823 start
# Epoch #823 end
# Epoch #824 start
# Epoch #824 end
# Epoch #825 start
# Epoch #825 end
# Epoch #826 start
# Epoch #826 end
# Epoch #827 start
# Epoch #827 end
# Epoch #828 start
# Epoch #828 end
# Epoch #829 start
# Epoch #829 end
# Epoch #830 start
# Epoch #830 end
# Epoch #831 start
# Epoch #831 end
# Epoch #832 start
# Epoch #832 end
# Epoch #833 start
# Epoch #833 end
# Epoch #834 start
# Epoch #834 end
# Epoch #835 start
# Epoch #835 end
# Epoch #836 start
# Epoch #836 end
# Epoch #837 start
# Epoch #837 end
# Epoch #838 start
# Epoch #838 end
# Epoch #839 start
# Epoch #839 end
# Epoch #840 start
# Epoch #840 end
# Epoch #841 start
# Epoch #841 end
# Epoch #842 start
# Epoch #842 end
# Epoch #843 start
# Epoch #843 end
# Epoch #844 start
# Epoch #844 end
# Epoch #845 start
# Epoch #845 end
# Epoch #846 start
# Epoch #846 end
# Epoch #847 start
# Epoch #847 end
# Epoch #848 start
# Epoch #848 end
# Epoch #849 start
# Epoch #849 end
# Epoch #850 start
# Epoch #850 end
# Epoch #851 start
# Epoch #851 end
# Epoch #852 start
# Epoch #852 end
# Epoch #853 start
# Epoch #853 end
# Epoch #854 start
# Epoch #854 end
# Epoch #855 start
# Epoch #855 end
# Epoch #856 start
# Epoch #856 end
# Epoch #857 start
# Epoch #857 end
# Epoch #858 start
# Epoch #858 end
# Epoch #859 start
# Epoch #859 end
# Epoch #860 start
# Epoch #860 end
# Epoch #861 start
# Epoch #861 end
# Epoch #862 start
# Epoch #862 end
# Epoch #863 start
# Epoch #863 end
# Epoch #864 start
# Epoch #864 end
# Epoch #865 start
# Epoch #865 end
# Epoch #866 start
# Epoch #866 end
# Epoch #867 start
# Epoch #867 end
# Epoch #868 start
# Epoch #868 end
# Epoch #869 start
# Epoch #869 end
# Epoch #870 start
# Epoch #870 end
# Epoch #871 start
# Epoch #871 end
# Epoch #872 start
# Epoch #872 end
# Epoch #873 start
# Epoch #873 end
# Epoch #874 start
# Epoch #874 end
# Epoch #875 start
# Epoch #875 end
# Epoch #876 start
# Epoch #876 end
# Epoch #877 start
# Epoch #877 end
# Epoch #878 start
# Epoch #878 end
# Epoch #879 start
# Epoch #879 end
# Epoch #880 start
# Epoch #880 end
# Epoch #881 start
# Epoch #881 end
# Epoch #882 start
# Epoch #882 end
# Epoch #883 start
# Epoch #883 end
# Epoch #884 start
# Epoch #884 end
# Epoch #885 start
# Epoch #885 end
# Epoch #886 start
# Epoch #886 end
# Epoch #887 start
# Epoch #887 end
# Epoch #888 start
# Epoch #888 end
# Epoch #889 start
# Epoch #889 end
# Epoch #890 start
# Epoch #890 end
# Epoch #891 start
# Epoch #891 end
# Epoch #892 start
# Epoch #892 end
# Epoch #893 start
# Epoch #893 end
# Epoch #894 start
# Epoch #894 end
# Epoch #895 start
# Epoch #895 end
# Epoch #896 start
# Epoch #896 end
# Epoch #897 start
# Epoch #897 end
# Epoch #898 start
# Epoch #898 end
# Epoch #899 start
# Epoch #899 end
#
# model 8 trained
# Epoch #900 start
# Epoch #900 end
# Epoch #901 start
# Epoch #901 end
# Epoch #902 start
# Epoch #902 end
# Epoch #903 start
# Epoch #903 end
# Epoch #904 start
# Epoch #904 end
# Epoch #905 start
# Epoch #905 end
# Epoch #906 start
# Epoch #906 end
# Epoch #907 start
# Epoch #907 end
# Epoch #908 start
# Epoch #908 end
# Epoch #909 start
# Epoch #909 end
# Epoch #910 start
# Epoch #910 end
# Epoch #911 start
# Epoch #911 end
# Epoch #912 start
# Epoch #912 end
# Epoch #913 start
# Epoch #913 end
# Epoch #914 start
# Epoch #914 end
# Epoch #915 start
# Epoch #915 end
# Epoch #916 start
# Epoch #916 end
# Epoch #917 start
# Epoch #917 end
# Epoch #918 start
# Epoch #918 end
# Epoch #919 start
# Epoch #919 end
# Epoch #920 start
# Epoch #920 end
# Epoch #921 start
# Epoch #921 end
# Epoch #922 start
# Epoch #922 end
# Epoch #923 start
# Epoch #923 end
# Epoch #924 start
# Epoch #924 end
# Epoch #925 start
# Epoch #925 end
# Epoch #926 start
# Epoch #926 end
# Epoch #927 start
# Epoch #927 end
# Epoch #928 start
# Epoch #928 end
# Epoch #929 start
# Epoch #929 end
# Epoch #930 start
# Epoch #930 end
# Epoch #931 start
# Epoch #931 end
# Epoch #932 start
# Epoch #932 end
# Epoch #933 start
# Epoch #933 end
# Epoch #934 start
# Epoch #934 end
# Epoch #935 start
# Epoch #935 end
# Epoch #936 start
# Epoch #936 end
# Epoch #937 start
# Epoch #937 end
# Epoch #938 start
# Epoch #938 end
# Epoch #939 start
# Epoch #939 end
# Epoch #940 start
# Epoch #940 end
# Epoch #941 start
# Epoch #941 end
# Epoch #942 start
# Epoch #942 end
# Epoch #943 start
# Epoch #943 end
# Epoch #944 start
# Epoch #944 end
# Epoch #945 start
# Epoch #945 end
# Epoch #946 start
# Epoch #946 end
# Epoch #947 start
# Epoch #947 end
# Epoch #948 start
# Epoch #948 end
# Epoch #949 start
# Epoch #949 end
# Epoch #950 start
# Epoch #950 end
# Epoch #951 start
# Epoch #951 end
# Epoch #952 start
# Epoch #952 end
# Epoch #953 start
# Epoch #953 end
# Epoch #954 start
# Epoch #954 end
# Epoch #955 start
# Epoch #955 end
# Epoch #956 start
# Epoch #956 end
# Epoch #957 start
# Epoch #957 end
# Epoch #958 start
# Epoch #958 end
# Epoch #959 start
# Epoch #959 end
# Epoch #960 start
# Epoch #960 end
# Epoch #961 start
# Epoch #961 end
# Epoch #962 start
# Epoch #962 end
# Epoch #963 start
# Epoch #963 end
# Epoch #964 start
# Epoch #964 end
# Epoch #965 start
# Epoch #965 end
# Epoch #966 start
# Epoch #966 end
# Epoch #967 start
# Epoch #967 end
# Epoch #968 start
# Epoch #968 end
# Epoch #969 start
# Epoch #969 end
# Epoch #970 start
# Epoch #970 end
# Epoch #971 start
# Epoch #971 end
# Epoch #972 start
# Epoch #972 end
# Epoch #973 start
# Epoch #973 end
# Epoch #974 start
# Epoch #974 end
# Epoch #975 start
# Epoch #975 end
# Epoch #976 start
# Epoch #976 end
# Epoch #977 start
# Epoch #977 end
# Epoch #978 start
# Epoch #978 end
# Epoch #979 start
# Epoch #979 end
# Epoch #980 start
# Epoch #980 end
# Epoch #981 start
# Epoch #981 end
# Epoch #982 start
# Epoch #982 end
# Epoch #983 start
# Epoch #983 end
# Epoch #984 start
# Epoch #984 end
# Epoch #985 start
# Epoch #985 end
# Epoch #986 start
# Epoch #986 end
# Epoch #987 start
# Epoch #987 end
# Epoch #988 start
# Epoch #988 end
# Epoch #989 start
# Epoch #989 end
# Epoch #990 start
# Epoch #990 end
# Epoch #991 start
# Epoch #991 end
# Epoch #992 start
# Epoch #992 end
# Epoch #993 start
# Epoch #993 end
# Epoch #994 start
# Epoch #994 end
# Epoch #995 start
# Epoch #995 end
# Epoch #996 start
# Epoch #996 end
# Epoch #997 start
# Epoch #997 end
# Epoch #998 start
# Epoch #998 end
# Epoch #999 start
# Epoch #999 end
#
# model 9 trained
# Epoch #1000 start
# Epoch #1000 end
# Epoch #1001 start
# Epoch #1001 end
# Epoch #1002 start
# Epoch #1002 end
# Epoch #1003 start
# Epoch #1003 end
# Epoch #1004 start
# Epoch #1004 end
# Epoch #1005 start
# Epoch #1005 end
# Epoch #1006 start
# Epoch #1006 end
# Epoch #1007 start
# Epoch #1007 end
# Epoch #1008 start
# Epoch #1008 end
# Epoch #1009 start
# Epoch #1009 end
# Epoch #1010 start
# Epoch #1010 end
# Epoch #1011 start
# Epoch #1011 end
# Epoch #1012 start
# Epoch #1012 end
# Epoch #1013 start
# Epoch #1013 end
# Epoch #1014 start
# Epoch #1014 end
# Epoch #1015 start
# Epoch #1015 end
# Epoch #1016 start
# Epoch #1016 end
# Epoch #1017 start
# Epoch #1017 end
# Epoch #1018 start
# Epoch #1018 end
# Epoch #1019 start
# Epoch #1019 end
# Epoch #1020 start
# Epoch #1020 end
# Epoch #1021 start
# Epoch #1021 end
# Epoch #1022 start
# Epoch #1022 end
# Epoch #1023 start
# Epoch #1023 end
# Epoch #1024 start
# Epoch #1024 end
# Epoch #1025 start
# Epoch #1025 end
# Epoch #1026 start
# Epoch #1026 end
# Epoch #1027 start
# Epoch #1027 end
# Epoch #1028 start
# Epoch #1028 end
# Epoch #1029 start
# Epoch #1029 end
# Epoch #1030 start
# Epoch #1030 end
# Epoch #1031 start
# Epoch #1031 end
# Epoch #1032 start
# Epoch #1032 end
# Epoch #1033 start
# Epoch #1033 end
# Epoch #1034 start
# Epoch #1034 end
# Epoch #1035 start
# Epoch #1035 end
# Epoch #1036 start
# Epoch #1036 end
# Epoch #1037 start
# Epoch #1037 end
# Epoch #1038 start
# Epoch #1038 end
# Epoch #1039 start
# Epoch #1039 end
# Epoch #1040 start
# Epoch #1040 end
# Epoch #1041 start
# Epoch #1041 end
# Epoch #1042 start
# Epoch #1042 end
# Epoch #1043 start
# Epoch #1043 end
# Epoch #1044 start
# Epoch #1044 end
# Epoch #1045 start
# Epoch #1045 end
# Epoch #1046 start
# Epoch #1046 end
# Epoch #1047 start
# Epoch #1047 end
# Epoch #1048 start
# Epoch #1048 end
# Epoch #1049 start
# Epoch #1049 end
# Epoch #1050 start
# Epoch #1050 end
# Epoch #1051 start
# Epoch #1051 end
# Epoch #1052 start
# Epoch #1052 end
# Epoch #1053 start
# Epoch #1053 end
# Epoch #1054 start
# Epoch #1054 end
# Epoch #1055 start
# Epoch #1055 end
# Epoch #1056 start
# Epoch #1056 end
# Epoch #1057 start
# Epoch #1057 end
# Epoch #1058 start
# Epoch #1058 end
# Epoch #1059 start
# Epoch #1059 end
# Epoch #1060 start
# Epoch #1060 end
# Epoch #1061 start
# Epoch #1061 end
# Epoch #1062 start
# Epoch #1062 end
# Epoch #1063 start
# Epoch #1063 end
# Epoch #1064 start
# Epoch #1064 end
# Epoch #1065 start
# Epoch #1065 end
# Epoch #1066 start
# Epoch #1066 end
# Epoch #1067 start
# Epoch #1067 end
# Epoch #1068 start
# Epoch #1068 end
# Epoch #1069 start
# Epoch #1069 end
# Epoch #1070 start
# Epoch #1070 end
# Epoch #1071 start
# Epoch #1071 end
# Epoch #1072 start
# Epoch #1072 end
# Epoch #1073 start
# Epoch #1073 end
# Epoch #1074 start
# Epoch #1074 end
# Epoch #1075 start
# Epoch #1075 end
# Epoch #1076 start
# Epoch #1076 end
# Epoch #1077 start
# Epoch #1077 end
# Epoch #1078 start
# Epoch #1078 end
# Epoch #1079 start
# Epoch #1079 end
# Epoch #1080 start
# Epoch #1080 end
# Epoch #1081 start
# Epoch #1081 end
# Epoch #1082 start
# Epoch #1082 end
# Epoch #1083 start
# Epoch #1083 end
# Epoch #1084 start
# Epoch #1084 end
# Epoch #1085 start
# Epoch #1085 end
# Epoch #1086 start
# Epoch #1086 end
# Epoch #1087 start
# Epoch #1087 end
# Epoch #1088 start
# Epoch #1088 end
# Epoch #1089 start
# Epoch #1089 end
# Epoch #1090 start
# Epoch #1090 end
# Epoch #1091 start
# Epoch #1091 end
# Epoch #1092 start
# Epoch #1092 end
# Epoch #1093 start
# Epoch #1093 end
# Epoch #1094 start
# Epoch #1094 end
# Epoch #1095 start
# Epoch #1095 end
# Epoch #1096 start
# Epoch #1096 end
# Epoch #1097 start
# Epoch #1097 end
# Epoch #1098 start
# Epoch #1098 end
# Epoch #1099 start
# Epoch #1099 end
#
# model 10 trained
# Epoch #1100 start
# Epoch #1100 end
# Epoch #1101 start
# Epoch #1101 end
# Epoch #1102 start
# Epoch #1102 end
# Epoch #1103 start
# Epoch #1103 end
# Epoch #1104 start
# Epoch #1104 end
# Epoch #1105 start
# Epoch #1105 end
# Epoch #1106 start
# Epoch #1106 end
# Epoch #1107 start
# Epoch #1107 end
# Epoch #1108 start
# Epoch #1108 end
# Epoch #1109 start
# Epoch #1109 end
# Epoch #1110 start
# Epoch #1110 end
# Epoch #1111 start
# Epoch #1111 end
# Epoch #1112 start
# Epoch #1112 end
# Epoch #1113 start
# Epoch #1113 end
# Epoch #1114 start
# Epoch #1114 end
# Epoch #1115 start
# Epoch #1115 end
# Epoch #1116 start
# Epoch #1116 end
# Epoch #1117 start
# Epoch #1117 end
# Epoch #1118 start
# Epoch #1118 end
# Epoch #1119 start
# Epoch #1119 end
# Epoch #1120 start
# Epoch #1120 end
# Epoch #1121 start
# Epoch #1121 end
# Epoch #1122 start
# Epoch #1122 end
# Epoch #1123 start
# Epoch #1123 end
# Epoch #1124 start
# Epoch #1124 end
# Epoch #1125 start
# Epoch #1125 end
# Epoch #1126 start
# Epoch #1126 end
# Epoch #1127 start
# Epoch #1127 end
# Epoch #1128 start
# Epoch #1128 end
# Epoch #1129 start
# Epoch #1129 end
# Epoch #1130 start
# Epoch #1130 end
# Epoch #1131 start
# Epoch #1131 end
# Epoch #1132 start
# Epoch #1132 end
# Epoch #1133 start
# Epoch #1133 end
# Epoch #1134 start
# Epoch #1134 end
# Epoch #1135 start
# Epoch #1135 end
# Epoch #1136 start
# Epoch #1136 end
# Epoch #1137 start
# Epoch #1137 end
# Epoch #1138 start
# Epoch #1138 end
# Epoch #1139 start
# Epoch #1139 end
# Epoch #1140 start
# Epoch #1140 end
# Epoch #1141 start
# Epoch #1141 end
# Epoch #1142 start
# Epoch #1142 end
# Epoch #1143 start
# Epoch #1143 end
# Epoch #1144 start
# Epoch #1144 end
# Epoch #1145 start
# Epoch #1145 end
# Epoch #1146 start
# Epoch #1146 end
# Epoch #1147 start
# Epoch #1147 end
# Epoch #1148 start
# Epoch #1148 end
# Epoch #1149 start
# Epoch #1149 end
# Epoch #1150 start
# Epoch #1150 end
# Epoch #1151 start
# Epoch #1151 end
# Epoch #1152 start
# Epoch #1152 end
# Epoch #1153 start
# Epoch #1153 end
# Epoch #1154 start
# Epoch #1154 end
# Epoch #1155 start
# Epoch #1155 end
# Epoch #1156 start
# Epoch #1156 end
# Epoch #1157 start
# Epoch #1157 end
# Epoch #1158 start
# Epoch #1158 end
# Epoch #1159 start
# Epoch #1159 end
# Epoch #1160 start
# Epoch #1160 end
# Epoch #1161 start
# Epoch #1161 end
# Epoch #1162 start
# Epoch #1162 end
# Epoch #1163 start
# Epoch #1163 end
# Epoch #1164 start
# Epoch #1164 end
# Epoch #1165 start
# Epoch #1165 end
# Epoch #1166 start
# Epoch #1166 end
# Epoch #1167 start
# Epoch #1167 end
# Epoch #1168 start
# Epoch #1168 end
# Epoch #1169 start
# Epoch #1169 end
# Epoch #1170 start
# Epoch #1170 end
# Epoch #1171 start
# Epoch #1171 end
# Epoch #1172 start
# Epoch #1172 end
# Epoch #1173 start
# Epoch #1173 end
# Epoch #1174 start
# Epoch #1174 end
# Epoch #1175 start
# Epoch #1175 end
# Epoch #1176 start
# Epoch #1176 end
# Epoch #1177 start
# Epoch #1177 end
# Epoch #1178 start
# Epoch #1178 end
# Epoch #1179 start
# Epoch #1179 end
# Epoch #1180 start
# Epoch #1180 end
# Epoch #1181 start
# Epoch #1181 end
# Epoch #1182 start
# Epoch #1182 end
# Epoch #1183 start
# Epoch #1183 end
# Epoch #1184 start
# Epoch #1184 end
# Epoch #1185 start
# Epoch #1185 end
# Epoch #1186 start
# Epoch #1186 end
# Epoch #1187 start
# Epoch #1187 end
# Epoch #1188 start
# Epoch #1188 end
# Epoch #1189 start
# Epoch #1189 end
# Epoch #1190 start
# Epoch #1190 end
# Epoch #1191 start
# Epoch #1191 end
# Epoch #1192 start
# Epoch #1192 end
# Epoch #1193 start
# Epoch #1193 end
# Epoch #1194 start
# Epoch #1194 end
# Epoch #1195 start
# Epoch #1195 end
# Epoch #1196 start
# Epoch #1196 end
# Epoch #1197 start
# Epoch #1197 end
# Epoch #1198 start
# Epoch #1198 end
# Epoch #1199 start
# Epoch #1199 end
#
# model 11 trained
# Epoch #1200 start
# Epoch #1200 end
# Epoch #1201 start
# Epoch #1201 end
# Epoch #1202 start
# Epoch #1202 end
# Epoch #1203 start
# Epoch #1203 end
# Epoch #1204 start
# Epoch #1204 end
# Epoch #1205 start
# Epoch #1205 end
# Epoch #1206 start
# Epoch #1206 end
# Epoch #1207 start
# Epoch #1207 end
# Epoch #1208 start
# Epoch #1208 end
# Epoch #1209 start
# Epoch #1209 end
# Epoch #1210 start
# Epoch #1210 end
# Epoch #1211 start
# Epoch #1211 end
# Epoch #1212 start
# Epoch #1212 end
# Epoch #1213 start
# Epoch #1213 end
# Epoch #1214 start
# Epoch #1214 end
# Epoch #1215 start
# Epoch #1215 end
# Epoch #1216 start
# Epoch #1216 end
# Epoch #1217 start
# Epoch #1217 end
# Epoch #1218 start
# Epoch #1218 end
# Epoch #1219 start
# Epoch #1219 end
# Epoch #1220 start
# Epoch #1220 end
# Epoch #1221 start
# Epoch #1221 end
# Epoch #1222 start
# Epoch #1222 end
# Epoch #1223 start
# Epoch #1223 end
# Epoch #1224 start
# Epoch #1224 end
# Epoch #1225 start
# Epoch #1225 end
# Epoch #1226 start
# Epoch #1226 end
# Epoch #1227 start
# Epoch #1227 end
# Epoch #1228 start
# Epoch #1228 end
# Epoch #1229 start
# Epoch #1229 end
# Epoch #1230 start
# Epoch #1230 end
# Epoch #1231 start
# Epoch #1231 end
# Epoch #1232 start
# Epoch #1232 end
# Epoch #1233 start
# Epoch #1233 end
# Epoch #1234 start
# Epoch #1234 end
# Epoch #1235 start
# Epoch #1235 end
# Epoch #1236 start
# Epoch #1236 end
# Epoch #1237 start
# Epoch #1237 end
# Epoch #1238 start
# Epoch #1238 end
# Epoch #1239 start
# Epoch #1239 end
# Epoch #1240 start
# Epoch #1240 end
# Epoch #1241 start
# Epoch #1241 end
# Epoch #1242 start
# Epoch #1242 end
# Epoch #1243 start
# Epoch #1243 end
# Epoch #1244 start
# Epoch #1244 end
# Epoch #1245 start
# Epoch #1245 end
# Epoch #1246 start
# Epoch #1246 end
# Epoch #1247 start
# Epoch #1247 end
# Epoch #1248 start
# Epoch #1248 end
# Epoch #1249 start
# Epoch #1249 end
# Epoch #1250 start
# Epoch #1250 end
# Epoch #1251 start
# Epoch #1251 end
# Epoch #1252 start
# Epoch #1252 end
# Epoch #1253 start
# Epoch #1253 end
# Epoch #1254 start
# Epoch #1254 end
# Epoch #1255 start
# Epoch #1255 end
# Epoch #1256 start
# Epoch #1256 end
# Epoch #1257 start
# Epoch #1257 end
# Epoch #1258 start
# Epoch #1258 end
# Epoch #1259 start
# Epoch #1259 end
# Epoch #1260 start
# Epoch #1260 end
# Epoch #1261 start
# Epoch #1261 end
# Epoch #1262 start
# Epoch #1262 end
# Epoch #1263 start
# Epoch #1263 end
# Epoch #1264 start
# Epoch #1264 end
# Epoch #1265 start
# Epoch #1265 end
# Epoch #1266 start
# Epoch #1266 end
# Epoch #1267 start
# Epoch #1267 end
# Epoch #1268 start
# Epoch #1268 end
# Epoch #1269 start
# Epoch #1269 end
# Epoch #1270 start
# Epoch #1270 end
# Epoch #1271 start
# Epoch #1271 end
# Epoch #1272 start
# Epoch #1272 end
# Epoch #1273 start
# Epoch #1273 end
# Epoch #1274 start
# Epoch #1274 end
# Epoch #1275 start
# Epoch #1275 end
# Epoch #1276 start
# Epoch #1276 end
# Epoch #1277 start
# Epoch #1277 end
# Epoch #1278 start
# Epoch #1278 end
# Epoch #1279 start
# Epoch #1279 end
# Epoch #1280 start
# Epoch #1280 end
# Epoch #1281 start
# Epoch #1281 end
# Epoch #1282 start
# Epoch #1282 end
# Epoch #1283 start
# Epoch #1283 end
# Epoch #1284 start
# Epoch #1284 end
# Epoch #1285 start
# Epoch #1285 end
# Epoch #1286 start
# Epoch #1286 end
# Epoch #1287 start
# Epoch #1287 end
# Epoch #1288 start
# Epoch #1288 end
# Epoch #1289 start
# Epoch #1289 end
# Epoch #1290 start
# Epoch #1290 end
# Epoch #1291 start
# Epoch #1291 end
# Epoch #1292 start
# Epoch #1292 end
# Epoch #1293 start
# Epoch #1293 end
# Epoch #1294 start
# Epoch #1294 end
# Epoch #1295 start
# Epoch #1295 end
# Epoch #1296 start
# Epoch #1296 end
# Epoch #1297 start
# Epoch #1297 end
# Epoch #1298 start
# Epoch #1298 end
# Epoch #1299 start
# Epoch #1299 end
#
# model 12 trained
# Epoch #1300 start
# Epoch #1300 end
# Epoch #1301 start
# Epoch #1301 end
# Epoch #1302 start
# Epoch #1302 end
# Epoch #1303 start
# Epoch #1303 end
# Epoch #1304 start
# Epoch #1304 end
# Epoch #1305 start
# Epoch #1305 end
# Epoch #1306 start
# Epoch #1306 end
# Epoch #1307 start
# Epoch #1307 end
# Epoch #1308 start
# Epoch #1308 end
# Epoch #1309 start
# Epoch #1309 end
# Epoch #1310 start
# Epoch #1310 end
# Epoch #1311 start
# Epoch #1311 end
# Epoch #1312 start
# Epoch #1312 end
# Epoch #1313 start
# Epoch #1313 end
# Epoch #1314 start
# Epoch #1314 end
# Epoch #1315 start
# Epoch #1315 end
# Epoch #1316 start
# Epoch #1316 end
# Epoch #1317 start
# Epoch #1317 end
# Epoch #1318 start
# Epoch #1318 end
# Epoch #1319 start
# Epoch #1319 end
# Epoch #1320 start
# Epoch #1320 end
# Epoch #1321 start
# Epoch #1321 end
# Epoch #1322 start
# Epoch #1322 end
# Epoch #1323 start
# Epoch #1323 end
# Epoch #1324 start
# Epoch #1324 end
# Epoch #1325 start
# Epoch #1325 end
# Epoch #1326 start
# Epoch #1326 end
# Epoch #1327 start
# Epoch #1327 end
# Epoch #1328 start
# Epoch #1328 end
# Epoch #1329 start
# Epoch #1329 end
# Epoch #1330 start
# Epoch #1330 end
# Epoch #1331 start
# Epoch #1331 end
# Epoch #1332 start
# Epoch #1332 end
# Epoch #1333 start
# Epoch #1333 end
# Epoch #1334 start
# Epoch #1334 end
# Epoch #1335 start
# Epoch #1335 end
# Epoch #1336 start
# Epoch #1336 end
# Epoch #1337 start
# Epoch #1337 end
# Epoch #1338 start
# Epoch #1338 end
# Epoch #1339 start
# Epoch #1339 end
# Epoch #1340 start
# Epoch #1340 end
# Epoch #1341 start
# Epoch #1341 end
# Epoch #1342 start
# Epoch #1342 end
# Epoch #1343 start
# Epoch #1343 end
# Epoch #1344 start
# Epoch #1344 end
# Epoch #1345 start
# Epoch #1345 end
# Epoch #1346 start
# Epoch #1346 end
# Epoch #1347 start
# Epoch #1347 end
# Epoch #1348 start
# Epoch #1348 end
# Epoch #1349 start
# Epoch #1349 end
# Epoch #1350 start
# Epoch #1350 end
# Epoch #1351 start
# Epoch #1351 end
# Epoch #1352 start
# Epoch #1352 end
# Epoch #1353 start
# Epoch #1353 end
# Epoch #1354 start
# Epoch #1354 end
# Epoch #1355 start
# Epoch #1355 end
# Epoch #1356 start
# Epoch #1356 end
# Epoch #1357 start
# Epoch #1357 end
# Epoch #1358 start
# Epoch #1358 end
# Epoch #1359 start
# Epoch #1359 end
# Epoch #1360 start
# Epoch #1360 end
# Epoch #1361 start
# Epoch #1361 end
# Epoch #1362 start
# Epoch #1362 end
# Epoch #1363 start
# Epoch #1363 end
# Epoch #1364 start
# Epoch #1364 end
# Epoch #1365 start
# Epoch #1365 end
# Epoch #1366 start
# Epoch #1366 end
# Epoch #1367 start
# Epoch #1367 end
# Epoch #1368 start
# Epoch #1368 end
# Epoch #1369 start
# Epoch #1369 end
# Epoch #1370 start
# Epoch #1370 end
# Epoch #1371 start
# Epoch #1371 end
# Epoch #1372 start
# Epoch #1372 end
# Epoch #1373 start
# Epoch #1373 end
# Epoch #1374 start
# Epoch #1374 end
# Epoch #1375 start
# Epoch #1375 end
# Epoch #1376 start
# Epoch #1376 end
# Epoch #1377 start
# Epoch #1377 end
# Epoch #1378 start
# Epoch #1378 end
# Epoch #1379 start
# Epoch #1379 end
# Epoch #1380 start
# Epoch #1380 end
# Epoch #1381 start
# Epoch #1381 end
# Epoch #1382 start
# Epoch #1382 end
# Epoch #1383 start
# Epoch #1383 end
# Epoch #1384 start
# Epoch #1384 end
# Epoch #1385 start
# Epoch #1385 end
# Epoch #1386 start
# Epoch #1386 end
# Epoch #1387 start
# Epoch #1387 end
# Epoch #1388 start
# Epoch #1388 end
# Epoch #1389 start
# Epoch #1389 end
# Epoch #1390 start
# Epoch #1390 end
# Epoch #1391 start
# Epoch #1391 end
# Epoch #1392 start
# Epoch #1392 end
# Epoch #1393 start
# Epoch #1393 end
# Epoch #1394 start
# Epoch #1394 end
# Epoch #1395 start
# Epoch #1395 end
# Epoch #1396 start
# Epoch #1396 end
# Epoch #1397 start
# Epoch #1397 end
# Epoch #1398 start
# Epoch #1398 end
# Epoch #1399 start
# Epoch #1399 end
#
# model 13 trained
# Epoch #1400 start
# Epoch #1400 end
# Epoch #1401 start
# Epoch #1401 end
# Epoch #1402 start
# Epoch #1402 end
# Epoch #1403 start
# Epoch #1403 end
# Epoch #1404 start
# Epoch #1404 end
# Epoch #1405 start
# Epoch #1405 end
# Epoch #1406 start
# Epoch #1406 end
# Epoch #1407 start
# Epoch #1407 end
# Epoch #1408 start
# Epoch #1408 end
# Epoch #1409 start
# Epoch #1409 end
# Epoch #1410 start
# Epoch #1410 end
# Epoch #1411 start
# Epoch #1411 end
# Epoch #1412 start
# Epoch #1412 end
# Epoch #1413 start
# Epoch #1413 end
# Epoch #1414 start
# Epoch #1414 end
# Epoch #1415 start
# Epoch #1415 end
# Epoch #1416 start
# Epoch #1416 end
# Epoch #1417 start
# Epoch #1417 end
# Epoch #1418 start
# Epoch #1418 end
# Epoch #1419 start
# Epoch #1419 end
# Epoch #1420 start
# Epoch #1420 end
# Epoch #1421 start
# Epoch #1421 end
# Epoch #1422 start
# Epoch #1422 end
# Epoch #1423 start
# Epoch #1423 end
# Epoch #1424 start
# Epoch #1424 end
# Epoch #1425 start
# Epoch #1425 end
# Epoch #1426 start
# Epoch #1426 end
# Epoch #1427 start
# Epoch #1427 end
# Epoch #1428 start
# Epoch #1428 end
# Epoch #1429 start
# Epoch #1429 end
# Epoch #1430 start
# Epoch #1430 end
# Epoch #1431 start
# Epoch #1431 end
# Epoch #1432 start
# Epoch #1432 end
# Epoch #1433 start
# Epoch #1433 end
# Epoch #1434 start
# Epoch #1434 end
# Epoch #1435 start
# Epoch #1435 end
# Epoch #1436 start
# Epoch #1436 end
# Epoch #1437 start
# Epoch #1437 end
# Epoch #1438 start
# Epoch #1438 end
# Epoch #1439 start
# Epoch #1439 end
# Epoch #1440 start
# Epoch #1440 end
# Epoch #1441 start
# Epoch #1441 end
# Epoch #1442 start
# Epoch #1442 end
# Epoch #1443 start
# Epoch #1443 end
# Epoch #1444 start
# Epoch #1444 end
# Epoch #1445 start
# Epoch #1445 end
# Epoch #1446 start
# Epoch #1446 end
# Epoch #1447 start
# Epoch #1447 end
# Epoch #1448 start
# Epoch #1448 end
# Epoch #1449 start
# Epoch #1449 end
# Epoch #1450 start
# Epoch #1450 end
# Epoch #1451 start
# Epoch #1451 end
# Epoch #1452 start
# Epoch #1452 end
# Epoch #1453 start
# Epoch #1453 end
# Epoch #1454 start
# Epoch #1454 end
# Epoch #1455 start
# Epoch #1455 end
# Epoch #1456 start
# Epoch #1456 end
# Epoch #1457 start
# Epoch #1457 end
# Epoch #1458 start
# Epoch #1458 end
# Epoch #1459 start
# Epoch #1459 end
# Epoch #1460 start
# Epoch #1460 end
# Epoch #1461 start
# Epoch #1461 end
# Epoch #1462 start
# Epoch #1462 end
# Epoch #1463 start
# Epoch #1463 end
# Epoch #1464 start
# Epoch #1464 end
# Epoch #1465 start
# Epoch #1465 end
# Epoch #1466 start
# Epoch #1466 end
# Epoch #1467 start
# Epoch #1467 end
# Epoch #1468 start
# Epoch #1468 end
# Epoch #1469 start
# ...
# Epoch #1932 end
# Epoch #1933 start
# Epoch #1933 end
# Epoch #1934 start
# Epoch #1934 end
# Epoch #1935 start
# Epoch #1935 end
# Epoch #1936 start
# Epoch #1936 end
# Epoch #1937 start
# Epoch #1937 end
# Epoch #1938 start
# Epoch #1938 end
# Epoch #1939 start
# Epoch #1939 end
# Epoch #1940 start
# Epoch #1940 end
# Epoch #1941 start
# Epoch #1941 end
# Epoch #1942 start
# Epoch #1942 end
# Epoch #1943 start
# Epoch #1943 end
# Epoch #1944 start
# Epoch #1944 end
# Epoch #1945 start
# Epoch #1945 end
# Epoch #1946 start
# Epoch #1946 end
# Epoch #1947 start
# Epoch #1947 end
# Epoch #1948 start
# Epoch #1948 end
# Epoch #1949 start
# Epoch #1949 end
# Epoch #1950 start
# Epoch #1950 end
# Epoch #1951 start
# Epoch #1951 end
# Epoch #1952 start
# Epoch #1952 end
# Epoch #1953 start
# Epoch #1953 end
# Epoch #1954 start
# Epoch #1954 end
# Epoch #1955 start
# Epoch #1955 end
# Epoch #1956 start
# Epoch #1956 end
# Epoch #1957 start
# Epoch #1957 end
# Epoch #1958 start
# Epoch #1958 end
# Epoch #1959 start
# Epoch #1959 end
# Epoch #1960 start
# Epoch #1960 end
# Epoch #1961 start
# Epoch #1961 end
# Epoch #1962 start
# Epoch #1962 end
# Epoch #1963 start
# Epoch #1963 end
# Epoch #1964 start
# Epoch #1964 end
# Epoch #1965 start
# Epoch #1965 end
# Epoch #1966 start
# Epoch #1966 end
# Epoch #1967 start
# Epoch #1967 end
# Epoch #1968 start
# Epoch #1968 end
# Epoch #1969 start
# Epoch #1969 end
# Epoch #1970 start
# Epoch #1970 end
# Epoch #1971 start
# Epoch #1971 end
# Epoch #1972 start
# Epoch #1972 end
# Epoch #1973 start
# Epoch #1973 end
# Epoch #1974 start
# Epoch #1974 end
# Epoch #1975 start
# Epoch #1975 end
# Epoch #1976 start
# Epoch #1976 end
# Epoch #1977 start
# Epoch #1977 end
# Epoch #1978 start
# Epoch #1978 end
# Epoch #1979 start
# Epoch #1979 end
# Epoch #1980 start
# Epoch #1980 end
# Epoch #1981 start
# Epoch #1981 end
# Epoch #1982 start
# Epoch #1982 end
# Epoch #1983 start
# Epoch #1983 end
# Epoch #1984 start
# Epoch #1984 end
# Epoch #1985 start
# Epoch #1985 end
# Epoch #1986 start
# Epoch #1986 end
# Epoch #1987 start
# Epoch #1987 end
# Epoch #1988 start
# Epoch #1988 end
# Epoch #1989 start
# Epoch #1989 end
# Epoch #1990 start
# Epoch #1990 end
# Epoch #1991 start
# Epoch #1991 end
# Epoch #1992 start
# Epoch #1992 end
# Epoch #1993 start
# Epoch #1993 end
# Epoch #1994 start
# Epoch #1994 end
# Epoch #1995 start
# Epoch #1995 end
# Epoch #1996 start
# Epoch #1996 end
# Epoch #1997 start
# Epoch #1997 end
# Epoch #1998 start
# Epoch #1998 end
# Epoch #1999 start
# Epoch #1999 end
#
# model 19 trained
# Epoch #2000 start
# Epoch #2000 end
# Epoch #2001 start
# Epoch #2001 end
# Epoch #2002 start
# Epoch #2002 end
# Epoch #2003 start
# Epoch #2003 end
# Epoch #2004 start
# Epoch #2004 end
# Epoch #2005 start
# Epoch #2005 end
# Epoch #2006 start
# Epoch #2006 end
# Epoch #2007 start
# Epoch #2007 end
# Epoch #2008 start
# Epoch #2008 end
# Epoch #2009 start
# Epoch #2009 end
# Epoch #2010 start
# Epoch #2010 end
# Epoch #2011 start
# Epoch #2011 end
# Epoch #2012 start
# Epoch #2012 end
# Epoch #2013 start
# Epoch #2013 end
# Epoch #2014 start
# Epoch #2014 end
# Epoch #2015 start
# Epoch #2015 end
# Epoch #2016 start
# Epoch #2016 end
# Epoch #2017 start
# Epoch #2017 end
# Epoch #2018 start
# Epoch #2018 end
# Epoch #2019 start
# Epoch #2019 end
# Epoch #2020 start
# Epoch #2020 end
# Epoch #2021 start
# Epoch #2021 end
# Epoch #2022 start
# Epoch #2022 end
# Epoch #2023 start
# Epoch #2023 end
# Epoch #2024 start
# Epoch #2024 end
# Epoch #2025 start
# Epoch #2025 end
# Epoch #2026 start
# Epoch #2026 end
# Epoch #2027 start
# Epoch #2027 end
# Epoch #2028 start
# Epoch #2028 end
# Epoch #2029 start
# Epoch #2029 end
# Epoch #2030 start
# Epoch #2030 end
# Epoch #2031 start
# Epoch #2031 end
# Epoch #2032 start
# Epoch #2032 end
# Epoch #2033 start
# Epoch #2033 end
# Epoch #2034 start
# Epoch #2034 end
# Epoch #2035 start
# Epoch #2035 end
# Epoch #2036 start
# Epoch #2036 end
# Epoch #2037 start
# Epoch #2037 end
# Epoch #2038 start
# Epoch #2038 end
# Epoch #2039 start
# Epoch #2039 end
# Epoch #2040 start
# Epoch #2040 end
# Epoch #2041 start
# Epoch #2041 end
# Epoch #2042 start
# Epoch #2042 end
# Epoch #2043 start
# Epoch #2043 end
# Epoch #2044 start
# Epoch #2044 end
# Epoch #2045 start
# Epoch #2045 end
# Epoch #2046 start
# Epoch #2046 end
# Epoch #2047 start
# Epoch #2047 end
# Epoch #2048 start
# Epoch #2048 end
# Epoch #2049 start
# Epoch #2049 end
# Epoch #2050 start
# Epoch #2050 end
# Epoch #2051 start
# Epoch #2051 end
# Epoch #2052 start
# Epoch #2052 end
# Epoch #2053 start
# Epoch #2053 end
# Epoch #2054 start
# Epoch #2054 end
# Epoch #2055 start
# Epoch #2055 end
# Epoch #2056 start
# Epoch #2056 end
# Epoch #2057 start
# Epoch #2057 end
# Epoch #2058 start
# Epoch #2058 end
# Epoch #2059 start
# Epoch #2059 end
# Epoch #2060 start
# Epoch #2060 end
# Epoch #2061 start
# Epoch #2061 end
# Epoch #2062 start
# Epoch #2062 end
# Epoch #2063 start
# Epoch #2063 end
# Epoch #2064 start
# Epoch #2064 end
# Epoch #2065 start
# Epoch #2065 end
# Epoch #2066 start
# Epoch #2066 end
# Epoch #2067 start
# Epoch #2067 end
# Epoch #2068 start
# Epoch #2068 end
# Epoch #2069 start
# Epoch #2069 end
# Epoch #2070 start
# Epoch #2070 end
# Epoch #2071 start
# Epoch #2071 end
# Epoch #2072 start
# Epoch #2072 end
# Epoch #2073 start
# Epoch #2073 end
# Epoch #2074 start
# Epoch #2074 end
# Epoch #2075 start
# Epoch #2075 end
# Epoch #2076 start
# Epoch #2076 end
# Epoch #2077 start
# Epoch #2077 end
# Epoch #2078 start
# Epoch #2078 end
# Epoch #2079 start
# Epoch #2079 end
# Epoch #2080 start
# Epoch #2080 end
# Epoch #2081 start
# Epoch #2081 end
# Epoch #2082 start
# Epoch #2082 end
# Epoch #2083 start
# Epoch #2083 end
# Epoch #2084 start
# Epoch #2084 end
# Epoch #2085 start
# Epoch #2085 end
# Epoch #2086 start
# Epoch #2086 end
# Epoch #2087 start
# Epoch #2087 end
# Epoch #2088 start
# Epoch #2088 end
# Epoch #2089 start
# Epoch #2089 end
# Epoch #2090 start
# Epoch #2090 end
# Epoch #2091 start
# Epoch #2091 end
# Epoch #2092 start
# Epoch #2092 end
# Epoch #2093 start
# Epoch #2093 end
# Epoch #2094 start
# Epoch #2094 end
# Epoch #2095 start
# Epoch #2095 end
# Epoch #2096 start
# Epoch #2096 end
# Epoch #2097 start
# Epoch #2097 end
# Epoch #2098 start
# Epoch #2098 end
# Epoch #2099 start
# Epoch #2099 end
#
# model 20 trained
# Epoch #2100 start
# Epoch #2100 end
# Epoch #2101 start
# Epoch #2101 end
# Epoch #2102 start
# Epoch #2102 end
# Epoch #2103 start
# Epoch #2103 end
# Epoch #2104 start
# Epoch #2104 end
# Epoch #2105 start
# Epoch #2105 end
# Epoch #2106 start
# Epoch #2106 end
# Epoch #2107 start
# Epoch #2107 end
# Epoch #2108 start
# Epoch #2108 end
# Epoch #2109 start
# Epoch #2109 end
# Epoch #2110 start
# Epoch #2110 end
# Epoch #2111 start
# Epoch #2111 end
# Epoch #2112 start
# Epoch #2112 end
# Epoch #2113 start
# Epoch #2113 end
# Epoch #2114 start
# Epoch #2114 end
# Epoch #2115 start
# Epoch #2115 end
# Epoch #2116 start
# Epoch #2116 end
# Epoch #2117 start
# Epoch #2117 end
# Epoch #2118 start
# Epoch #2118 end
# Epoch #2119 start
# Epoch #2119 end
# Epoch #2120 start
# Epoch #2120 end
# Epoch #2121 start
# Epoch #2121 end
# Epoch #2122 start
# Epoch #2122 end
# Epoch #2123 start
# Epoch #2123 end
# Epoch #2124 start
# Epoch #2124 end
# Epoch #2125 start
# Epoch #2125 end
# Epoch #2126 start
# Epoch #2126 end
# Epoch #2127 start
# Epoch #2127 end
# Epoch #2128 start
# Epoch #2128 end
# Epoch #2129 start
# Epoch #2129 end
# Epoch #2130 start
# Epoch #2130 end
# Epoch #2131 start
# Epoch #2131 end
# Epoch #2132 start
# Epoch #2132 end
# Epoch #2133 start
# Epoch #2133 end
# Epoch #2134 start
# Epoch #2134 end
# Epoch #2135 start
# Epoch #2135 end
# Epoch #2136 start
# Epoch #2136 end
# Epoch #2137 start
# Epoch #2137 end
# Epoch #2138 start
# Epoch #2138 end
# Epoch #2139 start
# Epoch #2139 end
# Epoch #2140 start
# Epoch #2140 end
# Epoch #2141 start
# Epoch #2141 end
# Epoch #2142 start
# Epoch #2142 end
# Epoch #2143 start
# Epoch #2143 end
# Epoch #2144 start
# Epoch #2144 end
# Epoch #2145 start
# Epoch #2145 end
# Epoch #2146 start
# Epoch #2146 end
# Epoch #2147 start
# Epoch #2147 end
# Epoch #2148 start
# Epoch #2148 end
# Epoch #2149 start
# Epoch #2149 end
# Epoch #2150 start
# Epoch #2150 end
# Epoch #2151 start
# Epoch #2151 end
# Epoch #2152 start
# Epoch #2152 end
# Epoch #2153 start
# Epoch #2153 end
# Epoch #2154 start
# Epoch #2154 end
# Epoch #2155 start
# Epoch #2155 end
# Epoch #2156 start
# Epoch #2156 end
# Epoch #2157 start
# Epoch #2157 end
# Epoch #2158 start
# Epoch #2158 end
# Epoch #2159 start
# Epoch #2159 end
# Epoch #2160 start
# Epoch #2160 end
# Epoch #2161 start
# Epoch #2161 end
# Epoch #2162 start
# Epoch #2162 end
# Epoch #2163 start
# Epoch #2163 end
# Epoch #2164 start
# Epoch #2164 end
# Epoch #2165 start
# Epoch #2165 end
# Epoch #2166 start
# Epoch #2166 end
# Epoch #2167 start
# Epoch #2167 end
# Epoch #2168 start
# Epoch #2168 end
# Epoch #2169 start
# Epoch #2169 end
# Epoch #2170 start
# Epoch #2170 end
# Epoch #2171 start
# Epoch #2171 end
# Epoch #2172 start
# Epoch #2172 end
# Epoch #2173 start
# Epoch #2173 end
# Epoch #2174 start
# Epoch #2174 end
# Epoch #2175 start
# Epoch #2175 end
# Epoch #2176 start
# Epoch #2176 end
# Epoch #2177 start
# Epoch #2177 end
# Epoch #2178 start
# Epoch #2178 end
# Epoch #2179 start
# Epoch #2179 end
# Epoch #2180 start
# Epoch #2180 end
# Epoch #2181 start
# Epoch #2181 end
# Epoch #2182 start
# Epoch #2182 end
# Epoch #2183 start
# Epoch #2183 end
# Epoch #2184 start
# Epoch #2184 end
# Epoch #2185 start
# Epoch #2185 end
# Epoch #2186 start
# Epoch #2186 end
# Epoch #2187 start
# Epoch #2187 end
# Epoch #2188 start
# Epoch #2188 end
# Epoch #2189 start
# Epoch #2189 end
# Epoch #2190 start
# Epoch #2190 end
# Epoch #2191 start
# Epoch #2191 end
# Epoch #2192 start
# Epoch #2192 end
# Epoch #2193 start
# Epoch #2193 end
# Epoch #2194 start
# Epoch #2194 end
# Epoch #2195 start
# Epoch #2195 end
# Epoch #2196 start
# Epoch #2196 end
# Epoch #2197 start
# Epoch #2197 end
# Epoch #2198 start
# Epoch #2198 end
# Epoch #2199 start
# Epoch #2199 end
#
# model 21 trained
# Epoch #2200 start
# Epoch #2200 end
# Epoch #2201 start
# Epoch #2201 end
# Epoch #2202 start
# Epoch #2202 end
# Epoch #2203 start
# Epoch #2203 end
# Epoch #2204 start
# Epoch #2204 end
# Epoch #2205 start
# Epoch #2205 end
# Epoch #2206 start
# Epoch #2206 end
# Epoch #2207 start
# Epoch #2207 end
# Epoch #2208 start
# Epoch #2208 end
# Epoch #2209 start
# Epoch #2209 end
# Epoch #2210 start
# Epoch #2210 end
# Epoch #2211 start
# Epoch #2211 end
# Epoch #2212 start
# Epoch #2212 end
# Epoch #2213 start
# Epoch #2213 end
# Epoch #2214 start
# Epoch #2214 end
# Epoch #2215 start
# Epoch #2215 end
# Epoch #2216 start
# Epoch #2216 end
# Epoch #2217 start
# Epoch #2217 end
# Epoch #2218 start
# Epoch #2218 end
# Epoch #2219 start
# Epoch #2219 end
# Epoch #2220 start
# Epoch #2220 end
# Epoch #2221 start
# Epoch #2221 end
# Epoch #2222 start
# Epoch #2222 end
# Epoch #2223 start
# Epoch #2223 end
# Epoch #2224 start
# Epoch #2224 end
# Epoch #2225 start
# Epoch #2225 end
# Epoch #2226 start
# Epoch #2226 end
# Epoch #2227 start
# Epoch #2227 end
# Epoch #2228 start
# Epoch #2228 end
# Epoch #2229 start
# Epoch #2229 end
# Epoch #2230 start
# Epoch #2230 end
# Epoch #2231 start
# Epoch #2231 end
# Epoch #2232 start
# Epoch #2232 end
# Epoch #2233 start
# Epoch #2233 end
# Epoch #2234 start
# Epoch #2234 end
# Epoch #2235 start
# Epoch #2235 end
# Epoch #2236 start
# Epoch #2236 end
# Epoch #2237 start
# Epoch #2237 end
# Epoch #2238 start
# Epoch #2238 end
# Epoch #2239 start
# Epoch #2239 end
# Epoch #2240 start
# Epoch #2240 end
# Epoch #2241 start
# Epoch #2241 end
# Epoch #2242 start
# Epoch #2242 end
# Epoch #2243 start
# Epoch #2243 end
# Epoch #2244 start
# Epoch #2244 end
# Epoch #2245 start
# Epoch #2245 end
# Epoch #2246 start
# Epoch #2246 end
# Epoch #2247 start
# Epoch #2247 end
# Epoch #2248 start
# Epoch #2248 end
# Epoch #2249 start
# Epoch #2249 end
# Epoch #2250 start
# Epoch #2250 end
# Epoch #2251 start
# Epoch #2251 end
# Epoch #2252 start
# Epoch #2252 end
# Epoch #2253 start
# Epoch #2253 end
# Epoch #2254 start
# Epoch #2254 end
# Epoch #2255 start
# Epoch #2255 end
# Epoch #2256 start
# Epoch #2256 end
# Epoch #2257 start
# Epoch #2257 end
# Epoch #2258 start
# Epoch #2258 end
# Epoch #2259 start
# Epoch #2259 end
# Epoch #2260 start
# Epoch #2260 end
# Epoch #2261 start
# Epoch #2261 end
# Epoch #2262 start
# Epoch #2262 end
# Epoch #2263 start
# Epoch #2263 end
# Epoch #2264 start
# Epoch #2264 end
# Epoch #2265 start
# Epoch #2265 end
# Epoch #2266 start
# Epoch #2266 end
# Epoch #2267 start
# Epoch #2267 end
# Epoch #2268 start
# Epoch #2268 end
# Epoch #2269 start
# Epoch #2269 end
# Epoch #2270 start
# Epoch #2270 end
# Epoch #2271 start
# Epoch #2271 end
# Epoch #2272 start
# Epoch #2272 end
# Epoch #2273 start
# Epoch #2273 end
# Epoch #2274 start
# Epoch #2274 end
# Epoch #2275 start
# Epoch #2275 end
# Epoch #2276 start
# Epoch #2276 end
# Epoch #2277 start
# Epoch #2277 end
# Epoch #2278 start
# Epoch #2278 end
# Epoch #2279 start
# Epoch #2279 end
# Epoch #2280 start
# Epoch #2280 end
# Epoch #2281 start
# Epoch #2281 end
# Epoch #2282 start
# Epoch #2282 end
# Epoch #2283 start
# Epoch #2283 end
# Epoch #2284 start
# Epoch #2284 end
# Epoch #2285 start
# Epoch #2285 end
# Epoch #2286 start
# Epoch #2286 end
# Epoch #2287 start
# Epoch #2287 end
# Epoch #2288 start
# Epoch #2288 end
# Epoch #2289 start
# Epoch #2289 end
# Epoch #2290 start
# Epoch #2290 end
# Epoch #2291 start
# Epoch #2291 end
# Epoch #2292 start
# Epoch #2292 end
# Epoch #2293 start
# Epoch #2293 end
# Epoch #2294 start
# Epoch #2294 end
# Epoch #2295 start
# Epoch #2295 end
# Epoch #2296 start
# Epoch #2296 end
# Epoch #2297 start
# Epoch #2297 end
# Epoch #2298 start
# Epoch #2298 end
# Epoch #2299 start
# Epoch #2299 end
#
# model 22 trained
# Epoch #2300 start
# Epoch #2300 end
# Epoch #2301 start
# Epoch #2301 end
# Epoch #2302 start
# Epoch #2302 end
# Epoch #2303 start
# Epoch #2303 end
# Epoch #2304 start
# Epoch #2304 end
# Epoch #2305 start
# Epoch #2305 end
# Epoch #2306 start
# Epoch #2306 end
# Epoch #2307 start
# Epoch #2307 end
# Epoch #2308 start
# Epoch #2308 end
# Epoch #2309 start
# Epoch #2309 end
# Epoch #2310 start
# Epoch #2310 end
# Epoch #2311 start
# Epoch #2311 end
# Epoch #2312 start
# Epoch #2312 end
# Epoch #2313 start
# Epoch #2313 end
# Epoch #2314 start
# Epoch #2314 end
# Epoch #2315 start
# Epoch #2315 end
# Epoch #2316 start
# Epoch #2316 end
# Epoch #2317 start
# Epoch #2317 end
# Epoch #2318 start
# Epoch #2318 end
# Epoch #2319 start
# Epoch #2319 end
# Epoch #2320 start
# Epoch #2320 end
# Epoch #2321 start
# Epoch #2321 end
# Epoch #2322 start
# Epoch #2322 end
# Epoch #2323 start
# Epoch #2323 end
# Epoch #2324 start
# Epoch #2324 end
# Epoch #2325 start
# Epoch #2325 end
# Epoch #2326 start
# Epoch #2326 end
# Epoch #2327 start
# Epoch #2327 end
# Epoch #2328 start
# Epoch #2328 end
# Epoch #2329 start
# Epoch #2329 end
# Epoch #2330 start
# Epoch #2330 end
# Epoch #2331 start
# Epoch #2331 end
# Epoch #2332 start
# Epoch #2332 end
# Epoch #2333 start
# Epoch #2333 end
# Epoch #2334 start
# Epoch #2334 end
# Epoch #2335 start
# Epoch #2335 end
# Epoch #2336 start
# Epoch #2336 end
# Epoch #2337 start
# Epoch #2337 end
# Epoch #2338 start
# Epoch #2338 end
# Epoch #2339 start
# Epoch #2339 end
# Epoch #2340 start
# Epoch #2340 end
# Epoch #2341 start
# Epoch #2341 end
# Epoch #2342 start
# Epoch #2342 end
# Epoch #2343 start
# Epoch #2343 end
# Epoch #2344 start
# Epoch #2344 end
# Epoch #2345 start
# Epoch #2345 end
# Epoch #2346 start
# Epoch #2346 end
# Epoch #2347 start
# Epoch #2347 end
# Epoch #2348 start
# Epoch #2348 end
# Epoch #2349 start
# Epoch #2349 end
# Epoch #2350 start
# Epoch #2350 end
# Epoch #2351 start
# Epoch #2351 end
# Epoch #2352 start
# Epoch #2352 end
# Epoch #2353 start
# Epoch #2353 end
# Epoch #2354 start
# Epoch #2354 end
# Epoch #2355 start
# Epoch #2355 end
# Epoch #2356 start
# Epoch #2356 end
# Epoch #2357 start
# Epoch #2357 end
# Epoch #2358 start
# Epoch #2358 end
# Epoch #2359 start
# Epoch #2359 end
# Epoch #2360 start
# Epoch #2360 end
# Epoch #2361 start
# Epoch #2361 end
# Epoch #2362 start
# Epoch #2362 end
# Epoch #2363 start
# Epoch #2363 end
# Epoch #2364 start
# Epoch #2364 end
# Epoch #2365 start
# Epoch #2365 end
# Epoch #2366 start
# Epoch #2366 end
# Epoch #2367 start
# Epoch #2367 end
# Epoch #2368 start
# Epoch #2368 end
# Epoch #2369 start
# Epoch #2369 end
# Epoch #2370 start
# Epoch #2370 end
# Epoch #2371 start
# Epoch #2371 end
# Epoch #2372 start
# Epoch #2372 end
# Epoch #2373 start
# Epoch #2373 end
# Epoch #2374 start
# Epoch #2374 end
# Epoch #2375 start
# Epoch #2375 end
# Epoch #2376 start
# Epoch #2376 end
# Epoch #2377 start
# Epoch #2377 end
# Epoch #2378 start
# Epoch #2378 end
# Epoch #2379 start
# Epoch #2379 end
# Epoch #2380 start
# Epoch #2380 end
# Epoch #2381 start
# Epoch #2381 end
# Epoch #2382 start
# Epoch #2382 end
# Epoch #2383 start
# Epoch #2383 end
# Epoch #2384 start
# Epoch #2384 end
# Epoch #2385 start
# Epoch #2385 end
# Epoch #2386 start
# Epoch #2386 end
# Epoch #2387 start
# Epoch #2387 end
# Epoch #2388 start
# Epoch #2388 end
# Epoch #2389 start
# Epoch #2389 end
# Epoch #2390 start
# Epoch #2390 end
# Epoch #2391 start
# Epoch #2391 end
# Epoch #2392 start
# Epoch #2392 end
# Epoch #2393 start
# Epoch #2393 end
# Epoch #2394 start
# Epoch #2394 end
# Epoch #2395 start
# Epoch #2395 end
# Epoch #2396 start
# Epoch #2396 end
# Epoch #2397 start
# Epoch #2397 end
# Epoch #2398 start
# Epoch #2398 end
# Epoch #2399 start
# Epoch #2399 end
#
# model 23 trained

# %%
count = 0
for model in models:
    infer_embedding(model, 'train')
    infer_embedding(model, 'dev')
    print("\nembedding inffered for model %i" %count)
    count += 1
# Out:
# Directory  ../RESULTS/PV-DM-AV/25_5_5_0  Created
#
# saving inferred vectors and labels to file
# Directory  ../RESULTS/PV-DM-AV/25_5_5_0  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 0
# Directory  ../RESULTS/PV-DM-AV/25_5_10_0  Created
#
# saving inferred vectors and labels to file
# Directory  ../RESULTS/PV-DM-AV/25_5_10_0  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 1
# Directory  ../RESULTS/PV-DM-AV/25_5_0_1  Created
#
# saving inferred vectors and labels to file
# Directory  ../RESULTS/PV-DM-AV/25_5_0_1  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 2
# Directory  ../RESULTS/PV-DM-AV/25_10_5_0  Created
#
# saving inferred vectors and labels to file
# Directory  ../RESULTS/PV-DM-AV/25_10_5_0  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 3
# Directory  ../RESULTS/PV-DM-AV/25_10_10_0  Created
#
# saving inferred vectors and labels to file
# Directory  ../RESULTS/PV-DM-AV/25_10_10_0  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 4
# Directory  ../RESULTS/PV-DM-AV/25_10_0_1  Created
#
# saving inferred vectors and labels to file
# Directory  ../RESULTS/PV-DM-AV/25_10_0_1  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 5
# Directory  ../RESULTS/PV-DM-AV/50_5_5_0  Created
#
# saving inferred vectors and labels to file
# Directory  ../RESULTS/PV-DM-AV/50_5_5_0  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 6
# Directory  ../RESULTS/PV-DM-AV/50_5_10_0  Created
#
# saving inferred vectors and labels to file
# Directory  ../RESULTS/PV-DM-AV/50_5_10_0  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 7
# Directory  ../RESULTS/PV-DM-AV/50_5_0_1  Created
#
# saving inferred vectors and labels to file
# Directory  ../RESULTS/PV-DM-AV/50_5_0_1  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 8
# Directory  ../RESULTS/PV-DM-AV/50_10_5_0  Created
#
# saving inferred vectors and labels to file
# Directory  ../RESULTS/PV-DM-AV/50_10_5_0  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 9
# Directory  ../RESULTS/PV-DM-AV/50_10_10_0  Created
#
# saving inferred vectors and labels to file
# Directory  ../RESULTS/PV-DM-AV/50_10_10_0  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 10
# Directory  ../RESULTS/PV-DM-AV/50_10_0_1  Created
#
# saving inferred vectors and labels to file
# Directory  ../RESULTS/PV-DM-AV/50_10_0_1  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 11
# Directory  ../RESULTS/PV-DM-AV/75_5_5_0  Created
#
# saving inferred vectors and labels to file
# Directory  ../RESULTS/PV-DM-AV/75_5_5_0  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 12
# Directory  ../RESULTS/PV-DM-AV/75_5_10_0  Created
#
# saving inferred vectors and labels to file
# Directory  ../RESULTS/PV-DM-AV/75_5_10_0  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 13
# Directory  ../RESULTS/PV-DM-AV/75_5_0_1  Created
#
# saving inferred vectors and labels to file
# Directory  ../RESULTS/PV-DM-AV/75_5_0_1  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 14
# Directory  ../RESULTS/PV-DM-AV/75_10_5_0  Created
#
# saving inferred vectors and labels to file
# Directory  ../RESULTS/PV-DM-AV/75_10_5_0  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 15
# Directory  ../RESULTS/PV-DM-AV/75_10_10_0  Created
#
# saving inferred vectors and labels to file
# Directory  ../RESULTS/PV-DM-AV/75_10_10_0  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 16
# Directory  ../RESULTS/PV-DM-AV/75_10_0_1  Created
#
# saving inferred vectors and labels to file
# Directory  ../RESULTS/PV-DM-AV/75_10_0_1  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 17
# Directory  ../RESULTS/PV-DM-AV/100_5_5_0  Created
#
# saving inferred vectors and labels to file
# Directory  ../RESULTS/PV-DM-AV/100_5_5_0  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 18
# Directory  ../RESULTS/PV-DM-AV/100_5_10_0  Created
#
# saving inferred vectors and labels to file
# Directory  ../RESULTS/PV-DM-AV/100_5_10_0  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 19
# Directory  ../RESULTS/PV-DM-AV/100_5_0_1  Created
#
# saving inferred vectors and labels to file
# Directory  ../RESULTS/PV-DM-AV/100_5_0_1  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 20
# Directory  ../RESULTS/PV-DM-AV/100_10_5_0  Created
#
# saving inferred vectors and labels to file
# Directory  ../RESULTS/PV-DM-AV/100_10_5_0  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 21
# Directory  ../RESULTS/PV-DM-AV/100_10_10_0  Created
#
# saving inferred vectors and labels to file
# Directory  ../RESULTS/PV-DM-AV/100_10_10_0  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 22
# Directory  ../RESULTS/PV-DM-AV/100_10_0_1  Created
#
# saving inferred vectors and labels to file
# Directory  ../RESULTS/PV-DM-AV/100_10_0_1  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 23

# %%
#dm conc
models = [
    doc2vec.Doc2Vec(dm=1, dm_concat=1, vector_size=25, window=5, negative=5, hs=0, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=1, dm_concat=1, vector_size=25, window=5, negative=10, hs=0, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=1, dm_concat=1, vector_size=25, window=5, negative=0, hs=1, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=1, dm_concat=1, vector_size=25, window=10, negative=5, hs=0, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=1, dm_concat=1, vector_size=25, window=10, negative=10, hs=0, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=1, dm_concat=1, vector_size=25, window=10, negative=0, hs=1, min_count=2, epochs=100, workers=cores,sample=0),
    
    doc2vec.Doc2Vec(dm=1, dm_concat=1, vector_size=50, window=5, negative=5, hs=0, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=1, dm_concat=1, vector_size=50, window=5, negative=10, hs=0, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=1, dm_concat=1, vector_size=50, window=5, negative=0, hs=1, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=1, dm_concat=1, vector_size=50, window=10, negative=5, hs=0, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=1, dm_concat=1, vector_size=50, window=10, negative=10, hs=0, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=1, dm_concat=1, vector_size=50, window=10, negative=0, hs=1, min_count=2, epochs=100, workers=cores,sample=0),
    
    doc2vec.Doc2Vec(dm=1, dm_concat=1, vector_size=75, window=5, negative=5, hs=0, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=1, dm_concat=1, vector_size=75, window=5, negative=10, hs=0, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=1, dm_concat=1, vector_size=75, window=5, negative=0, hs=1, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=1, dm_concat=1, vector_size=75, window=10, negative=5, hs=0, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=1, dm_concat=1, vector_size=75, window=10, negative=10, hs=0, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=1, dm_concat=1, vector_size=75, window=10, negative=0, hs=1, min_count=2, epochs=100, workers=cores,sample=0),
    
    doc2vec.Doc2Vec(dm=1, dm_concat=1, vector_size=100, window=5, negative=5, hs=0, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=1, dm_concat=1, vector_size=100, window=5, negative=10, hs=0, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=1, dm_concat=1, vector_size=100, window=5, negative=0, hs=1, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=1, dm_concat=1, vector_size=100, window=10, negative=5, hs=0, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=1, dm_concat=1, vector_size=100, window=10, negative=10, hs=0, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=1, dm_concat=1, vector_size=100, window=10, negative=0, hs=1, min_count=2, epochs=100, workers=cores,sample=0)
]

# %%
count = 0
for model in models:
    print("\nbuilding vocabulary for doc2vec model %i" %count)
    model.build_vocab(all_docs)
    print("\nvocabulary scanned & built.")
    count += 1
# Out:
# building vocabulary for doc2vec model 0
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 1
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 2
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 3
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 4
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 5
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 6
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 7
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 8
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 9
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 10
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 11
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 12
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 13
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 14
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 15
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 16
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 17
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 18
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 19
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 20
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 21
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 22
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 23
#
# vocabulary scanned & built.

# %%
from gensim.models.callbacks import CallbackAny2Vec
class EpochLogger(CallbackAny2Vec):
    '''Callback to log information about training'''
    
    def __init__(self):
        self.epoch = 0
    
    def on_epoch_begin(self, model):
        print("Epoch #{} start".format(self.epoch))
    
    def on_epoch_end(self, model):
        print("Epoch #{} end".format(self.epoch))
        self.epoch += 1
epoch_logger = EpochLogger()
count = 0
for model in models:
    model.train(all_docs, total_examples=len(all_docs), epochs=model.epochs)
    print("\nmodel %i trained" %count)
    count += 1
# Out:
# model 0 trained
#
# model 1 trained
#
# model 2 trained
#
# model 3 trained
#
# model 4 trained
#
# model 5 trained
#
# model 6 trained
#
# model 7 trained
#
# model 8 trained
#
# model 9 trained
#
# model 10 trained
#
# model 11 trained
#
# model 12 trained
#
# model 13 trained
#
# model 14 trained
#
# model 15 trained
#
# model 16 trained
#
# model 17 trained
#
# model 18 trained
#
# model 19 trained
#
# model 20 trained
#
# model 21 trained
#
# model 22 trained
#
# model 23 trained

# %%
count = 0
for model in models:
    infer_embedding(model, 'train')
    infer_embedding(model, 'dev')
    print("\nembedding inffered for model %i" %count)
    count += 1
# Out:
# Directory  ../RESULTS/PV-DM-CONC/25_5_5_0  Created
#
# saving inferred vectors and labels to file
# Directory  ../RESULTS/PV-DM-CONC/25_5_5_0  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 0
# Directory  ../RESULTS/PV-DM-CONC/25_5_10_0  Created
#
# saving inferred vectors and labels to file
# Directory  ../RESULTS/PV-DM-CONC/25_5_10_0  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 1
# Directory  ../RESULTS/PV-DM-CONC/25_5_0_1  Created
#
# saving inferred vectors and labels to file
# Directory  ../RESULTS/PV-DM-CONC/25_5_0_1  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 2
# Directory  ../RESULTS/PV-DM-CONC/25_10_5_0  Created
#
# saving inferred vectors and labels to file
# Directory  ../RESULTS/PV-DM-CONC/25_10_5_0  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 3
# Directory  ../RESULTS/PV-DM-CONC/25_10_10_0  Created
#
# saving inferred vectors and labels to file
# Directory  ../RESULTS/PV-DM-CONC/25_10_10_0  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 4
# Directory  ../RESULTS/PV-DM-CONC/25_10_0_1  Created
#
# saving inferred vectors and labels to file
# Directory  ../RESULTS/PV-DM-CONC/25_10_0_1  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 5
# Directory  ../RESULTS/PV-DM-CONC/50_5_5_0  Created
#
# saving inferred vectors and labels to file
# Directory  ../RESULTS/PV-DM-CONC/50_5_5_0  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 6
# Directory  ../RESULTS/PV-DM-CONC/50_5_10_0  Created
#
# saving inferred vectors and labels to file
# Directory  ../RESULTS/PV-DM-CONC/50_5_10_0  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 7
# Directory  ../RESULTS/PV-DM-CONC/50_5_0_1  Created
#
# saving inferred vectors and labels to file
# Directory  ../RESULTS/PV-DM-CONC/50_5_0_1  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 8
# Directory  ../RESULTS/PV-DM-CONC/50_10_5_0  Created
#
# saving inferred vectors and labels to file
# Directory  ../RESULTS/PV-DM-CONC/50_10_5_0  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 9
# Directory  ../RESULTS/PV-DM-CONC/50_10_10_0  Created
#
# saving inferred vectors and labels to file
# Directory  ../RESULTS/PV-DM-CONC/50_10_10_0  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 10
# Directory  ../RESULTS/PV-DM-CONC/50_10_0_1  Created
#
# saving inferred vectors and labels to file
# Directory  ../RESULTS/PV-DM-CONC/50_10_0_1  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 11
# Directory  ../RESULTS/PV-DM-CONC/75_5_5_0  Created
#
# saving inferred vectors and labels to file
# Directory  ../RESULTS/PV-DM-CONC/75_5_5_0  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 12
# Directory  ../RESULTS/PV-DM-CONC/75_5_10_0  Created
#
# saving inferred vectors and labels to file
# Directory  ../RESULTS/PV-DM-CONC/75_5_10_0  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 13
# Directory  ../RESULTS/PV-DM-CONC/75_5_0_1  Created
#
# saving inferred vectors and labels to file
# Directory  ../RESULTS/PV-DM-CONC/75_5_0_1  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 14
# Directory  ../RESULTS/PV-DM-CONC/75_10_5_0  Created
#
# saving inferred vectors and labels to file
# Directory  ../RESULTS/PV-DM-CONC/75_10_5_0  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 15
# Directory  ../RESULTS/PV-DM-CONC/75_10_10_0  Created
#
# saving inferred vectors and labels to file
# Directory  ../RESULTS/PV-DM-CONC/75_10_10_0  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 16
# Directory  ../RESULTS/PV-DM-CONC/75_10_0_1  Created
#
# saving inferred vectors and labels to file
# Directory  ../RESULTS/PV-DM-CONC/75_10_0_1  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 17
# Directory  ../RESULTS/PV-DM-CONC/100_5_5_0  Created
#
# saving inferred vectors and labels to file
# Directory  ../RESULTS/PV-DM-CONC/100_5_5_0  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 18
# Directory  ../RESULTS/PV-DM-CONC/100_5_10_0  Created
#
# saving inferred vectors and labels to file
# Directory  ../RESULTS/PV-DM-CONC/100_5_10_0  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 19
# Directory  ../RESULTS/PV-DM-CONC/100_5_0_1  Created
#
# saving inferred vectors and labels to file
# Directory  ../RESULTS/PV-DM-CONC/100_5_0_1  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 20
# Directory  ../RESULTS/PV-DM-CONC/100_10_5_0  Created
#
# saving inferred vectors and labels to file
# Directory  ../RESULTS/PV-DM-CONC/100_10_5_0  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 21
# Directory  ../RESULTS/PV-DM-CONC/100_10_10_0  Created
#
# saving inferred vectors and labels to file
# Directory  ../RESULTS/PV-DM-CONC/100_10_10_0  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 22
# Directory  ../RESULTS/PV-DM-CONC/100_10_0_1  Created
#
# saving inferred vectors and labels to file
# Directory  ../RESULTS/PV-DM-CONC/100_10_0_1  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 23

# %%
#dbow 
models = [
    doc2vec.Doc2Vec(dm=0, vector_size=25, negative=5, hs=0, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=0, vector_size=25, negative=10, hs=0, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=0, vector_size=25, negative=0, hs=1, min_count=2, epochs=100, workers=cores,sample=0),
    
    doc2vec.Doc2Vec(dm=0, vector_size=50, negative=5, hs=0, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=0, vector_size=50, negative=10, hs=0, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=0, vector_size=50, negative=0, hs=1, min_count=2, epochs=100, workers=cores,sample=0),
    
    doc2vec.Doc2Vec(dm=0, vector_size=75, negative=5, hs=0, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=0, vector_size=75, negative=10, hs=0, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=0, vector_size=75, negative=0, hs=1, min_count=2, epochs=100, workers=cores,sample=0),
    
    doc2vec.Doc2Vec(dm=0, vector_size=100, negative=5, hs=0, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=0, vector_size=100, negative=10, hs=0, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=0, vector_size=100, negative=0, hs=1, min_count=2, epochs=100, workers=cores,sample=0),
    
]

# %%
count = 0
for model in models:
    print("\nbuilding vocabulary for doc2vec model %i" %count)
    model.build_vocab(all_docs)
    print("\nvocabulary scanned & built.")
    count += 1
# Out:
# building vocabulary for doc2vec model 0
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 1
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 2
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 3
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 4
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 5
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 6
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 7
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 8
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 9
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 10
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 11
#
# vocabulary scanned & built.

# %%
from gensim.models.callbacks import CallbackAny2Vec
class EpochLogger(CallbackAny2Vec):
    '''Callback to log information about training'''
    
    def __init__(self):
        self.epoch = 0
    
    def on_epoch_begin(self, model):
        print("Epoch #{} start".format(self.epoch))
    
    def on_epoch_end(self, model):
        print("Epoch #{} end".format(self.epoch))
        self.epoch += 1
epoch_logger = EpochLogger()
count = 0
for model in models:
    model.train(all_docs, total_examples=len(all_docs), epochs=model.epochs)
    print("\nmodel %i trained" %count)
    count += 1
# Out:
# model 0 trained
#
# model 1 trained
#
# model 2 trained
#
# model 3 trained
#
# model 4 trained
#
# model 5 trained
#
# model 6 trained
#
# model 7 trained
#
# model 8 trained
#
# model 9 trained
#
# model 10 trained
#
# model 11 trained

# %%
count = 0
for model in models:
    infer_embedding(model, 'train')
    infer_embedding(model, 'dev')
    print("\nembedding inffered for model %i" %count)
    count += 1
# Out:
# Directory  ../RESULTS/PV-DBOW/25_5_5_0  Created
#
# saving inferred vectors and labels to file
# Directory  ../RESULTS/PV-DBOW/25_5_5_0  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 0
# Directory  ../RESULTS/PV-DBOW/25_5_10_0  Created
#
# saving inferred vectors and labels to file
# Directory  ../RESULTS/PV-DBOW/25_5_10_0  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 1
# Directory  ../RESULTS/PV-DBOW/25_5_0_1  Created
#
# saving inferred vectors and labels to file
# Directory  ../RESULTS/PV-DBOW/25_5_0_1  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 2
# Directory  ../RESULTS/PV-DBOW/50_5_5_0  Created
#
# saving inferred vectors and labels to file
# Directory  ../RESULTS/PV-DBOW/50_5_5_0  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 3
# Directory  ../RESULTS/PV-DBOW/50_5_10_0  Created
#
# saving inferred vectors and labels to file
# Directory  ../RESULTS/PV-DBOW/50_5_10_0  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 4
# Directory  ../RESULTS/PV-DBOW/50_5_0_1  Created
#
# saving inferred vectors and labels to file
# Directory  ../RESULTS/PV-DBOW/50_5_0_1  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 5
# Directory  ../RESULTS/PV-DBOW/75_5_5_0  Created
#
# saving inferred vectors and labels to file
# Directory  ../RESULTS/PV-DBOW/75_5_5_0  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 6
# Directory  ../RESULTS/PV-DBOW/75_5_10_0  Created
#
# saving inferred vectors and labels to file
# Directory  ../RESULTS/PV-DBOW/75_5_10_0  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 7
# Directory  ../RESULTS/PV-DBOW/75_5_0_1  Created
#
# saving inferred vectors and labels to file
# Directory  ../RESULTS/PV-DBOW/75_5_0_1  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 8
# Directory  ../RESULTS/PV-DBOW/100_5_5_0  Created
#
# saving inferred vectors and labels to file
# Directory  ../RESULTS/PV-DBOW/100_5_5_0  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 9
# Directory  ../RESULTS/PV-DBOW/100_5_10_0  Created
#
# saving inferred vectors and labels to file
# Directory  ../RESULTS/PV-DBOW/100_5_10_0  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 10
# Directory  ../RESULTS/PV-DBOW/100_5_0_1  Created
#
# saving inferred vectors and labels to file
# Directory  ../RESULTS/PV-DBOW/100_5_0_1  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 11

# %%
import itertools as it
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import precision_recall_fscore_support


class RandomForest():
   
    def __init__(self, feature_name, X_train, y_train, X_dev, y_dev, line):
        self.config = json.load(open('../model.json', 'r'))
        self.model_name = 'RF'
        self.feature_name = feature_name
        self.X_train = X_train
        self.X_dev = X_dev
        self.y_train = y_train
        self.y_dev = y_dev
        self.parameters = dict()
        self.parameters['n_estimators'] = None
        self.parameters['max_features'] = None
        self.parameters['max_depth'] = None
        self.parameters['criterion'] = None
        self.model = None
        self.line = line

    def run(self):
        """main function for the model"""
        filename = os.path.join(self.line, '%s_%s_params.json' % (self.model_name, self.feature_name))

        if os.path.isfile(filename):
            self.parameters = json.load(open(filename, 'r'))
        
        if not self.parameters['n_estimators'] or not self.parameters['max_features'] or not self.parameters['max_depth'] or not self.parameters['criterion']:
            print("\nhyperparameters are not tuned yet")
            self.tune_dev()
        
        # build RF model
        self.model = RandomForestClassifier(
            n_estimators=self.parameters['n_estimators'], 
            max_features=self.parameters['max_features'], 
            max_depth=self.parameters['max_depth'], 
            criterion=self.parameters['criterion'], 
            verbose=1, n_jobs=-1,
            class_weight="balanced")
        self.train()

    def train(self):
        """train the model
        """
        print("\ntraining a Random Forest Classifier ...")
        self.model.fit(self.X_train, self.y_train)

    def evaluate(self):
        """evaluate the model
        """
        print("\nevaluating the Random Forest Classifier ...")
        y_pred_train = self.model.predict(self.X_train)
        y_pred_dev = self.model.predict(self.X_dev)
        
        precision, recall, fscore, _ = precision_recall_fscore_support(self.y_dev, y_pred_dev, average='macro')
        
        filename = os.path.join(self.line, '%s_%s_score.json' % (self.model_name, self.feature_name))
        file = open(filename,"w") 
        file.write("\nprecision on dev set: %.4f" % precision) 
        file.write("\nrecall on dev set: %.4f" % recall) 
        file.write("\nfscore on dev set: %.4f" % fscore) 
        file.write("\naccuracy on dev set: %.4f" % metrics.accuracy_score(y_pred_dev, y_dev)) 
        file.close() 

        print("\naccuracy on training set: %.4f" % metrics.accuracy_score(y_pred_train, self.y_train))
        print("\naccuracy on development set: %.4f" % metrics.accuracy_score(y_pred_dev, self.y_dev))
        print("\nprecision on dev set: %.4f" % precision)
        print("\nrecall on dev set: %.4f" % recall)
        print("\nfscore on dev set: %.4f" % fscore)

        
        return y_pred_train, y_pred_dev

    def tune_dev(self):
        """fine tune hyperparameters for the model with given dev set
        """
        parameters = {
            "n_estimators": self.config['baseline']['random_forest']['n_estimators'],
            "max_features": self.config['baseline']['random_forest']['max_features'],
            "max_depth": self.config['baseline']['random_forest']['max_depth'],
            "criterion": ["entropy"]
        }
        print("\nrunning the validation on development set ...")
        allnames = sorted(parameters)
        parameters_set = list(it.product(*(parameters[name] for name in allnames)))
        results = np.zeros((len(parameters_set), 5))

        for i in range(len(parameters_set)):
            para = parameters_set[i]
            clf = RandomForestClassifier(
                    n_estimators=para[3],
                    max_features=para[2], 
                    max_depth=para[1], 
                    criterion=para[0], 
                    verbose=1, n_jobs=-1,
                    class_weight="balanced")
            
            for j in range(5):
                clf.fit(self.X_train, self.y_train)
                y_pred_dev = clf.predict(self.X_dev)
                recall = metrics.recall_score(self.y_dev, y_pred_dev, average='macro')
                print("\nrecall for this hyparameter setting is %.3f\n" % recall)
                results[i,j] = recall
        
        results_avg = [np.mean(res) for res in results]
        parameters_id = np.argmax(results_avg)

        self.parameters['n_estimators'] = parameters_set[parameters_id][3]
        self.parameters['max_features'] = parameters_set[parameters_id][2]
        self.parameters['max_depth'] = parameters_set[parameters_id][1]
        self.parameters['criterion'] = parameters_set[parameters_id][0]

        filename = os.path.join(self.line, '%s_%s_params.json' % (self.model_name, self.feature_name))
        
        # write to model json file
        with open(filename, 'w') as output:
            json.dump(self.parameters, output)
            output.write("\n")
        output.close()

# %%
import itertools as it
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import precision_recall_fscore_support

class RandomForestCV():
   
    def __init__(self, feature_name, X_train, y_train, X_dev, y_dev, line):
        self.config = json.load(open('../model.json', 'r'))
        self.model_name = 'RF_CV'
        self.feature_name = feature_name
        self.X_train = X_train
        self.X_dev = X_dev
        self.y_train = y_train
        self.y_dev = y_dev
        self.parameters = dict()
        self.parameters['n_estimators'] = None
        self.parameters['max_features'] = None
        self.parameters['max_depth'] = None
        self.parameters['criterion'] = None
        self.model = None
        self.line = line

    def run(self):
        """main function for the model"""
        filename = os.path.join(self.line, '%s_%s_params.json' % (self.model_name, self.feature_name))

        if os.path.isfile(filename):
            self.parameters = json.load(open(filename, 'r'))
        
        if not self.parameters['n_estimators'] or not self.parameters['max_features'] or not self.parameters['max_depth'] or not self.parameters['criterion']:
            print("\nhyperparameters are not tuned yet")
            self.crossvalidate()
        else:
            self.model = RandomForestClassifier(
                n_estimators=self.parameters['n_estimators'], 
                max_features=self.parameters['max_features'], 
                max_depth=self.parameters['max_depth'], 
                criterion=self.parameters['criterion'], 
                verbose=1, n_jobs=-1,
                class_weight="balanced")
            self.model.fit(self.X_train, self.y_train)
            y_pred_train = self.model.predict(self.X_train)
            y_pred_dev = self.model.predict(self.X_dev)
            precision, recall, fscore, _ = precision_recall_fscore_support(self.y_dev, y_pred_dev, average='macro')
            print("\naccuracy on training set: %.4f" % metrics.accuracy_score(y_pred_train, self.y_train))
            print("\naccuracy on development set: %.4f" % metrics.accuracy_score(y_pred_dev, self.y_dev))
            print("\nprecision on dev set: %.4f" % precision)
            print("\nrecall on dev set: %.4f" % recall)
            print("\nfscore on dev set: %.4f" % fscore)
        
            
    def crossvalidate(self):
        
        parameters = {
            "n_estimators": self.config['baseline']['random_forest']['n_estimators'],
            "max_features": self.config['baseline']['random_forest']['max_features'],
            "max_depth": self.config['baseline']['random_forest']['max_depth'],
            "criterion": ["entropy"]
        }
        
        print("\nrunning the Grid Search for Random Forest CV classifier ...")
        clf = GridSearchCV(RandomForestClassifier(), 
                        parameters, 
                        cv=5, 
                        n_jobs=-1, 
                        verbose=0, 
                        scoring='recall_macro')
        
        clf.fit(self.X_train, self.y_train)
        print("\nfinal score for the tuned model\n", clf.score(self.X_dev, self.y_dev))
        print("\nbest hyperparameters for the tuned model\n", clf.best_params_)
        print("\ncross validation results (MEAN)\n", clf.cv_results_['mean_test_score'])
        print("\ncross validation results (STD)\n", clf.cv_results_['std_test_score'])

        self.parameters['n_estimators'] = clf.best_params_['n_estimators']
        self.parameters['max_features'] = clf.best_params_['max_features']
        self.parameters['max_depth'] = clf.best_params_['max_depth']
        self.parameters['criterion'] = clf.best_params_['criterion']
        
        filename = os.path.join(self.line, '%s_%s_params.json' % (self.model_name, self.feature_name))
        
        # write to model json file
        with open(filename, 'w') as output:
            json.dump(self.parameters, output)
            output.write("\n")
        output.close()
        
        best_grid = clf.best_estimator_
        print("\nevaluating the Random Forest Classifier ...")
        y_pred_train = best_grid.predict(self.X_train)
        y_pred_dev = best_grid.predict(self.X_dev)
        
        precision, recall, fscore, _ = precision_recall_fscore_support(self.y_dev, y_pred_dev, average='macro')
        
        filename = os.path.join(self.line, '%s_%s_score.json' % (self.model_name, self.feature_name))
        file = open(filename,"w") 
        file.write("\nprecision on dev set: %.4f" % precision) 
        file.write("\nrecall on dev set: %.4f" % recall) 
        file.write("\nfscore on dev set: %.4f" % fscore) 
        file.write("\naccuracy on dev set: %.4f" % metrics.accuracy_score(y_pred_dev, y_dev)) 
        file.close() 

        print("\naccuracy on training set: %.4f" % metrics.accuracy_score(y_pred_train, self.y_train))
        print("\naccuracy on development set: %.4f" % metrics.accuracy_score(y_pred_dev, self.y_dev))
        print("\nprecision on dev set: %.4f" % precision)
        print("\nrecall on dev set: %.4f" % recall)
        print("\nfscore on dev set: %.4f" % fscore)

# %%
line = '../RESULTS/PV-DM-AV/' 
names = ['25_5_5_0', '25_5_10_0','25_5_0_1','25_10_5_0','25_10_10_0','25_10_0_1',
         '50_5_5_0', '50_5_10_0','50_5_0_1','50_10_5_0','50_10_10_0','50_10_0_1',
         '75_5_5_0', '75_5_10_0','75_5_0_1','75_10_5_0','75_10_10_0','75_10_0_1',
         '100_5_5_0', '100_5_10_0','100_5_0_1','100_10_5_0','100_10_10_0','100_10_0_1']

# %%
for i in names:
    path = os.path.join(line, i)
    X_train = np.load(os.path.join(path, 'vectors_train.npy'))
    X_dev = np.load(os.path.join(path, 'vectors_dev.npy'))
    y_train = np.load(os.path.join(path, 'labels_train.npy'))
    y_dev = np.load(os.path.join(path, 'labels_dev.npy'))
    y_train = np.ravel(y_train)
    y_dev = np.ravel(y_dev)
    
    feature_name = 'TEXT_'+str(i)
    save_dir = '../RESULTS/PV-DM-AV/' 
    random_forest = RandomForestCV(feature_name, X_train, y_train, X_dev, y_dev, save_dir)
    random_forest.run()
    print ("------"  * 10)
# Out:
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [CV] criterion=entropy, max_depth=2, max_features=0.1, n_estimators=100
# [CV] criterion=entropy, max_depth=2, max_features=0.1, n_estimators=100
# [CV] criterion=entropy, max_depth=2, max_features=0.1, n_estimators=100
# [CV] criterion=entropy, max_depth=2, max_features=0.1, n_estimators=100
# [CV] criterion=entropy, max_depth=2, max_features=0.1, n_estimators=100
# [CV] criterion=entropy, max_depth=2, max_features=0.1, n_estimators=200
# [CV] criterion=entropy, max_depth=2, max_features=0.1, n_estimators=200
# [CV] criterion=entropy, max_depth=2, max_features=0.1, n_estimators=200
# [CV] criterion=entropy, max_depth=2, max_features=0.1, n_estimators=200
# [CV] criterion=entropy, max_depth=2, max_features=0.1, n_estimators=200
# [CV] criterion=entropy, max_depth=2, max_features=0.1, n_estimators=400
# [CV] criterion=entropy, max_depth=2, max_features=0.1, n_estimators=400
# [CV] criterion=entropy, max_depth=2, max_features=0.1, n_estimators=400
# [CV] criterion=entropy, max_depth=2, max_features=0.1, n_estimators=400
# [CV] criterion=entropy, max_depth=2, max_features=0.1, n_estimators=400
# [CV] criterion=entropy, max_depth=2, max_features=0.1, n_estimators=800
# [CV] criterion=entropy, max_depth=2, max_features=0.1, n_estimators=800
# [CV] criterion=entropy, max_depth=2, max_features=0.1, n_estimators=800
# [CV] criterion=entropy, max_depth=2, max_features=0.1, n_estimators=800
# [CV] criterion=entropy, max_depth=2, max_features=0.1, n_estimators=800
# [CV] criterion=entropy, max_depth=2, max_features=0.2, n_estimators=100
# [CV] criterion=entropy, max_depth=2, max_features=0.2, n_estimators=100
# [CV] criterion=entropy, max_depth=2, max_features=0.2, n_estimators=100
# [CV] criterion=entropy, max_depth=2, max_features=0.2, n_estimators=100
# [CV] criterion=entropy, max_depth=2, max_features=0.2, n_estimators=100
# [CV] criterion=entropy, max_depth=2, max_features=0.2, n_estimators=200
# [CV] criterion=entropy, max_depth=2, max_features=0.2, n_estimators=200
# [CV] criterion=entropy, max_depth=2, max_features=0.2, n_estimators=200
# [CV] criterion=entropy, max_depth=2, max_features=0.2, n_estimators=200
# [CV] criterion=entropy, max_depth=2, max_features=0.2, n_estimators=400
# [CV] criterion=entropy, max_depth=2, max_features=0.2, n_estimators=400
# [CV] criterion=entropy, max_depth=2, max_features=0.2, n_estimators=200
# [CV]  criterion=entropy, max_depth=2, max_features=0.1, n_estimators=100, score=0.38888888888888884, total=   0.4s
# [CV] criterion=entropy, max_depth=2, max_features=0.2, n_estimators=400
# [CV]  criterion=entropy, max_depth=2, max_features=0.1, n_estimators=100, score=0.44047619047619047, total=   0.4s
# [CV] criterion=entropy, max_depth=2, max_features=0.2, n_estimators=400
# [CV]  criterion=entropy, max_depth=2, max_features=0.1, n_estimators=100, score=0.5, total=   0.4s
# [CV]  criterion=entropy, max_depth=2, max_features=0.1, n_estimators=100, score=0.5357142857142857, total=   0.4s
# [CV] criterion=entropy, max_depth=2, max_features=0.2, n_estimators=400
# [CV]  criterion=entropy, max_depth=2, max_features=0.1, n_estimators=100, score=0.4583333333333333, total=   0.4s
# [CV] criterion=entropy, max_depth=2, max_features=0.2, n_estimators=800
# [CV]  criterion=entropy, max_depth=2, max_features=0.2, n_estimators=100, score=0.3148148148148148, total=   0.4s
# [CV] criterion=entropy, max_depth=2, max_features=0.2, n_estimators=800
# [CV]  criterion=entropy, max_depth=2, max_features=0.2, n_estimators=100, score=0.4166666666666667, total=   0.4s
# [CV]  criterion=entropy, max_depth=2, max_features=0.2, n_estimators=100, score=0.5773809523809524, total=   0.4s
# [CV]  criterion=entropy, max_depth=2, max_features=0.2, n_estimators=100, score=0.4583333333333333, total=   0.4s
# [CV] criterion=entropy, max_depth=2, max_features=0.2, n_estimators=800
# [CV] criterion=entropy, max_depth=2, max_features=0.2, n_estimators=800
# [CV] criterion=entropy, max_depth=2, max_features=0.2, n_estimators=800
# [CV] criterion=entropy, max_depth=2, max_features=0.4, n_estimators=100
# [CV]  criterion=entropy, max_depth=2, max_features=0.2, n_estimators=100, score=0.44047619047619047, total=   0.4s
# [CV] criterion=entropy, max_depth=2, max_features=0.4, n_estimators=100
# [CV]  criterion=entropy, max_depth=2, max_features=0.1, n_estimators=200, score=0.5, total=   0.8s
# [CV]  criterion=entropy, max_depth=2, max_features=0.1, n_estimators=200, score=0.5357142857142857, total=   0.8s
# [CV]  criterion=entropy, max_depth=2, max_features=0.1, n_estimators=200, score=0.5714285714285715, total=   0.8s
# [CV] criterion=entropy, max_depth=2, max_features=0.4, n_estimators=100
# [CV] criterion=entropy, max_depth=2, max_features=0.4, n_estimators=100
# [CV]  criterion=entropy, max_depth=2, max_features=0.1, n_estimators=200, score=0.4583333333333333, total=   0.8s
# [CV] criterion=entropy, max_depth=2, max_features=0.4, n_estimators=100
# [CV]  criterion=entropy, max_depth=2, max_features=0.1, n_estimators=200, score=0.38425925925925924, total=   0.8s
# [CV] criterion=entropy, max_depth=2, max_features=0.4, n_estimators=200
# [CV] criterion=entropy, max_depth=2, max_features=0.4, n_estimators=200
# [CV]  criterion=entropy, max_depth=2, max_features=0.2, n_estimators=200, score=0.38888888888888884, total=   0.8s
# [CV] criterion=entropy, max_depth=2, max_features=0.4, n_estimators=200
# [CV]  criterion=entropy, max_depth=2, max_features=0.2, n_estimators=200, score=0.4583333333333333, total=   0.8s
# [CV]  criterion=entropy, max_depth=2, max_features=0.2, n_estimators=200, score=0.5773809523809524, total=   0.8s
# [CV] criterion=entropy, max_depth=2, max_features=0.4, n_estimators=200
# [CV]  criterion=entropy, max_depth=2, max_features=0.2, n_estimators=200, score=0.44047619047619047, total=   0.8s
# [CV] criterion=entropy, max_depth=2, max_features=0.4, n_estimators=200
# [CV] criterion=entropy, max_depth=2, max_features=0.4, n_estimators=400
# [CV]  criterion=entropy, max_depth=2, max_features=0.2, n_estimators=200, score=0.375, total=   0.9s
# [CV]  criterion=entropy, max_depth=2, max_features=0.4, n_estimators=100, score=0.38888888888888884, total=   0.4s
# [CV] criterion=entropy, max_depth=2, max_features=0.4, n_estimators=400
# [CV] criterion=entropy, max_depth=2, max_features=0.4, n_estimators=400
# [CV]  criterion=entropy, max_depth=2, max_features=0.4, n_estimators=100, score=0.3333333333333333, total=   0.4s
# [CV] criterion=entropy, max_depth=2, max_features=0.4, n_estimators=400
# [CV]  criterion=entropy, max_depth=2, max_features=0.4, n_estimators=100, score=0.44642857142857145, total=   0.4s
# [CV] criterion=entropy, max_depth=2, max_features=0.4, n_estimators=400
# [CV]  criterion=entropy, max_depth=2, max_features=0.4, n_estimators=100, score=0.4583333333333333, total=   0.5s
# [CV] criterion=entropy, max_depth=2, max_features=0.4, n_estimators=800
# [CV]  criterion=entropy, max_depth=2, max_features=0.4, n_estimators=100, score=0.44047619047619047, total=   0.5s
# [CV] criterion=entropy, max_depth=2, max_features=0.4, n_estimators=800
# [CV]  criterion=entropy, max_depth=2, max_features=0.1, n_estimators=400, score=0.5, total=   1.6s
# [CV] criterion=entropy, max_depth=2, max_features=0.4, n_estimators=800
# [CV]  criterion=entropy, max_depth=2, max_features=0.1, n_estimators=400, score=0.5297619047619048, total=   1.6s
# [CV]  criterion=entropy, max_depth=2, max_features=0.1, n_estimators=400, score=0.5416666666666666, total=   1.6s
# [CV] criterion=entropy, max_depth=2, max_features=0.4, n_estimators=800
# [CV] criterion=entropy, max_depth=2, max_features=0.4, n_estimators=800
# [CV]  criterion=entropy, max_depth=2, max_features=0.1, n_estimators=400, score=0.5773809523809524, total=   1.6s
# [CV] criterion=entropy, max_depth=4, max_features=0.1, n_estimators=100
# [CV]  criterion=entropy, max_depth=2, max_features=0.1, n_estimators=400, score=0.38425925925925924, total=   1.6s
# [CV] criterion=entropy, max_depth=4, max_features=0.1, n_estimators=100
# [CV]  criterion=entropy, max_depth=2, max_features=0.2, n_estimators=400, score=0.38888888888888884, total=   1.7s
# [CV]  criterion=entropy, max_depth=2, max_features=0.4, n_estimators=200, score=0.5, total=   0.9s
# [CV] criterion=entropy, max_depth=4, max_features=0.1, n_estimators=100
# [CV] criterion=entropy, max_depth=4, max_features=0.1, n_estimators=100
# [CV]  criterion=entropy, max_depth=2, max_features=0.4, n_estimators=200, score=0.375, total=   0.9s
# [CV] criterion=entropy, max_depth=4, max_features=0.1, n_estimators=100
# [CV]  criterion=entropy, max_depth=2, max_features=0.4, n_estimators=200, score=0.5357142857142857, total=   0.9s
# [CV]  criterion=entropy, max_depth=2, max_features=0.2, n_estimators=400, score=0.4166666666666667, total=   1.7s
# [CV] criterion=entropy, max_depth=4, max_features=0.1, n_estimators=200
# [CV] criterion=entropy, max_depth=4, max_features=0.1, n_estimators=200
# [CV]  criterion=entropy, max_depth=2, max_features=0.4, n_estimators=200, score=0.4259259259259259, total=   0.9s
# [CV] criterion=entropy, max_depth=4, max_features=0.1, n_estimators=200
# [CV]  criterion=entropy, max_depth=2, max_features=0.4, n_estimators=200, score=0.44047619047619047, total=   0.9s
# [CV] criterion=entropy, max_depth=4, max_features=0.1, n_estimators=200
# [CV]  criterion=entropy, max_depth=2, max_features=0.2, n_estimators=400, score=0.4583333333333333, total=   1.7s
# [CV] criterion=entropy, max_depth=4, max_features=0.1, n_estimators=200
# [CV]  criterion=entropy, max_depth=2, max_features=0.2, n_estimators=400, score=0.44047619047619047, total=   1.7s
# [CV] criterion=entropy, max_depth=4, max_features=0.1, n_estimators=400
# [CV]  criterion=entropy, max_depth=4, max_features=0.1, n_estimators=100, score=0.5297619047619048, total=   0.4s
# [CV] criterion=entropy, max_depth=4, max_features=0.1, n_estimators=400
# [CV]  criterion=entropy, max_depth=2, max_features=0.2, n_estimators=400, score=0.5357142857142857, total=   1.8s
# [CV]  criterion=entropy, max_depth=4, max_features=0.1, n_estimators=100, score=0.4231481481481481, total=   0.5s
# [CV] criterion=entropy, max_depth=4, max_features=0.1, n_estimators=400
# [CV] criterion=entropy, max_depth=4, max_features=0.1, n_estimators=400
# [CV]  criterion=entropy, max_depth=4, max_features=0.1, n_estimators=100, score=0.4166666666666667, total=   0.5s
# [CV]  criterion=entropy, max_depth=4, max_features=0.1, n_estimators=100, score=0.39999999999999997, total=   0.4s
# [CV] criterion=entropy, max_depth=4, max_features=0.1, n_estimators=400
# [CV] criterion=entropy, max_depth=4, max_features=0.1, n_estimators=800
# [CV]  criterion=entropy, max_depth=4, max_features=0.1, n_estimators=100, score=0.3511904761904762, total=   0.5s
# [CV] criterion=entropy, max_depth=4, max_features=0.1, n_estimators=800
# [CV]  criterion=entropy, max_depth=4, max_features=0.1, n_estimators=200, score=0.3148148148148148, total=   0.8s
# [CV] criterion=entropy, max_depth=4, max_features=0.1, n_estimators=800
# [CV]  criterion=entropy, max_depth=4, max_features=0.1, n_estimators=200, score=0.375, total=   0.9s
# [CV] criterion=entropy, max_depth=4, max_features=0.1, n_estimators=800
# [CV]  criterion=entropy, max_depth=4, max_features=0.1, n_estimators=200, score=0.375, total=   0.9s
# [CV] criterion=entropy, max_depth=4, max_features=0.1, n_estimators=800
# [CV]  criterion=entropy, max_depth=4, max_features=0.1, n_estimators=200, score=0.5773809523809524, total=   0.8s
# [CV] criterion=entropy, max_depth=4, max_features=0.2, n_estimators=100
# [CV]  criterion=entropy, max_depth=2, max_features=0.4, n_estimators=400, score=0.4259259259259259, total=   1.8s
# [CV] criterion=entropy, max_depth=4, max_features=0.2, n_estimators=100
# [CV]  criterion=entropy, max_depth=2, max_features=0.4, n_estimators=400, score=0.4166666666666667, total=   1.8s
# [CV]  criterion=entropy, max_depth=2, max_features=0.4, n_estimators=400, score=0.5, total=   1.8s
# [CV] criterion=entropy, max_depth=4, max_features=0.2, n_estimators=100
# [CV] criterion=entropy, max_depth=4, max_features=0.2, n_estimators=100
# [CV]  criterion=entropy, max_depth=2, max_features=0.4, n_estimators=400, score=0.49404761904761907, total=   1.8s
# [CV] criterion=entropy, max_depth=4, max_features=0.2, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=0.1, n_estimators=200, score=0.48214285714285715, total=   0.8s
# [CV] criterion=entropy, max_depth=4, max_features=0.2, n_estimators=200
# [CV]  criterion=entropy, max_depth=2, max_features=0.4, n_estimators=400, score=0.44047619047619047, total=   1.8s
# [CV] criterion=entropy, max_depth=4, max_features=0.2, n_estimators=200
# [CV]  criterion=entropy, max_depth=4, max_features=0.2, n_estimators=100, score=0.6009259259259259, total=   0.4s
# [CV] criterion=entropy, max_depth=4, max_features=0.2, n_estimators=200
# [CV]  criterion=entropy, max_depth=4, max_features=0.2, n_estimators=100, score=0.48333333333333334, total=   0.4s
# [CV] criterion=entropy, max_depth=4, max_features=0.2, n_estimators=200
# [CV]  criterion=entropy, max_depth=4, max_features=0.2, n_estimators=100, score=0.5773809523809524, total=   0.4s
# [CV] criterion=entropy, max_depth=4, max_features=0.2, n_estimators=200
# [CV]  criterion=entropy, max_depth=4, max_features=0.2, n_estimators=100, score=0.375, total=   0.5s
# [CV] criterion=entropy, max_depth=4, max_features=0.2, n_estimators=400
# [CV]  criterion=entropy, max_depth=4, max_features=0.2, n_estimators=100, score=0.48214285714285715, total=   0.5s
# [CV]  criterion=entropy, max_depth=2, max_features=0.1, n_estimators=800, score=0.4166666666666667, total=   3.2s
# [CV] criterion=entropy, max_depth=4, max_features=0.2, n_estimators=400
# [CV] criterion=entropy, max_depth=4, max_features=0.2, n_estimators=400
# [CV]  criterion=entropy, max_depth=2, max_features=0.1, n_estimators=800, score=0.38425925925925924, total=   3.3s
# [CV]  criterion=entropy, max_depth=2, max_features=0.1, n_estimators=800, score=0.5, total=   3.3s
# [CV]  criterion=entropy, max_depth=2, max_features=0.1, n_estimators=800, score=0.5773809523809524, total=   3.3s
# [CV] criterion=entropy, max_depth=4, max_features=0.2, n_estimators=400
# [CV] criterion=entropy, max_depth=4, max_features=0.2, n_estimators=400
# [CV] criterion=entropy, max_depth=4, max_features=0.2, n_estimators=800
# [CV]  criterion=entropy, max_depth=2, max_features=0.1, n_estimators=800, score=0.5297619047619048, total=   3.3s
# [CV] criterion=entropy, max_depth=4, max_features=0.2, n_estimators=800
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed:    3.5s
# [CV]  criterion=entropy, max_depth=2, max_features=0.2, n_estimators=800, score=0.5773809523809524, total=   3.4s
# [CV] criterion=entropy, max_depth=4, max_features=0.2, n_estimators=800
# [CV]  criterion=entropy, max_depth=4, max_features=0.1, n_estimators=400, score=0.4583333333333333, total=   1.7s
# [CV] criterion=entropy, max_depth=4, max_features=0.2, n_estimators=800
# [CV]  criterion=entropy, max_depth=4, max_features=0.1, n_estimators=400, score=0.34722222222222215, total=   1.7s
# [CV] criterion=entropy, max_depth=4, max_features=0.2, n_estimators=800
# [CV]  criterion=entropy, max_depth=4, max_features=0.2, n_estimators=200, score=0.46759259259259256, total=   0.9s
# [CV] criterion=entropy, max_depth=4, max_features=0.4, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=0.1, n_estimators=400, score=0.5, total=   1.7s
# [CV] criterion=entropy, max_depth=4, max_features=0.4, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=0.1, n_estimators=400, score=0.5357142857142857, total=   1.7s
# [CV] criterion=entropy, max_depth=4, max_features=0.4, n_estimators=100
# [CV]  criterion=entropy, max_depth=2, max_features=0.2, n_estimators=800, score=0.5, total=   3.5s
# [CV] criterion=entropy, max_depth=4, max_features=0.4, n_estimators=100
# [CV]  criterion=entropy, max_depth=2, max_features=0.2, n_estimators=800, score=0.48809523809523814, total=   3.5s
# [CV] criterion=entropy, max_depth=4, max_features=0.4, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=0.2, n_estimators=200, score=0.375, total=   0.9s
# [CV] criterion=entropy, max_depth=4, max_features=0.4, n_estimators=200
# [CV]  criterion=entropy, max_depth=4, max_features=0.1, n_estimators=400, score=0.48214285714285715, total=   1.7s
# [CV]  criterion=entropy, max_depth=4, max_features=0.2, n_estimators=200, score=0.525, total=   0.9s
# [CV] criterion=entropy, max_depth=4, max_features=0.4, n_estimators=200
# [CV]  criterion=entropy, max_depth=2, max_features=0.2, n_estimators=800, score=0.4259259259259259, total=   3.6s
# [CV] criterion=entropy, max_depth=4, max_features=0.4, n_estimators=200
# [CV] criterion=entropy, max_depth=4, max_features=0.4, n_estimators=200
# [CV]  criterion=entropy, max_depth=4, max_features=0.2, n_estimators=200, score=0.5357142857142857, total=   0.9s
# [CV] criterion=entropy, max_depth=4, max_features=0.4, n_estimators=200
# [CV]  criterion=entropy, max_depth=4, max_features=0.2, n_estimators=200, score=0.35714285714285715, total=   0.9s
# [CV] criterion=entropy, max_depth=4, max_features=0.4, n_estimators=400
# [CV]  criterion=entropy, max_depth=2, max_features=0.2, n_estimators=800, score=0.4166666666666667, total=   3.6s
# [CV] criterion=entropy, max_depth=4, max_features=0.4, n_estimators=400
# [CV]  criterion=entropy, max_depth=4, max_features=0.4, n_estimators=100, score=0.3814814814814815, total=   0.4s
# [CV] criterion=entropy, max_depth=4, max_features=0.4, n_estimators=400
# [CV]  criterion=entropy, max_depth=4, max_features=0.4, n_estimators=100, score=0.44166666666666665, total=   0.5s
# [CV]  criterion=entropy, max_depth=4, max_features=0.4, n_estimators=100, score=0.4166666666666667, total=   0.5s
# [CV] criterion=entropy, max_depth=4, max_features=0.4, n_estimators=400
# [CV] criterion=entropy, max_depth=4, max_features=0.4, n_estimators=400
# [CV]  criterion=entropy, max_depth=4, max_features=0.4, n_estimators=100, score=0.5357142857142857, total=   0.5s
# [CV]  criterion=entropy, max_depth=4, max_features=0.4, n_estimators=100, score=0.46547619047619043, total=   0.5s
# [CV] criterion=entropy, max_depth=4, max_features=0.4, n_estimators=800
# [CV] criterion=entropy, max_depth=4, max_features=0.4, n_estimators=800
# [CV]  criterion=entropy, max_depth=2, max_features=0.4, n_estimators=800, score=0.4166666666666667, total=   3.6s
# [CV]  criterion=entropy, max_depth=4, max_features=0.4, n_estimators=200, score=0.3814814814814815, total=   0.9s
# [CV] criterion=entropy, max_depth=4, max_features=0.4, n_estimators=800
# [CV] criterion=entropy, max_depth=4, max_features=0.4, n_estimators=800
# [CV]  criterion=entropy, max_depth=4, max_features=0.4, n_estimators=200, score=0.48333333333333334, total=   0.9s
# [CV] criterion=entropy, max_depth=4, max_features=0.4, n_estimators=800
# [CV]  criterion=entropy, max_depth=4, max_features=0.4, n_estimators=200, score=0.4166666666666667, total=   0.9s
# [CV] criterion=entropy, max_depth=8, max_features=0.1, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=0.4, n_estimators=200, score=0.5357142857142857, total=   0.9s
# [CV] criterion=entropy, max_depth=8, max_features=0.1, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=0.4, n_estimators=200, score=0.46547619047619043, total=   0.9s
# [CV] criterion=entropy, max_depth=8, max_features=0.1, n_estimators=100
# [CV]  criterion=entropy, max_depth=2, max_features=0.4, n_estimators=800, score=0.38888888888888884, total=   3.7s
# [CV]  criterion=entropy, max_depth=4, max_features=0.2, n_estimators=400, score=0.49722222222222223, total=   1.8s
# [CV] criterion=entropy, max_depth=8, max_features=0.1, n_estimators=100
# [CV] criterion=entropy, max_depth=8, max_features=0.1, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=0.2, n_estimators=400, score=0.375, total=   1.8s
# [CV] criterion=entropy, max_depth=8, max_features=0.1, n_estimators=200
# [CV]  criterion=entropy, max_depth=4, max_features=0.2, n_estimators=400, score=0.5773809523809524, total=   1.8s
# [CV]  criterion=entropy, max_depth=4, max_features=0.2, n_estimators=400, score=0.48333333333333334, total=   1.9s
# [CV]  criterion=entropy, max_depth=4, max_features=0.2, n_estimators=400, score=0.35714285714285715, total=   1.8s
# [CV] criterion=entropy, max_depth=8, max_features=0.1, n_estimators=200
# [CV] criterion=entropy, max_depth=8, max_features=0.1, n_estimators=200
# [CV] criterion=entropy, max_depth=8, max_features=0.1, n_estimators=200
# [CV]  criterion=entropy, max_depth=2, max_features=0.4, n_estimators=800, score=0.5, total=   3.6s
# [CV] criterion=entropy, max_depth=8, max_features=0.1, n_estimators=200
# [CV]  criterion=entropy, max_depth=2, max_features=0.4, n_estimators=800, score=0.49404761904761907, total=   3.7s
# [CV] criterion=entropy, max_depth=8, max_features=0.1, n_estimators=400
# [CV]  criterion=entropy, max_depth=2, max_features=0.4, n_estimators=800, score=0.44047619047619047, total=   3.7s
# [CV] criterion=entropy, max_depth=8, max_features=0.1, n_estimators=400
# [CV]  criterion=entropy, max_depth=8, max_features=0.1, n_estimators=100, score=0.39999999999999997, total=   0.4s
# [CV] criterion=entropy, max_depth=8, max_features=0.1, n_estimators=400
# [CV]  criterion=entropy, max_depth=8, max_features=0.1, n_estimators=100, score=0.4601851851851852, total=   0.4s
# [CV] criterion=entropy, max_depth=8, max_features=0.1, n_estimators=400
# [CV]  criterion=entropy, max_depth=8, max_features=0.1, n_estimators=100, score=0.30952380952380953, total=   0.4s
# [CV] criterion=entropy, max_depth=8, max_features=0.1, n_estimators=400
# [CV]  criterion=entropy, max_depth=8, max_features=0.1, n_estimators=100, score=0.525, total=   0.5s
# [CV] criterion=entropy, max_depth=8, max_features=0.1, n_estimators=800
# [CV]  criterion=entropy, max_depth=8, max_features=0.1, n_estimators=100, score=0.46547619047619043, total=   0.5s
# [CV] criterion=entropy, max_depth=8, max_features=0.1, n_estimators=800
# [CV]  criterion=entropy, max_depth=4, max_features=0.1, n_estimators=800, score=0.38888888888888884, total=   3.3s
# [CV] criterion=entropy, max_depth=8, max_features=0.1, n_estimators=800
# [CV]  criterion=entropy, max_depth=4, max_features=0.1, n_estimators=800, score=0.5, total=   3.4s
# [CV] criterion=entropy, max_depth=8, max_features=0.1, n_estimators=800
# [CV]  criterion=entropy, max_depth=4, max_features=0.1, n_estimators=800, score=0.44047619047619047, total=   3.3s
# [CV] criterion=entropy, max_depth=8, max_features=0.1, n_estimators=800
# [CV]  criterion=entropy, max_depth=4, max_features=0.1, n_estimators=800, score=0.5773809523809524, total=   3.4s
# [CV] criterion=entropy, max_depth=8, max_features=0.2, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=0.1, n_estimators=800, score=0.4583333333333333, total=   3.4s
# [CV] criterion=entropy, max_depth=8, max_features=0.2, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=0.4, n_estimators=400, score=0.4185185185185185, total=   1.9s
# [CV] criterion=entropy, max_depth=8, max_features=0.2, n_estimators=100
# [CV]  criterion=entropy, max_depth=8, max_features=0.1, n_estimators=200, score=0.3333333333333333, total=   0.8s
# [CV] criterion=entropy, max_depth=8, max_features=0.2, n_estimators=100
# [CV]  criterion=entropy, max_depth=8, max_features=0.1, n_estimators=200, score=0.4583333333333333, total=   0.9s
# [CV] criterion=entropy, max_depth=8, max_features=0.2, n_estimators=100
# [CV]  criterion=entropy, max_depth=8, max_features=0.1, n_estimators=200, score=0.38888888888888884, total=   0.9s
# [CV] criterion=entropy, max_depth=8, max_features=0.2, n_estimators=200
# [CV]  criterion=entropy, max_depth=8, max_features=0.1, n_estimators=200, score=0.49404761904761907, total=   0.9s
# [CV] criterion=entropy, max_depth=8, max_features=0.2, n_estimators=200
# [CV]  criterion=entropy, max_depth=8, max_features=0.1, n_estimators=200, score=0.35714285714285715, total=   0.9s
# [CV] criterion=entropy, max_depth=8, max_features=0.2, n_estimators=200
# [CV]  criterion=entropy, max_depth=4, max_features=0.4, n_estimators=400, score=0.48333333333333334, total=   2.0s
# [CV] criterion=entropy, max_depth=8, max_features=0.2, n_estimators=200
# [CV]  criterion=entropy, max_depth=4, max_features=0.4, n_estimators=400, score=0.5297619047619048, total=   2.0s
# [CV] criterion=entropy, max_depth=8, max_features=0.2, n_estimators=200
# [CV]  criterion=entropy, max_depth=8, max_features=0.2, n_estimators=100, score=0.4166666666666667, total=   0.5s
# [CV]  criterion=entropy, max_depth=4, max_features=0.4, n_estimators=400, score=0.375, total=   2.1s
# [CV]  criterion=entropy, max_depth=4, max_features=0.4, n_estimators=400, score=0.3988095238095238, total=   2.1s
# [CV]  criterion=entropy, max_depth=8, max_features=0.2, n_estimators=100, score=0.4166666666666667, total=   0.5s
# [CV] criterion=entropy, max_depth=8, max_features=0.2, n_estimators=400
# [CV] criterion=entropy, max_depth=8, max_features=0.2, n_estimators=400
# [CV]  criterion=entropy, max_depth=8, max_features=0.2, n_estimators=100, score=0.35714285714285715, total=   0.5s
# [CV] criterion=entropy, max_depth=8, max_features=0.2, n_estimators=400
# [CV]  criterion=entropy, max_depth=8, max_features=0.2, n_estimators=100, score=0.49722222222222223, total=   0.5s
# [CV] criterion=entropy, max_depth=8, max_features=0.2, n_estimators=400
# [CV] criterion=entropy, max_depth=8, max_features=0.2, n_estimators=800
# [CV] criterion=entropy, max_depth=8, max_features=0.2, n_estimators=400
# [CV]  criterion=entropy, max_depth=8, max_features=0.2, n_estimators=100, score=0.49404761904761907, total=   0.5s
# [CV] criterion=entropy, max_depth=8, max_features=0.2, n_estimators=800
# [CV]  criterion=entropy, max_depth=8, max_features=0.2, n_estimators=200, score=0.45555555555555555, total=   0.9s
# [CV] criterion=entropy, max_depth=8, max_features=0.2, n_estimators=800
# [CV]  criterion=entropy, max_depth=4, max_features=0.2, n_estimators=800, score=0.375, total=   3.6s
# [CV] criterion=entropy, max_depth=8, max_features=0.2, n_estimators=800
# [CV]  criterion=entropy, max_depth=8, max_features=0.2, n_estimators=200, score=0.4166666666666667, total=   0.9s
# [CV] criterion=entropy, max_depth=8, max_features=0.2, n_estimators=800
# [CV]  criterion=entropy, max_depth=8, max_features=0.1, n_estimators=400, score=0.4305555555555555, total=   1.7s
# [CV] criterion=entropy, max_depth=8, max_features=0.4, n_estimators=100
# [CV]  criterion=entropy, max_depth=8, max_features=0.2, n_estimators=200, score=0.44166666666666665, total=   0.9s
# [CV] criterion=entropy, max_depth=8, max_features=0.4, n_estimators=100
# [CV]  criterion=entropy, max_depth=8, max_features=0.2, n_estimators=200, score=0.49404761904761907, total=   0.9s
# [CV] criterion=entropy, max_depth=8, max_features=0.4, n_estimators=100
# [CV]  criterion=entropy, max_depth=8, max_features=0.1, n_estimators=400, score=0.3988095238095238, total=   1.7s
# [CV] criterion=entropy, max_depth=8, max_features=0.4, n_estimators=100
# [CV]  criterion=entropy, max_depth=8, max_features=0.1, n_estimators=400, score=0.3333333333333333, total=   1.7s
# [CV]  criterion=entropy, max_depth=4, max_features=0.2, n_estimators=800, score=0.45555555555555555, total=   3.8s
# [CV] criterion=entropy, max_depth=8, max_features=0.4, n_estimators=100
# [CV] criterion=entropy, max_depth=8, max_features=0.4, n_estimators=200
# [CV]  criterion=entropy, max_depth=8, max_features=0.1, n_estimators=400, score=0.5357142857142857, total=   1.7s
# [CV] criterion=entropy, max_depth=8, max_features=0.4, n_estimators=200
# [CV]  criterion=entropy, max_depth=8, max_features=0.1, n_estimators=400, score=0.4166666666666667, total=   1.8s
# [CV] criterion=entropy, max_depth=8, max_features=0.4, n_estimators=200
# [CV]  criterion=entropy, max_depth=8, max_features=0.2, n_estimators=200, score=0.39285714285714285, total=   0.9s
# [CV] criterion=entropy, max_depth=8, max_features=0.4, n_estimators=200
# [CV]  criterion=entropy, max_depth=4, max_features=0.2, n_estimators=800, score=0.375, total=   3.5s
# [CV] criterion=entropy, max_depth=8, max_features=0.4, n_estimators=200
# [CV]  criterion=entropy, max_depth=4, max_features=0.2, n_estimators=800, score=0.5357142857142857, total=   3.6s
# [CV] criterion=entropy, max_depth=8, max_features=0.4, n_estimators=400
# [CV]  criterion=entropy, max_depth=8, max_features=0.4, n_estimators=100, score=0.4435185185185186, total=   0.5s
# [CV] criterion=entropy, max_depth=8, max_features=0.4, n_estimators=400
# [CV]  criterion=entropy, max_depth=8, max_features=0.4, n_estimators=100, score=0.5083333333333333, total=   0.5s
# [CV] criterion=entropy, max_depth=8, max_features=0.4, n_estimators=400
# [CV]  criterion=entropy, max_depth=8, max_features=0.4, n_estimators=100, score=0.49404761904761907, total=   0.5s
# [CV] criterion=entropy, max_depth=8, max_features=0.4, n_estimators=400
# [CV]  criterion=entropy, max_depth=8, max_features=0.4, n_estimators=100, score=0.4166666666666667, total=   0.6s
# [CV] criterion=entropy, max_depth=8, max_features=0.4, n_estimators=400
# [CV]  criterion=entropy, max_depth=4, max_features=0.2, n_estimators=800, score=0.3988095238095238, total=   3.8s
# [CV] criterion=entropy, max_depth=8, max_features=0.4, n_estimators=800
# [CV]  criterion=entropy, max_depth=8, max_features=0.4, n_estimators=100, score=0.39285714285714285, total=   0.5s
# [CV] criterion=entropy, max_depth=8, max_features=0.4, n_estimators=800
# [CV]  criterion=entropy, max_depth=8, max_features=0.4, n_estimators=200, score=0.5083333333333333, total=   0.9s
# [CV] criterion=entropy, max_depth=8, max_features=0.4, n_estimators=800
# [CV]  criterion=entropy, max_depth=8, max_features=0.4, n_estimators=200, score=0.4851851851851852, total=   1.0s
# [CV] criterion=entropy, max_depth=8, max_features=0.4, n_estimators=800
# [CV]  criterion=entropy, max_depth=8, max_features=0.4, n_estimators=200, score=0.4166666666666667, total=   1.0s
# [CV] criterion=entropy, max_depth=8, max_features=0.4, n_estimators=800
# [CV]  criterion=entropy, max_depth=8, max_features=0.2, n_estimators=400, score=0.45555555555555555, total=   1.8s
# [CV]  criterion=entropy, max_depth=8, max_features=0.4, n_estimators=200, score=0.6023809523809524, total=   1.0s
# [CV]  criterion=entropy, max_depth=8, max_features=0.2, n_estimators=400, score=0.375, total=   1.8s
# [CV]  criterion=entropy, max_depth=8, max_features=0.2, n_estimators=400, score=0.49404761904761907, total=   1.8s
# [CV]  criterion=entropy, max_depth=4, max_features=0.4, n_estimators=800, score=0.49259259259259264, total=   3.9s
# [CV]  criterion=entropy, max_depth=8, max_features=0.2, n_estimators=400, score=0.375, total=   1.9s
# [CV]  criterion=entropy, max_depth=8, max_features=0.2, n_estimators=400, score=0.3988095238095238, total=   1.9s
# [CV]  criterion=entropy, max_depth=8, max_features=0.4, n_estimators=200, score=0.30952380952380953, total=   1.0s
# [CV]  criterion=entropy, max_depth=4, max_features=0.4, n_estimators=800, score=0.44166666666666665, total=   4.0s
# [CV]  criterion=entropy, max_depth=4, max_features=0.4, n_estimators=800, score=0.3511904761904762, total=   3.8s
# [CV]  criterion=entropy, max_depth=8, max_features=0.1, n_estimators=800, score=0.4166666666666667, total=   3.3s
# [CV]  criterion=entropy, max_depth=4, max_features=0.4, n_estimators=800, score=0.5773809523809524, total=   3.8s
# [CV]  criterion=entropy, max_depth=8, max_features=0.1, n_estimators=800, score=0.46759259259259256, total=   3.4s
# [CV]  criterion=entropy, max_depth=8, max_features=0.1, n_estimators=800, score=0.4583333333333333, total=   3.4s
# [CV]  criterion=entropy, max_depth=4, max_features=0.4, n_estimators=800, score=0.375, total=   4.0s
# [CV]  criterion=entropy, max_depth=8, max_features=0.1, n_estimators=800, score=0.5357142857142857, total=   3.4s
# [CV]  criterion=entropy, max_depth=8, max_features=0.4, n_estimators=400, score=0.4185185185185185, total=   1.6s
# [CV]  criterion=entropy, max_depth=8, max_features=0.1, n_estimators=800, score=0.3988095238095238, total=   3.2s
# [CV]  criterion=entropy, max_depth=8, max_features=0.4, n_estimators=400, score=0.4166666666666667, total=   1.7s
# [CV]  criterion=entropy, max_depth=8, max_features=0.4, n_estimators=400, score=0.3511904761904762, total=   1.5s
# [CV]  criterion=entropy, max_depth=8, max_features=0.4, n_estimators=400, score=0.5499999999999999, total=   1.8s
# [CV]  criterion=entropy, max_depth=8, max_features=0.4, n_estimators=400, score=0.5773809523809524, total=   1.7s
# [CV]  criterion=entropy, max_depth=8, max_features=0.2, n_estimators=800, score=0.4185185185185185, total=   3.2s
# [CV]  criterion=entropy, max_depth=8, max_features=0.2, n_estimators=800, score=0.375, total=   3.2s
# [CV]  criterion=entropy, max_depth=8, max_features=0.2, n_estimators=800, score=0.5773809523809524, total=   2.9s
# [CV]  criterion=entropy, max_depth=8, max_features=0.2, n_estimators=800, score=0.3988095238095238, total=   3.0s
# [CV]  criterion=entropy, max_depth=8, max_features=0.2, n_estimators=800, score=0.375, total=   3.2s
# [CV]  criterion=entropy, max_depth=8, max_features=0.4, n_estimators=800, score=0.4185185185185185, total=   2.8s
# [CV]  criterion=entropy, max_depth=8, max_features=0.4, n_estimators=800, score=0.5916666666666667, total=   2.8s
# [CV]  criterion=entropy, max_depth=8, max_features=0.4, n_estimators=800, score=0.4166666666666667, total=   2.5s
# [CV]  criterion=entropy, max_depth=8, max_features=0.4, n_estimators=800, score=0.30952380952380953, total=   2.4s
# [Parallel(n_jobs=-1)]: Done 178 out of 180 | elapsed:   11.0s remaining:    0.1s
# [CV]  criterion=entropy, max_depth=8, max_features=0.4, n_estimators=800, score=0.5773809523809524, total=   2.7s
# [Parallel(n_jobs=-1)]: Done 180 out of 180 | elapsed:   11.4s finished
# final score for the tuned model
#  0.31746031746031744
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 2, 'max_features': 0.1, 'n_estimators': 400}
#
# cross validation results (MEAN)
#  [0.46350351 0.48770732 0.50453424 0.47929385 0.43901989 0.44627595
#  0.44667659 0.48009514 0.41267933 0.45451135 0.45491199 0.44707723
#  0.42382987 0.42179233 0.46270223 0.47151633 0.50419083 0.45234788
#  0.45821505 0.42752595 0.44655194 0.4549654  0.4404215  0.44767755
#  0.43316417 0.4058112  0.42223748 0.45531263 0.43714133 0.44024344
#  0.41951313 0.42770401 0.45115868 0.46478047 0.4622965  0.46269714]
#
# cross validation results (STD)
#  [0.05056487 0.06526603 0.0669746  0.07161769 0.08438899 0.07116028
#  0.0494738  0.05784031 0.04668499 0.05633106 0.03490266 0.04360259
#  0.05742675 0.09306388 0.06483502 0.0631165  0.08100086 0.07350258
#  0.08088842 0.06074446 0.05175474 0.0536295  0.05661688 0.08078448
#  0.07225026 0.06025821 0.06479805 0.04682346 0.05278605 0.03392311
#  0.047178   0.07488977 0.04381849 0.09599568 0.08543984 0.10602151]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 0.7019
#
# accuracy on development set: 0.3333
#
# precision on dev set: 0.2201
#
# recall on dev set: 0.3175
#
# fscore on dev set: 0.2554
# ------------------------------------------------------------
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# /home/ceccarelli/.local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# [CV] criterion=entropy, max_depth=2, max_features=0.1, n_estimators=100
# [CV] criterion=entropy, max_depth=2, max_features=0.1, n_estimators=100
# [CV] criterion=entropy, max_depth=2, max_features=0.1, n_estimators=100
# [CV] criterion=entropy, max_depth=2, max_features=0.1, n_estimators=100
# [CV] criterion=entropy, max_depth=2, max_features=0.1, n_estimators=100
# [CV] criterion=entropy, max_depth=2, max_features=0.1, n_estimators=200
# [CV] criterion=entropy, max_depth=2, max_features=0.1, n_estimators=200
# [CV] criterion=entropy, max_depth=2, max_features=0.1, n_estimators=200
# [CV] criterion=entropy, max_depth=2, max_features=0.1, n_estimators=200
# [CV] criterion=entropy, max_depth=2, max_features=0.1, n_estimators=200
# [CV] criterion=entropy, max_depth=2, max_features=0.1, n_estimators=400
# [CV] criterion=entropy, max_depth=2, max_features=0.1, n_estimators=400
# [CV] criterion=entropy, max_depth=2, max_features=0.1, n_estimators=400
# [CV] criterion=entropy, max_depth=2, max_features=0.1, n_estimators=400
# [CV] criterion=entropy, max_depth=2, max_features=0.1, n_estimators=400
# [CV] criterion=entropy, max_depth=2, max_features=0.1, n_estimators=800
# [CV] criterion=entropy, max_depth=2, max_features=0.1, n_estimators=800
# [CV] criterion=entropy, max_depth=2, max_features=0.1, n_estimators=800
# [CV] criterion=entropy, max_depth=2, max_features=0.1, n_estimators=800
# [CV] criterion=entropy, max_depth=2, max_features=0.1, n_estimators=800
# [CV] criterion=entropy, max_depth=2, max_features=0.2, n_estimators=100
# [CV] criterion=entropy, max_depth=2, max_features=0.2, n_estimators=100
# [CV] criterion=entropy, max_depth=2, max_features=0.2, n_estimators=100
# [CV] criterion=entropy, max_depth=2, max_features=0.2, n_estimators=100
# [CV] criterion=entropy, max_depth=2, max_features=0.2, n_estimators=100
# [CV] criterion=entropy, max_depth=2, max_features=0.2, n_estimators=200
# [CV] criterion=entropy, max_depth=2, max_features=0.2, n_estimators=200
# [CV] criterion=entropy, max_depth=2, max_features=0.2, n_estimators=200
# [CV] criterion=entropy, max_depth=2, max_features=0.2, n_estimators=200
# [CV] criterion=entropy, max_depth=2, max_features=0.2, n_estimators=200
# [CV] criterion=entropy, max_depth=2, max_features=0.2, n_estimators=400
# [CV] criterion=entropy, max_depth=2, max_features=0.2, n_estimators=400
# [CV]  criterion=entropy, max_depth=2, max_features=0.1, n_estimators=100, score=0.46759259259259256, total=   0.6s
# [CV] criterion=entropy, max_depth=2, max_features=0.2, n_estimators=400
# [CV]  criterion=entropy, max_depth=2, max_features=0.1, n_estimators=100, score=0.5773809523809524, total=   0.7s
# [CV] criterion=entropy, max_depth=2, max_features=0.2, n_estimators=400
# [CV]  criterion=entropy, max_depth=2, max_features=0.1, n_estimators=100, score=0.2916666666666667, total=   0.7s
# [CV]  criterion=entropy, max_depth=2, max_features=0.1, n_estimators=100, score=0.375, total=   0.7s
# [CV]  criterion=entropy, max_depth=2, max_features=0.1, n_estimators=100, score=0.39285714285714285, total=   0.7s
# [CV] criterion=entropy, max_depth=2, max_features=0.2, n_estimators=800
# [CV] criterion=entropy, max_depth=2, max_features=0.2, n_estimators=400
# [CV] criterion=entropy, max_depth=2, max_features=0.2, n_estimators=800
# [CV]  criterion=entropy, max_depth=2, max_features=0.2, n_estimators=100, score=0.3333333333333333, total=   0.7s
# [CV]  criterion=entropy, max_depth=2, max_features=0.2, n_estimators=100, score=0.3988095238095238, total=   0.7s
# [CV] criterion=entropy, max_depth=2, max_features=0.2, n_estimators=800
# [CV]  criterion=entropy, max_depth=2, max_features=0.2, n_estimators=100, score=0.4166666666666667, total=   0.7s
# [CV] criterion=entropy, max_depth=2, max_features=0.2, n_estimators=800
# [CV] criterion=entropy, max_depth=2, max_features=0.2, n_estimators=800
# [CV]  criterion=entropy, max_depth=2, max_features=0.2, n_estimators=100, score=0.46759259259259256, total=   0.7s
# [CV] criterion=entropy, max_depth=2, max_features=0.4, n_estimators=100
# [CV]  criterion=entropy, max_depth=2, max_features=0.2, n_estimators=100, score=0.49404761904761907, total=   0.7s
# [CV] criterion=entropy, max_depth=2, max_features=0.4, n_estimators=100
# [CV]  criterion=entropy, max_depth=2, max_features=0.1, n_estimators=200, score=0.3101851851851852, total=   1.1s
# [CV] criterion=entropy, max_depth=2, max_features=0.4, n_estimators=100
# [CV]  criterion=entropy, max_depth=2, max_features=0.2, n_estimators=200, score=0.44166666666666665, total=   1.1s
# [CV] criterion=entropy, max_depth=2, max_features=0.4, n_estimators=100
# [CV]  criterion=entropy, max_depth=2, max_features=0.1, n_estimators=200, score=0.5773809523809524, total=   1.1s
# [CV]  criterion=entropy, max_depth=2, max_features=0.1, n_estimators=200, score=0.39285714285714285, total=   1.1s
# [CV] criterion=entropy, max_depth=2, max_features=0.4, n_estimators=100
# [CV]  criterion=entropy, max_depth=2, max_features=0.2, n_estimators=200, score=0.4166666666666667, total=   1.1s
# [CV] criterion=entropy, max_depth=2, max_features=0.4, n_estimators=200
# [CV]  criterion=entropy, max_depth=2, max_features=0.1, n_estimators=200, score=0.375, total=   1.2s
# [CV] criterion=entropy, max_depth=2, max_features=0.4, n_estimators=200
# [CV]  criterion=entropy, max_depth=2, max_features=0.2, n_estimators=200, score=0.38888888888888884, total=   1.1s
# [CV] criterion=entropy, max_depth=2, max_features=0.4, n_estimators=200
# [CV] criterion=entropy, max_depth=2, max_features=0.4, n_estimators=200
# [CV]  criterion=entropy, max_depth=2, max_features=0.2, n_estimators=200, score=0.48809523809523814, total=   1.2s
# [CV]  criterion=entropy, max_depth=2, max_features=0.2, n_estimators=200, score=0.49404761904761907, total=   1.2s
# [CV]  criterion=entropy, max_depth=2, max_features=0.1, n_estimators=200, score=0.375, total=   1.2s
# [CV]  criterion=entropy, max_depth=2, max_features=0.4, n_estimators=100, score=0.44166666666666665, total=   0.5s
# [CV] criterion=entropy, max_depth=2, max_features=0.4, n_estimators=200
# [CV] criterion=entropy, max_depth=2, max_features=0.4, n_estimators=400
# [CV] criterion=entropy, max_depth=2, max_features=0.4, n_estimators=400
# [CV]  criterion=entropy, max_depth=2, max_features=0.4, n_estimators=100, score=0.38888888888888884, total=   0.5s
# [CV] criterion=entropy, max_depth=2, max_features=0.4, n_estimators=400
# [CV] criterion=entropy, max_depth=2, max_features=0.4, n_estimators=400
# [CV]  criterion=entropy, max_depth=2, max_features=0.4, n_estimators=100, score=0.375, total=   0.4s
# [CV] criterion=entropy, max_depth=2, max_features=0.4, n_estimators=400
# [CV]  criterion=entropy, max_depth=2, max_features=0.4, n_estimators=100, score=0.48809523809523814, total=   0.4s
# [CV] criterion=entropy, max_depth=2, max_features=0.4, n_estimators=800
# [CV]  criterion=entropy, max_depth=2, max_features=0.4, n_estimators=100, score=0.35714285714285715, total=   0.4s
# [CV] criterion=entropy, max_depth=2, max_features=0.4, n_estimators=800
# [CV]  criterion=entropy, max_depth=2, max_features=0.1, n_estimators=400, score=0.5357142857142857, total=   1.9s
# [CV] criterion=entropy, max_depth=2, max_features=0.4, n_estimators=800
# [CV]  criterion=entropy, max_depth=2, max_features=0.1, n_estimators=400, score=0.3101851851851852, total=   1.9s
# [CV]  criterion=entropy, max_depth=2, max_features=0.1, n_estimators=400, score=0.375, total=   1.9s
# [CV] criterion=entropy, max_depth=2, max_features=0.4, n_estimators=800
# [CV]  criterion=entropy, max_depth=2, max_features=0.1, n_estimators=400, score=0.2916666666666667, total=   1.9s
# [CV] criterion=entropy, max_depth=2, max_features=0.4, n_estimators=800
# [CV]  criterion=entropy, max_depth=2, max_features=0.1, n_estimators=400, score=0.39285714285714285, total=   2.0s
# [CV] criterion=entropy, max_depth=4, max_features=0.1, n_estimators=100
# [CV] criterion=entropy, max_depth=4, max_features=0.1, n_estimators=100
# [CV]  criterion=entropy, max_depth=2, max_features=0.2, n_estimators=400, score=0.375, total=   2.0s
# [CV] criterion=entropy, max_depth=4, max_features=0.1, n_estimators=100
# [CV]  criterion=entropy, max_depth=2, max_features=0.2, n_estimators=400, score=0.3101851851851852, total=   2.1s
# [CV]  criterion=entropy, max_depth=2, max_features=0.4, n_estimators=200, score=0.39999999999999997, total=   0.9s
# [CV] criterion=entropy, max_depth=4, max_features=0.1, n_estimators=200
# [CV] criterion=entropy, max_depth=4, max_features=0.1, n_estimators=100
# [CV] criterion=entropy, max_depth=4, max_features=0.1, n_estimators=100
# [CV]  criterion=entropy, max_depth=2, max_features=0.4, n_estimators=200, score=0.35185185185185186, total=   0.9s
# [CV]  criterion=entropy, max_depth=2, max_features=0.4, n_estimators=200, score=0.3333333333333333, total=   0.9s
# [CV]  criterion=entropy, max_depth=2, max_features=0.4, n_estimators=200, score=0.3988095238095238, total=   0.9s
# [CV] criterion=entropy, max_depth=4, max_features=0.1, n_estimators=200
# [CV] criterion=entropy, max_depth=4, max_features=0.1, n_estimators=200
# [CV]  criterion=entropy, max_depth=2, max_features=0.4, n_estimators=200, score=0.35714285714285715, total=   0.9s
# [CV] criterion=entropy, max_depth=4, max_features=0.1, n_estimators=200
# [CV]  criterion=entropy, max_depth=2, max_features=0.2, n_estimators=400, score=0.375, total=   1.8s
# [CV]  criterion=entropy, max_depth=4, max_features=0.1, n_estimators=100, score=0.38888888888888884, total=   0.5s
# [CV] criterion=entropy, max_depth=4, max_features=0.1, n_estimators=200
# [CV] criterion=entropy, max_depth=4, max_features=0.1, n_estimators=400
# [CV]  criterion=entropy, max_depth=4, max_features=0.1, n_estimators=100, score=0.4166666666666667, total=   0.4s
# [CV] criterion=entropy, max_depth=4, max_features=0.1, n_estimators=400
# [CV]  criterion=entropy, max_depth=4, max_features=0.1, n_estimators=100, score=0.44166666666666665, total=   0.5s
# [CV]  criterion=entropy, max_depth=4, max_features=0.1, n_estimators=100, score=0.3988095238095238, total=   0.4s
# [CV] criterion=entropy, max_depth=4, max_features=0.1, n_estimators=400
# [CV] criterion=entropy, max_depth=4, max_features=0.1, n_estimators=400
# [CV]  criterion=entropy, max_depth=2, max_features=0.2, n_estimators=400, score=0.44047619047619047, total=   1.8s
# [CV]  criterion=entropy, max_depth=4, max_features=0.1, n_estimators=100, score=0.5357142857142857, total=   0.4s
# [CV]  criterion=entropy, max_depth=2, max_features=0.2, n_estimators=400, score=0.44642857142857145, total=   1.8s
# [CV] criterion=entropy, max_depth=4, max_features=0.1, n_estimators=800
# [CV] criterion=entropy, max_depth=4, max_features=0.1, n_estimators=800
# [CV] criterion=entropy, max_depth=4, max_features=0.1, n_estimators=400
# [CV]  criterion=entropy, max_depth=4, max_features=0.1, n_estimators=200, score=0.44166666666666665, total=   0.8s
# [CV]  criterion=entropy, max_depth=4, max_features=0.1, n_estimators=200, score=0.34722222222222215, total=   0.8s
# [CV]  criterion=entropy, max_depth=4, max_features=0.1, n_estimators=200, score=0.48809523809523814, total=   0.8s
# [CV] criterion=entropy, max_depth=4, max_features=0.1, n_estimators=800
# [CV]  criterion=entropy, max_depth=4, max_features=0.1, n_estimators=200, score=0.3333333333333333, total=   0.8s
# [CV] criterion=entropy, max_depth=4, max_features=0.1, n_estimators=800
# [CV] criterion=entropy, max_depth=4, max_features=0.1, n_estimators=800
# [CV] criterion=entropy, max_depth=4, max_features=0.2, n_estimators=100
# [CV]  criterion=entropy, max_depth=2, max_features=0.4, n_estimators=400, score=0.375, total=   1.7s
# [CV] criterion=entropy, max_depth=4, max_features=0.2, n_estimators=100
# [CV]  criterion=entropy, max_depth=2, max_features=0.4, n_estimators=400, score=0.44166666666666665, total=   1.8s
# [CV] criterion=entropy, max_depth=4, max_features=0.2, n_estimators=100
# [CV]  criterion=entropy, max_depth=2, max_features=0.4, n_estimators=400, score=0.44047619047619047, total=   1.8s
# [CV] criterion=entropy, max_depth=4, max_features=0.2, n_estimators=100
# [CV]  criterion=entropy, max_depth=2, max_features=0.4, n_estimators=400, score=0.35185185185185186, total=   1.8s
# [CV] criterion=entropy, max_depth=4, max_features=0.2, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=0.1, n_estimators=200, score=0.35714285714285715, total=   0.8s
# [CV] criterion=entropy, max_depth=4, max_features=0.2, n_estimators=200
# [CV]  criterion=entropy, max_depth=4, max_features=0.2, n_estimators=100, score=0.4259259259259259, total=   0.4s
# [CV] criterion=entropy, max_depth=4, max_features=0.2, n_estimators=200
# ...
# [CV] criterion=entropy, max_depth=8, max_features=0.1, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=0.2, n_estimators=400, score=0.48333333333333334, total=   2.5s
# [CV] criterion=entropy, max_depth=8, max_features=0.1, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=0.4, n_estimators=200, score=0.35714285714285715, total=   1.6s
# [CV] criterion=entropy, max_depth=8, max_features=0.1, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=0.2, n_estimators=400, score=0.26785714285714285, total=   2.3s
# [CV] criterion=entropy, max_depth=8, max_features=0.1, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=0.4, n_estimators=200, score=0.17857142857142858, total=   1.5s
# [CV]  criterion=entropy, max_depth=4, max_features=0.1, n_estimators=800, score=0.23148148148148148, total=   3.8s
# [CV] criterion=entropy, max_depth=8, max_features=0.1, n_estimators=200
# [CV] criterion=entropy, max_depth=8, max_features=0.1, n_estimators=200
# [CV]  criterion=entropy, max_depth=4, max_features=0.2, n_estimators=400, score=0.3988095238095238, total=   2.5s
# [CV] criterion=entropy, max_depth=8, max_features=0.1, n_estimators=200
# [CV]  criterion=entropy, max_depth=2, max_features=0.4, n_estimators=800, score=0.1851851851851852, total=   5.0s
# [CV] criterion=entropy, max_depth=8, max_features=0.1, n_estimators=200
# [CV]  criterion=entropy, max_depth=2, max_features=0.4, n_estimators=800, score=0.4166666666666667, total=   5.1s
# [CV] criterion=entropy, max_depth=8, max_features=0.1, n_estimators=200
# [CV]  criterion=entropy, max_depth=2, max_features=0.4, n_estimators=800, score=0.44166666666666665, total=   4.9s
# [CV] criterion=entropy, max_depth=8, max_features=0.1, n_estimators=400
# [CV]  criterion=entropy, max_depth=8, max_features=0.1, n_estimators=100, score=0.1898148148148148, total=   0.5s
# [CV] criterion=entropy, max_depth=8, max_features=0.1, n_estimators=400
# [CV]  criterion=entropy, max_depth=2, max_features=0.4, n_estimators=800, score=0.44047619047619047, total=   5.0s
# [CV]  criterion=entropy, max_depth=8, max_features=0.1, n_estimators=100, score=0.2738095238095238, total=   0.4s
# [CV] criterion=entropy, max_depth=8, max_features=0.1, n_estimators=400
# [CV] criterion=entropy, max_depth=8, max_features=0.1, n_estimators=400
# [CV]  criterion=entropy, max_depth=8, max_features=0.1, n_estimators=100, score=0.44166666666666665, total=   0.5s
# [CV] criterion=entropy, max_depth=8, max_features=0.1, n_estimators=400
# [CV]  criterion=entropy, max_depth=8, max_features=0.1, n_estimators=100, score=0.4238095238095238, total=   0.5s
# [CV] criterion=entropy, max_depth=8, max_features=0.1, n_estimators=800
# [CV]  criterion=entropy, max_depth=8, max_features=0.1, n_estimators=100, score=0.3333333333333333, total=   0.5s
# [CV]  criterion=entropy, max_depth=4, max_features=0.1, n_estimators=800, score=0.4583333333333333, total=   4.3s
# [CV] criterion=entropy, max_depth=8, max_features=0.1, n_estimators=800
# [CV]  criterion=entropy, max_depth=2, max_features=0.4, n_estimators=800, score=0.30357142857142855, total=   5.1s
# [CV] criterion=entropy, max_depth=8, max_features=0.1, n_estimators=800
# [CV] criterion=entropy, max_depth=8, max_features=0.1, n_estimators=800
# [CV]  criterion=entropy, max_depth=4, max_features=0.1, n_estimators=800, score=0.48809523809523814, total=   3.9s
# [CV]  criterion=entropy, max_depth=4, max_features=0.1, n_estimators=800, score=0.3333333333333333, total=   4.0s
# [CV] criterion=entropy, max_depth=8, max_features=0.2, n_estimators=100
# [CV] criterion=entropy, max_depth=8, max_features=0.1, n_estimators=800
# [CV]  criterion=entropy, max_depth=8, max_features=0.1, n_estimators=200, score=0.375, total=   1.0s
# [CV] criterion=entropy, max_depth=8, max_features=0.2, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=0.1, n_estimators=800, score=0.2619047619047619, total=   4.1s
# [CV]  criterion=entropy, max_depth=8, max_features=0.1, n_estimators=200, score=0.1898148148148148, total=   1.0s
# [CV]  criterion=entropy, max_depth=8, max_features=0.1, n_estimators=200, score=0.30952380952380953, total=   0.9s
# [CV] criterion=entropy, max_depth=8, max_features=0.2, n_estimators=100
# [CV] criterion=entropy, max_depth=8, max_features=0.2, n_estimators=100
# [CV] criterion=entropy, max_depth=8, max_features=0.2, n_estimators=100
# [CV]  criterion=entropy, max_depth=8, max_features=0.1, n_estimators=200, score=0.2916666666666667, total=   1.0s
# [CV] criterion=entropy, max_depth=8, max_features=0.2, n_estimators=200
# [CV]  criterion=entropy, max_depth=4, max_features=0.4, n_estimators=400, score=0.44166666666666665, total=   2.8s
# [CV] criterion=entropy, max_depth=8, max_features=0.2, n_estimators=200
# [CV]  criterion=entropy, max_depth=8, max_features=0.1, n_estimators=200, score=0.26785714285714285, total=   1.0s
# [CV] criterion=entropy, max_depth=8, max_features=0.2, n_estimators=200
# [CV]  criterion=entropy, max_depth=4, max_features=0.4, n_estimators=400, score=0.1898148148148148, total=   2.9s
# [CV] criterion=entropy, max_depth=8, max_features=0.2, n_estimators=200
# [CV]  criterion=entropy, max_depth=8, max_features=0.2, n_estimators=100, score=0.26851851851851855, total=   0.6s
# [CV] criterion=entropy, max_depth=8, max_features=0.2, n_estimators=200
# [CV]  criterion=entropy, max_depth=8, max_features=0.2, n_estimators=100, score=0.48333333333333334, total=   0.6s
# [CV] criterion=entropy, max_depth=8, max_features=0.2, n_estimators=400
# [CV]  criterion=entropy, max_depth=8, max_features=0.2, n_estimators=100, score=0.44642857142857145, total=   0.6s
# [CV] criterion=entropy, max_depth=8, max_features=0.2, n_estimators=400
# [CV]  criterion=entropy, max_depth=8, max_features=0.2, n_estimators=100, score=0.25, total=   0.6s
# [CV] criterion=entropy, max_depth=8, max_features=0.2, n_estimators=400
# [CV]  criterion=entropy, max_depth=8, max_features=0.2, n_estimators=100, score=0.41785714285714287, total=   0.6s
# [CV] criterion=entropy, max_depth=8, max_features=0.2, n_estimators=400
# [CV]  criterion=entropy, max_depth=4, max_features=0.4, n_estimators=400, score=0.35714285714285715, total=   3.0s
# [CV] criterion=entropy, max_depth=8, max_features=0.2, n_estimators=400
# [CV]  criterion=entropy, max_depth=4, max_features=0.4, n_estimators=400, score=0.2619047619047619, total=   2.9s
# [CV]  criterion=entropy, max_depth=4, max_features=0.4, n_estimators=400, score=0.27499999999999997, total=   3.0s
# [CV] criterion=entropy, max_depth=8, max_features=0.2, n_estimators=800
# [CV] criterion=entropy, max_depth=8, max_features=0.2, n_estimators=800
# [CV]  criterion=entropy, max_depth=4, max_features=0.2, n_estimators=800, score=0.1898148148148148, total=   4.4s
# [CV] criterion=entropy, max_depth=8, max_features=0.2, n_estimators=800
# [CV]  criterion=entropy, max_depth=8, max_features=0.1, n_estimators=400, score=0.23148148148148148, total=   1.9s
# [CV] criterion=entropy, max_depth=8, max_features=0.2, n_estimators=800
# [CV]  criterion=entropy, max_depth=8, max_features=0.2, n_estimators=200, score=0.23148148148148148, total=   1.1s
# [CV] criterion=entropy, max_depth=8, max_features=0.2, n_estimators=800
# [CV]  criterion=entropy, max_depth=8, max_features=0.1, n_estimators=400, score=0.44166666666666665, total=   1.9s
# [CV] criterion=entropy, max_depth=8, max_features=0.4, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=0.2, n_estimators=800, score=0.525, total=   4.6s
# [CV] criterion=entropy, max_depth=8, max_features=0.4, n_estimators=100
# [CV]  criterion=entropy, max_depth=8, max_features=0.1, n_estimators=400, score=0.3988095238095238, total=   1.9s
# [CV] criterion=entropy, max_depth=8, max_features=0.4, n_estimators=100
# [CV]  criterion=entropy, max_depth=8, max_features=0.1, n_estimators=400, score=0.2916666666666667, total=   2.0s
# [CV] criterion=entropy, max_depth=8, max_features=0.4, n_estimators=100
# [CV]  criterion=entropy, max_depth=8, max_features=0.2, n_estimators=200, score=0.44166666666666665, total=   1.1s
# [CV] criterion=entropy, max_depth=8, max_features=0.4, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=0.2, n_estimators=800, score=0.20833333333333334, total=   4.4s
# [CV]  criterion=entropy, max_depth=8, max_features=0.2, n_estimators=200, score=0.3333333333333333, total=   1.1s
# [CV] criterion=entropy, max_depth=8, max_features=0.4, n_estimators=200
# [CV] criterion=entropy, max_depth=8, max_features=0.4, n_estimators=200
# [CV]  criterion=entropy, max_depth=8, max_features=0.2, n_estimators=200, score=0.22023809523809523, total=   1.1s
# [CV] criterion=entropy, max_depth=8, max_features=0.4, n_estimators=200
# [CV]  criterion=entropy, max_depth=8, max_features=0.2, n_estimators=200, score=0.48809523809523814, total=   1.2s
# [CV]  criterion=entropy, max_depth=8, max_features=0.1, n_estimators=400, score=0.30952380952380953, total=   2.0s
# [CV] criterion=entropy, max_depth=8, max_features=0.4, n_estimators=200
# [CV] criterion=entropy, max_depth=8, max_features=0.4, n_estimators=200
# [CV]  criterion=entropy, max_depth=4, max_features=0.2, n_estimators=800, score=0.3988095238095238, total=   4.6s
# [CV] criterion=entropy, max_depth=8, max_features=0.4, n_estimators=400
# [CV]  criterion=entropy, max_depth=4, max_features=0.2, n_estimators=800, score=0.2619047619047619, total=   4.6s
# [CV] criterion=entropy, max_depth=8, max_features=0.4, n_estimators=400
# [CV]  criterion=entropy, max_depth=8, max_features=0.4, n_estimators=100, score=0.22685185185185186, total=   0.7s
# [CV] criterion=entropy, max_depth=8, max_features=0.4, n_estimators=400
# [CV]  criterion=entropy, max_depth=8, max_features=0.4, n_estimators=100, score=0.32142857142857145, total=   0.7s
# [CV] criterion=entropy, max_depth=8, max_features=0.4, n_estimators=400
# [CV]  criterion=entropy, max_depth=8, max_features=0.4, n_estimators=100, score=0.25, total=   0.7s
# [CV] criterion=entropy, max_depth=8, max_features=0.4, n_estimators=400
# [CV]  criterion=entropy, max_depth=8, max_features=0.4, n_estimators=100, score=0.44166666666666665, total=   0.7s
# [CV]  criterion=entropy, max_depth=8, max_features=0.4, n_estimators=100, score=0.41190476190476194, total=   0.8s
# [CV] criterion=entropy, max_depth=8, max_features=0.4, n_estimators=800
# [CV] criterion=entropy, max_depth=8, max_features=0.4, n_estimators=800
# [CV]  criterion=entropy, max_depth=8, max_features=0.2, n_estimators=400, score=0.26851851851851855, total=   2.3s
# [CV] criterion=entropy, max_depth=8, max_features=0.4, n_estimators=800
# [CV]  criterion=entropy, max_depth=8, max_features=0.4, n_estimators=200, score=0.525, total=   1.5s
# [CV] criterion=entropy, max_depth=8, max_features=0.4, n_estimators=800
# [CV]  criterion=entropy, max_depth=8, max_features=0.4, n_estimators=200, score=0.31666666666666665, total=   1.4s
# [CV] criterion=entropy, max_depth=8, max_features=0.4, n_estimators=800
# [CV]  criterion=entropy, max_depth=8, max_features=0.2, n_estimators=400, score=0.39999999999999997, total=   2.4s
# [CV]  criterion=entropy, max_depth=8, max_features=0.2, n_estimators=400, score=0.2916666666666667, total=   2.4s
# [CV]  criterion=entropy, max_depth=8, max_features=0.4, n_estimators=200, score=0.1898148148148148, total=   1.5s
# [CV]  criterion=entropy, max_depth=8, max_features=0.4, n_estimators=200, score=0.34047619047619043, total=   1.5s
# [CV]  criterion=entropy, max_depth=8, max_features=0.4, n_estimators=200, score=0.44047619047619047, total=   1.5s
# [CV]  criterion=entropy, max_depth=8, max_features=0.2, n_estimators=400, score=0.3988095238095238, total=   2.5s
# [CV]  criterion=entropy, max_depth=8, max_features=0.2, n_estimators=400, score=0.22023809523809523, total=   2.4s
# [CV]  criterion=entropy, max_depth=8, max_features=0.1, n_estimators=800, score=0.3988095238095238, total=   3.9s
# [CV]  criterion=entropy, max_depth=8, max_features=0.1, n_estimators=800, score=0.375, total=   4.0s
# [CV]  criterion=entropy, max_depth=8, max_features=0.1, n_estimators=800, score=0.3055555555555555, total=   4.0s
# [CV]  criterion=entropy, max_depth=8, max_features=0.1, n_estimators=800, score=0.375, total=   4.0s
# [CV]  criterion=entropy, max_depth=4, max_features=0.4, n_estimators=800, score=0.1898148148148148, total=   5.7s
# [CV]  criterion=entropy, max_depth=8, max_features=0.1, n_estimators=800, score=0.30357142857142855, total=   3.9s
# [CV]  criterion=entropy, max_depth=4, max_features=0.4, n_estimators=800, score=0.39999999999999997, total=   6.0s
# [CV]  criterion=entropy, max_depth=8, max_features=0.4, n_estimators=400, score=0.23148148148148148, total=   2.4s
# [CV]  criterion=entropy, max_depth=8, max_features=0.4, n_estimators=400, score=0.5083333333333333, total=   2.4s
# [CV]  criterion=entropy, max_depth=4, max_features=0.4, n_estimators=800, score=0.27499999999999997, total=   5.4s
# [CV]  criterion=entropy, max_depth=4, max_features=0.4, n_estimators=800, score=0.48809523809523814, total=   5.5s
# [CV]  criterion=entropy, max_depth=8, max_features=0.4, n_estimators=400, score=0.27499999999999997, total=   2.5s
# [CV]  criterion=entropy, max_depth=8, max_features=0.4, n_estimators=400, score=0.35714285714285715, total=   2.5s
# [CV]  criterion=entropy, max_depth=4, max_features=0.4, n_estimators=800, score=0.2619047619047619, total=   5.9s
# [CV]  criterion=entropy, max_depth=8, max_features=0.4, n_estimators=400, score=0.22023809523809523, total=   2.6s
# [CV]  criterion=entropy, max_depth=8, max_features=0.2, n_estimators=800, score=0.23148148148148148, total=   3.8s
# [CV]  criterion=entropy, max_depth=8, max_features=0.2, n_estimators=800, score=0.3333333333333333, total=   4.0s
# [CV]  criterion=entropy, max_depth=8, max_features=0.2, n_estimators=800, score=0.44047619047619047, total=   4.0s
# [CV]  criterion=entropy, max_depth=8, max_features=0.2, n_estimators=800, score=0.4166666666666667, total=   4.2s
# [CV]  criterion=entropy, max_depth=8, max_features=0.2, n_estimators=800, score=0.3511904761904762, total=   4.1s
# [CV]  criterion=entropy, max_depth=8, max_features=0.4, n_estimators=800, score=0.23148148148148148, total=   4.2s
# [CV]  criterion=entropy, max_depth=8, max_features=0.4, n_estimators=800, score=0.44166666666666665, total=   4.3s
# [CV]  criterion=entropy, max_depth=8, max_features=0.4, n_estimators=800, score=0.3511904761904762, total=   3.8s
# [Parallel(n_jobs=-1)]: Done 178 out of 180 | elapsed:   14.7s remaining:    0.2s
# [CV]  criterion=entropy, max_depth=8, max_features=0.4, n_estimators=800, score=0.35833333333333334, total=   4.2s
# [CV]  criterion=entropy, max_depth=8, max_features=0.4, n_estimators=800, score=0.26785714285714285, total=   4.2s
# [Parallel(n_jobs=-1)]: Done 180 out of 180 | elapsed:   15.1s finished
# final score for the tuned model
#  0.47883597883597884
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 4, 'max_features': 0.1, 'n_estimators': 400}
#
# cross validation results (MEAN)
#  [0.30326618 0.37466931 0.35080891 0.3760493  0.29272868 0.30034086
#  0.31865588 0.35207443 0.33221408 0.33255749 0.33999161 0.35557718
#  0.35872507 0.37433226 0.40015644 0.35305377 0.37775616 0.34144027
#  0.3326834  0.3152905  0.31500941 0.27065909 0.30391229 0.32068198
#  0.33080103 0.28580332 0.33326211 0.35115232 0.37108771 0.34167557
#  0.31551307 0.35265313 0.32867699 0.36028821 0.31817511 0.32955332]
#
# cross validation results (STD)
#  [0.07900357 0.0719319  0.08314647 0.06891585 0.08325736 0.09914046
#  0.07559321 0.08671182 0.10221612 0.07138206 0.07947609 0.10147916
#  0.08634278 0.06900162 0.04635734 0.10270239 0.11693653 0.11708431
#  0.09455576 0.12810215 0.05261722 0.0981117  0.08739937 0.1066247
#  0.09474248 0.06109552 0.07647399 0.03926345 0.09613741 0.10751922
#  0.07143715 0.07411061 0.08580968 0.11542095 0.10679146 0.07457837]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 1.0000
#
# accuracy on development set: 0.5000
#
# precision on dev set: 0.6683
#
# recall on dev set: 0.4788
#
# fscore on dev set: 0.4165
# ------------------------------------------------------------

# %%
line = '../RESULTS/PV-DM-CONC/' 
names = ['25_5_5_0', '25_5_10_0','25_5_0_1','25_10_5_0','25_10_10_0','25_10_0_1',
         '50_5_5_0', '50_5_10_0','50_5_0_1','50_10_5_0','50_10_10_0','50_10_0_1',
         '75_5_5_0', '75_5_10_0','75_5_0_1','75_10_5_0','75_10_10_0','75_10_0_1',
         '100_5_5_0', '100_5_10_0','100_5_0_1','100_10_5_0','100_10_10_0','100_10_0_1']

# %%
for i in names:
    print (i)
    path = os.path.join(line, i)
    X_train = np.load(os.path.join(path, 'vectors_train.npy'))
    X_dev = np.load(os.path.join(path, 'vectors_dev.npy'))
    y_train = np.load(os.path.join(path, 'labels_train.npy'))
    y_dev = np.load(os.path.join(path, 'labels_dev.npy'))
    y_train = np.ravel(y_train)
    y_dev = np.ravel(y_dev)
    
    feature_name = 'TEXT_'+str(i)
    save_dir = '../RESULTS/PV-DM-CONC/' 
    random_forest = RandomForestCV(feature_name, X_train, y_train, X_dev, y_dev, save_dir)
    random_forest.run()
    print ("------"  * 10)
# Out:
# 25_5_5_0
# [Parallel(n_jobs=-1)]: Done 136 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done 386 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 736 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=-1)]: Done 800 out of 800 | elapsed:    2.5s finished
# [Parallel(n_jobs=32)]: Done 136 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=32)]: Done 386 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=32)]: Done 736 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=32)]: Done 800 out of 800 | elapsed:    0.4s finished
# [Parallel(n_jobs=32)]: Done 136 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=32)]: Done 386 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=32)]: Done 736 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=32)]: Done 800 out of 800 | elapsed:    0.4s finished
# accuracy on training set: 1.0000
#
# accuracy on development set: 0.3500
#
# precision on dev set: 0.3274
#
# recall on dev set: 0.3386
#
# fscore on dev set: 0.3207
# ------------------------------------------------------------
# 25_5_10_0
# [Parallel(n_jobs=-1)]: Done 136 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done 386 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 736 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=-1)]: Done 800 out of 800 | elapsed:    2.4s finished
# [Parallel(n_jobs=32)]: Done 136 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=32)]: Done 386 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=32)]: Done 736 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=32)]: Done 800 out of 800 | elapsed:    0.3s finished
# [Parallel(n_jobs=32)]: Done 136 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=32)]: Done 386 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=32)]: Done 736 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=32)]: Done 800 out of 800 | elapsed:    0.4s finished
# accuracy on training set: 0.8846
#
# accuracy on development set: 0.4167
#
# precision on dev set: 0.4222
#
# recall on dev set: 0.4233
#
# fscore on dev set: 0.4144
# ------------------------------------------------------------
# 25_5_0_1
# [Parallel(n_jobs=-1)]: Done 136 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done 400 out of 400 | elapsed:    1.2s finished
# [Parallel(n_jobs=32)]: Done 136 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=32)]: Done 400 out of 400 | elapsed:    0.2s finished
# [Parallel(n_jobs=32)]: Done 136 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=32)]: Done 400 out of 400 | elapsed:    0.2s finished
# accuracy on training set: 1.0000
#
# accuracy on development set: 0.4667
#
# precision on dev set: 0.4614
#
# recall on dev set: 0.4550
#
# fscore on dev set: 0.4423
# ------------------------------------------------------------
# 25_10_5_0
# [Parallel(n_jobs=-1)]: Done 136 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done 386 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 736 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=-1)]: Done 800 out of 800 | elapsed:    2.5s finished
# [Parallel(n_jobs=32)]: Done 136 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=32)]: Done 386 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=32)]: Done 736 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=32)]: Done 800 out of 800 | elapsed:    0.4s finished
# [Parallel(n_jobs=32)]: Done 136 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=32)]: Done 386 tasks      | elapsed:    0.2s
# accuracy on training set: 1.0000
#
# accuracy on development set: 0.3667
#
# precision on dev set: 0.3479
#
# recall on dev set: 0.3545
#
# fscore on dev set: 0.3335
# ------------------------------------------------------------
# 25_10_10_0
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
# [Parallel(n_jobs=32)]: Done 736 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=32)]: Done 800 out of 800 | elapsed:    0.5s finished
# final score for the tuned model
#  0.35185185185185186
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 8, 'max_features': 0.1, 'n_estimators': 200}
#
# cross validation results (MEAN)
#  [0.31333308 0.34600758 0.33690731 0.35233262 0.35277905 0.34715227
#  0.37595772 0.35175392 0.34334046 0.33510506 0.35209732 0.3577241
#  0.37076084 0.34466321 0.36990359 0.36464947 0.333285   0.3573807
#  0.37140822 0.37942104 0.37180886 0.3488922  0.34674654 0.37180886
#  0.32690909 0.38040039 0.34105744 0.34714718 0.32332112 0.32274242
#  0.3639741  0.37100758 0.36328729 0.33418931 0.34428546 0.36259412]
#
# cross validation results (STD)
#  [0.06862583 0.07545148 0.04048758 0.05472057 0.06145626 0.07761264
#  0.06492135 0.07116241 0.05087727 0.03249393 0.06940945 0.0665406
#  0.06810931 0.05625784 0.04006701 0.04361779 0.09155963 0.05093304
#  0.06459    0.05954144 0.10696793 0.06159113 0.05610828 0.06641293
#  0.08221257 0.07940355 0.05764536 0.09513552 0.05504836 0.06436323
#  0.06950187 0.07281204 0.08634571 0.05744696 0.05921548 0.0872786 ]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 1.0000
#
# accuracy on development set: 0.3667
#
# precision on dev set: 0.3148
#
# recall on dev set: 0.3519
#
# fscore on dev set: 0.3194
# ------------------------------------------------------------
# 25_10_0_1
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
#
# final score for the tuned model
#  0.5
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 4, 'max_features': 0.2, 'n_estimators': 800}
#
# cross validation results (MEAN)
#  [0.35240766 0.31396775 0.28292252 0.29974944 0.29718534 0.34860475
#  0.36130571 0.31378968 0.36136803 0.32788716 0.35549196 0.36332672
#  0.37398504 0.30747227 0.33425799 0.33558074 0.33986696 0.33451109
#  0.34325015 0.39018747 0.35396953 0.35403185 0.37438441 0.38746312
#  0.31913665 0.36545075 0.34747914 0.33163156 0.37294338 0.34620981
#  0.35430784 0.33964438 0.34956247 0.31672772 0.33796169 0.35350656]
#
# cross validation results (STD)
#  [0.05383846 0.02657068 0.04809923 0.03037139 0.04522736 0.07750674
#  0.06364244 0.05030329 0.03973245 0.05788505 0.05705173 0.03897969
#  0.05817288 0.06594093 0.08195246 0.08647295 0.04504269 0.09074903
#  0.06324877 0.10209292 0.07125107 0.1114827  0.0669758  0.07961041
#  0.06044164 0.05902462 0.07442261 0.05439044 0.03293047 0.07979292
#  0.08472931 0.05105484 0.05152252 0.07805207 0.08323757 0.05175963]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 1.0000
#
# accuracy on development set: 0.5167
#
# precision on dev set: 0.4952
#
# recall on dev set: 0.5000
#
# fscore on dev set: 0.4730
# ------------------------------------------------------------
# 50_5_5_0
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
#
# final score for the tuned model
#  0.4920634920634921
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 8, 'max_features': 0.1, 'n_estimators': 200}
#
# cross validation results (MEAN)
#  [0.34127493 0.31825524 0.30182896 0.31138711 0.3545991  0.31218839
#  0.34103454 0.36701898 0.35810312 0.33456705 0.3437589  0.33766916
#  0.37755647 0.34393697 0.34275794 0.35469704 0.34355922 0.37813518
#  0.3599855  0.36385455 0.37280601 0.35671805 0.38458486 0.32905601
#  0.38326211 0.42665217 0.35956705 0.35075295 0.36597222 0.39088065
#  0.34251755 0.35934447 0.31980184 0.32905601 0.34750331 0.37657204]
#
# cross validation results (STD)
#  [0.06714661 0.07699879 0.08809455 0.06576799 0.05147546 0.02979488
#  0.0682502  0.08558412 0.07628158 0.10043743 0.09118788 0.08365571
#  0.05214039 0.07959834 0.09076164 0.09435872 0.02861216 0.07760123
#  0.0675113  0.06561948 0.08133636 0.07550101 0.0587293  0.09057034
#  0.04911191 0.10633632 0.09622869 0.0774187  0.0771056  0.08123283
#  0.08854026 0.06665329 0.08628399 0.0753588  0.07541427 0.06723878]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 1.0000
#
# accuracy on development set: 0.5000
#
# precision on dev set: 0.5090
#
# recall on dev set: 0.4921
#
# fscore on dev set: 0.4890
# ------------------------------------------------------------
# 50_5_10_0
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
#
# final score for the tuned model
#  0.34920634920634924
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 2, 'max_features': 0.1, 'n_estimators': 100}
#
# cross validation results (MEAN)
#  [0.39655194 0.36255469 0.38012566 0.37131156 0.33657026 0.36255469
#  0.34670711 0.33829365 0.33771495 0.34669439 0.36329874 0.31419795
#  0.33200422 0.32186737 0.33596993 0.33102488 0.31805556 0.3535409
#  0.3535409  0.3535409  0.33516865 0.35239621 0.33556929 0.33556929
#  0.33532891 0.30618513 0.32261142 0.33142552 0.32895808 0.32094526
#  0.33671398 0.33102488 0.30934447 0.32112332 0.3042964  0.32755647]
#
# cross validation results (STD)
#  [0.1027059  0.08412219 0.09214046 0.11292559 0.08829465 0.08412219
#  0.08269541 0.08569331 0.0925712  0.0812839  0.10559507 0.10540427
#  0.08781679 0.08309632 0.07230159 0.09309354 0.04795624 0.07817183
#  0.07817183 0.07817183 0.08671887 0.07683543 0.08754611 0.09180112
#  0.07724493 0.10326125 0.09802275 0.08269812 0.07673552 0.05430002
#  0.08893815 0.09309354 0.07184894 0.07001108 0.07489817 0.07907454]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 0.7692
#
# accuracy on development set: 0.3667
#
# precision on dev set: 0.2424
#
# recall on dev set: 0.3492
#
# fscore on dev set: 0.2855
# ------------------------------------------------------------
# 50_5_0_1
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
# /home/ceccarelli/.local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# final score for the tuned model
#  0.4656084656084656
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 4, 'max_features': 0.4, 'n_estimators': 100}
#
# cross validation results (MEAN)
#  [0.41690196 0.43751908 0.41880342 0.41994811 0.35859916 0.35058633
#  0.36603327 0.36603327 0.34848138 0.37999847 0.36775666 0.35974384
#  0.39123423 0.45716702 0.42527727 0.43260328 0.38653465 0.40673458
#  0.43005698 0.44710648 0.47975936 0.45215456 0.44055377 0.4224448
#  0.36849054 0.47669668 0.45185694 0.44200117 0.41182336 0.42278312
#  0.44350071 0.45714031 0.35433074 0.43183761 0.47060185 0.45417557]
#
# cross validation results (STD)
#  [0.04805951 0.07325526 0.03002238 0.03222153 0.04038761 0.06192434
#  0.04158663 0.04158663 0.08523519 0.07018378 0.04514934 0.04473549
#  0.0898053  0.06297079 0.07508717 0.05056089 0.07073477 0.12577511
#  0.1046634  0.05908336 0.11167291 0.09088762 0.1130559  0.07847799
#  0.12871879 0.08978746 0.0907545  0.0952111  0.11483435 0.10683442
#  0.07119932 0.09772684 0.09729995 0.08104852 0.11915165 0.10479794]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 1.0000
#
# accuracy on development set: 0.4833
#
# precision on dev set: 0.4616
#
# recall on dev set: 0.4656
#
# fscore on dev set: 0.4260
# ------------------------------------------------------------
# 50_10_5_0
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
#
# final score for the tuned model
#  0.3783068783068783
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 8, 'max_features': 0.2, 'n_estimators': 100}
#
# cross validation results (MEAN)
#  [0.39022054 0.31028694 0.29346001 0.30988629 0.37294719 0.33112027
#  0.34349944 0.30513584 0.30628053 0.31372736 0.33838904 0.33624339
#  0.31246184 0.32788716 0.31872965 0.31929563 0.31957672 0.35687704
#  0.35961793 0.3342122  0.35809676 0.35831934 0.33563797 0.34336971
#  0.37685058 0.3720378  0.36769307 0.34146825 0.39546322 0.36414581
#  0.34146825 0.33305479 0.36571276 0.33896266 0.38223698 0.37674247]
#
# cross validation results (STD)
#  [0.08579067 0.07512337 0.04219345 0.05618414 0.11576487 0.0754886
#  0.04484546 0.03807535 0.03336191 0.06081969 0.06388877 0.0553488
#  0.0695858  0.05262139 0.0772993  0.06634055 0.04604796 0.04197192
#  0.101787   0.10607216 0.10580958 0.1106596  0.12267035 0.09932237
#  0.06179638 0.07534826 0.08122878 0.10040768 0.08075573 0.04950684
#  0.0968534  0.10246152 0.05512975 0.06717629 0.1351209  0.11744348]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 1.0000
#
# accuracy on development set: 0.3833
#
# precision on dev set: 0.3834
#
# recall on dev set: 0.3783
#
# fscore on dev set: 0.3738
# ------------------------------------------------------------
# 50_10_10_0
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
#
# final score for the tuned model
#  0.4708994708994709
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 8, 'max_features': 0.4, 'n_estimators': 100}
#
# cross validation results (MEAN)
#  [0.34662062 0.33780652 0.33786376 0.3294503  0.30575524 0.30420991
#  0.33786376 0.32143747 0.35138762 0.33768569 0.33746312 0.33786376
#  0.30877722 0.31538843 0.32767094 0.32259997 0.32003587 0.324724
#  0.29189306 0.29154965 0.33969017 0.32761371 0.3241453  0.33123601
#  0.3383954  0.34978632 0.34708359 0.33123601 0.35401531 0.36162749
#  0.3448578  0.34439993 0.37867699 0.37295991 0.31578907 0.31084402]
#
# cross validation results (STD)
#  [0.05207742 0.03766512 0.02752501 0.03733741 0.0546389  0.03522581
#  0.02752501 0.04240308 0.06139739 0.05113378 0.01870018 0.04678127
#  0.08374618 0.06580837 0.04666322 0.05199835 0.06125361 0.04690563
#  0.04489137 0.05137304 0.05498629 0.06336515 0.07506219 0.08800485
#  0.1091277  0.05131966 0.06508105 0.04118333 0.0559102  0.06459158
#  0.08521769 0.0663155  0.09475729 0.08153293 0.08021133 0.05573143]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 1.0000
#
# accuracy on development set: 0.4833
#
# precision on dev set: 0.5095
#
# recall on dev set: 0.4709
#
# fscore on dev set: 0.4510
# ------------------------------------------------------------
# 50_10_0_1
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
#
# final score for the tuned model
#  0.36772486772486773
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 2, 'max_features': 0.4, 'n_estimators': 800}
#
# cross validation results (MEAN)
#  [0.36236518 0.36153465 0.37273479 0.37273479 0.43277371 0.41463675
#  0.42147054 0.41420177 0.43355846 0.42087022 0.406933   0.46608415
#  0.43410791 0.44473062 0.4424069  0.43799985 0.40451898 0.39811381
#  0.37996413 0.39713446 0.4454912  0.42685694 0.38781161 0.40069444
#  0.40289861 0.39656848 0.37917557 0.40400259 0.43147003 0.38781161
#  0.40938899 0.40480388 0.37332494 0.4056802  0.43967745 0.44402727]
#
# cross validation results (STD)
#  [0.0674044  0.06822087 0.05666675 0.05666675 0.06746215 0.04803278
#  0.09847156 0.08864052 0.10017222 0.07543467 0.12122236 0.04789488
#  0.06105331 0.11161223 0.08460038 0.07354381 0.09496373 0.05866787
#  0.05580506 0.05973903 0.05850163 0.07904181 0.05979908 0.07244523
#  0.07466815 0.10112734 0.07999105 0.06429064 0.08408334 0.05718986
#  0.07715679 0.04931623 0.09483303 0.07969107 0.08625416 0.08471596]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 0.7308
#
# accuracy on development set: 0.3833
#
# precision on dev set: 0.3464
#
# recall on dev set: 0.3677
#
# fscore on dev set: 0.3303
# ------------------------------------------------------------
# 75_5_5_0
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
#
# final score for the tuned model
#  0.3095238095238095
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 4, 'max_features': 0.4, 'n_estimators': 400}
#
# cross validation results (MEAN)
#  [0.3108084  0.2934155  0.30125025 0.30966372 0.29095442 0.25255011
#  0.28500204 0.30125025 0.25655652 0.30640135 0.30680199 0.28214031
#  0.3022703  0.32286325 0.33598647 0.29687882 0.33029736 0.31225071
#  0.31132479 0.31505011 0.29441774 0.33632479 0.34568198 0.3130698
#  0.23524369 0.27656695 0.30788436 0.31188568 0.29525845 0.31521546
#  0.31972044 0.28823006 0.32374466 0.32813899 0.28880876 0.3167735 ]
#
# cross validation results (STD)
#  [0.05212487 0.04976418 0.05600923 0.06290205 0.06346411 0.0340483
#  0.05904911 0.05600923 0.07433732 0.08318036 0.07192551 0.08582975
#  0.08693041 0.04592859 0.07171781 0.0406602  0.04514919 0.0577732
#  0.06133402 0.04892628 0.05247955 0.06263748 0.04647629 0.05454468
#  0.08536036 0.0709539  0.05328879 0.05048308 0.07423443 0.07371616
#  0.05132853 0.04933672 0.09929191 0.0735267  0.05121967 0.04006464]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 1.0000
#
# accuracy on development set: 0.3167
#
# precision on dev set: 0.3071
#
# recall on dev set: 0.3095
#
# fscore on dev set: 0.3042
# ------------------------------------------------------------
# 75_5_10_0
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
#
# final score for the tuned model
#  0.40211640211640215
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 8, 'max_features': 0.1, 'n_estimators': 400}
#
# cross validation results (MEAN)
#  [0.30245218 0.3352704  0.34640822 0.36340049 0.33394765 0.3295813
#  0.33873881 0.33741606 0.35958995 0.3426422  0.3211106  0.32191188
#  0.35416412 0.32475198 0.30996769 0.35592567 0.3765148  0.3534824
#  0.3753574  0.34809091 0.33715914 0.3372965  0.35470213 0.34540725
#  0.34666514 0.38631716 0.38649522 0.37808176 0.34530423 0.34140084
#  0.33224334 0.36606253 0.36385455 0.3384768  0.33827584 0.34540725]
#
# cross validation results (STD)
#  [0.06060505 0.03373299 0.05338962 0.07604907 0.09466621 0.03115662
#  0.0626985  0.05476281 0.11834244 0.07659099 0.06318781 0.04927097
#  0.10247823 0.07789287 0.10068367 0.08536317 0.09846513 0.09406523
#  0.09772169 0.10625905 0.08686369 0.08351131 0.09183616 0.11825203
#  0.055008   0.06746815 0.08716652 0.11155563 0.10124586 0.07939767
#  0.07413328 0.10263723 0.0922416  0.05953477 0.08301787 0.11825203]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 1.0000
#
# accuracy on development set: 0.4167
#
# precision on dev set: 0.3741
#
# recall on dev set: 0.4021
#
# fscore on dev set: 0.3816
# ------------------------------------------------------------
# 75_5_0_1
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
#
# final score for the tuned model
#  0.42328042328042326
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 4, 'max_features': 0.4, 'n_estimators': 400}
#
# cross validation results (MEAN)
#  [0.33873245 0.35149573 0.38555021 0.36030983 0.37440731 0.35630342
#  0.35790598 0.36271368 0.32421907 0.36369302 0.39197828 0.33610602
#  0.37942104 0.39213853 0.39179513 0.4093661  0.41396902 0.33720111
#  0.42597044 0.41755698 0.39335317 0.41715634 0.44132072 0.4099448
#  0.41347044 0.39015822 0.41557667 0.41790039 0.38869429 0.3684562
#  0.34287241 0.37572497 0.35109763 0.39255189 0.39393697 0.39022817]
#
# cross validation results (STD)
#  [0.06630864 0.09393697 0.06543644 0.06299499 0.08961641 0.05811787
#  0.05591613 0.05364435 0.10348381 0.09698665 0.08840488 0.08615926
#  0.06503031 0.09857732 0.08891508 0.09387844 0.13395343 0.09253081
#  0.09833158 0.08707118 0.08731221 0.08718657 0.09981118 0.11110023
#  0.12604405 0.03818274 0.07648282 0.07113005 0.10870389 0.08296369
#  0.08112444 0.09117042 0.05432779 0.10582469 0.05947219 0.09886933]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 1.0000
#
# accuracy on development set: 0.4333
#
# precision on dev set: 0.4300
#
# recall on dev set: 0.4233
#
# fscore on dev set: 0.4140
# ------------------------------------------------------------
# 75_10_5_0
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
#
# final score for the tuned model
#  0.3333333333333333
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 4, 'max_features': 0.1, 'n_estimators': 100}
#
# cross validation results (MEAN)
#  [0.3202241  0.32096815 0.28731431 0.28691367 0.27757809 0.28811559
#  0.27054462 0.28811559 0.27855744 0.25297365 0.25411834 0.28731431
#  0.35015771 0.33320996 0.30031288 0.31616046 0.33025794 0.30860551
#  0.28939255 0.28508852 0.29916819 0.31417506 0.28394383 0.26711691
#  0.33837378 0.32555327 0.33138482 0.30752442 0.32322955 0.30992827
#  0.28486594 0.29287876 0.2667735  0.3063403  0.32316723 0.30780423]
#
# cross validation results (STD)
#  [0.06670311 0.07009171 0.07715578 0.0846921  0.06792818 0.079178
#  0.07257429 0.05643251 0.08550454 0.08990222 0.09072488 0.04588422
#  0.10512384 0.07587721 0.06619039 0.06609051 0.05057257 0.06775407
#  0.07287683 0.07553486 0.06465769 0.07170086 0.04892605 0.05703467
#  0.07369322 0.0778917  0.0968808  0.08348934 0.04618389 0.07676102
#  0.07799358 0.06957014 0.04111746 0.07432089 0.06353591 0.04985538]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 0.9615
#
# accuracy on development set: 0.3500
#
# precision on dev set: 0.2593
#
# recall on dev set: 0.3333
#
# fscore on dev set: 0.2834
# ------------------------------------------------------------
# 75_10_10_0
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
#
# final score for the tuned model
#  0.4788359788359789
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 8, 'max_features': 0.4, 'n_estimators': 400}
#
# cross validation results (MEAN)
#  [0.29265873 0.27565374 0.27583181 0.27350809 0.28781034 0.28895503
#  0.28112027 0.27328551 0.2985259  0.28971179 0.28971179 0.28129833
#  0.32651353 0.33126399 0.31205612 0.32244989 0.34050163 0.29394714
#  0.33275209 0.34076491 0.31606253 0.33927681 0.34803368 0.32319394
#  0.34655194 0.3211335  0.33561381 0.33601445 0.3406568  0.32497456
#  0.30716829 0.33126399 0.31733949 0.31993157 0.36368157 0.35486747]
#
# cross validation results (STD)
#  [0.03140075 0.02516316 0.0271339  0.04374163 0.04152387 0.03262968
#  0.02672401 0.0286572  0.04948905 0.03774598 0.03774598 0.04088568
#  0.05806779 0.06151983 0.09276757 0.07532907 0.04350219 0.05282815
#  0.0500098  0.06576691 0.05718017 0.06933811 0.0674466  0.05275547
#  0.05293945 0.07196279 0.06245589 0.02882588 0.08622032 0.04301757
#  0.02741165 0.02743625 0.07601054 0.06312355 0.06416613 0.06110634]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 1.0000
#
# accuracy on development set: 0.4833
#
# precision on dev set: 0.4879
#
# recall on dev set: 0.4788
#
# fscore on dev set: 0.4799
# ------------------------------------------------------------
# 75_10_0_1
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
#
# final score for the tuned model
#  0.42063492063492064
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 8, 'max_features': 0.1, 'n_estimators': 100}
#
# cross validation results (MEAN)
#  [0.34646037 0.37064637 0.36223291 0.36241097 0.40210877 0.36775666
#  0.39878917 0.39878917 0.40681853 0.40331578 0.39861111 0.40622329
#  0.42618793 0.42322319 0.39303775 0.39269434 0.38764627 0.41100936
#  0.4045813  0.41942282 0.39780474 0.41043066 0.41635506 0.38962658
#  0.47066417 0.43185923 0.38821225 0.41043066 0.41986416 0.35802808
#  0.40661884 0.41392832 0.41721357 0.38724562 0.37454467 0.4011078 ]
#
# cross validation results (STD)
#  [0.06797207 0.07010519 0.07989539 0.10417199 0.05274986 0.05277783
#  0.05129589 0.05129589 0.03999748 0.0540092  0.02876542 0.05546216
#  0.05012052 0.04407743 0.0596388  0.06348865 0.07042708 0.05013699
#  0.07592065 0.05836075 0.02992801 0.05819504 0.06729454 0.05798534
#  0.07606681 0.05621382 0.04781265 0.05636314 0.09363396 0.04160933
#  0.0400681  0.04282247 0.11488136 0.07853527 0.05309753 0.05250931]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 1.0000
#
# accuracy on development set: 0.4333
#
# precision on dev set: 0.4076
#
# recall on dev set: 0.4206
#
# fscore on dev set: 0.4048
# ------------------------------------------------------------
# 100_5_5_0
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
#
# final score for the tuned model
#  0.3201058201058201
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 8, 'max_features': 0.1, 'n_estimators': 200}
#
# cross validation results (MEAN)
#  [0.31963523 0.33795024 0.35494251 0.32014398 0.31997863 0.29513889
#  0.33777218 0.32014398 0.30549832 0.3213459  0.31293244 0.30491962
#  0.3164708  0.36166819 0.34780601 0.31699608 0.34217923 0.33080103
#  0.31403643 0.32535231 0.36485551 0.32941595 0.32535231 0.32593101
#  0.38007987 0.38144714 0.36015084 0.37525438 0.36108949 0.32116784
#  0.36549654 0.32615359 0.37681242 0.35553775 0.34704925 0.32535231]
#
# cross validation results (STD)
#  [0.06515717 0.07117504 0.07533368 0.09609019 0.06876919 0.07022863
#  0.0614143  0.09609019 0.05701923 0.08259447 0.07873238 0.05467037
#  0.09075114 0.07324173 0.08882831 0.07576884 0.07700372 0.07554885
#  0.10226837 0.07695712 0.04073781 0.06219213 0.07695712 0.08254689
#  0.07818222 0.05783416 0.06358548 0.04997644 0.06928034 0.04353602
#  0.04289854 0.05879658 0.05417376 0.03160328 0.04566425 0.07695712]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 1.0000
#
# accuracy on development set: 0.3333
#
# precision on dev set: 0.2914
#
# recall on dev set: 0.3201
#
# fscore on dev set: 0.2902
# ------------------------------------------------------------
# 100_5_10_0
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
#
# final score for the tuned model
#  0.3994708994708995
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 4, 'max_features': 0.4, 'n_estimators': 400}
#
# cross validation results (MEAN)
#  [0.35272182 0.38539632 0.37698286 0.39380978 0.4163258  0.36015593
#  0.35294439 0.37818478 0.35684778 0.36555886 0.39268798 0.40831298
#  0.36982855 0.41775031 0.41520401 0.41400209 0.36630291 0.40366555
#  0.38916234 0.3975758  0.35444012 0.40435999 0.4515377  0.39855515
#  0.407747   0.38643798 0.37291412 0.38155016 0.40285918 0.38212887
#  0.41520401 0.40679055 0.40177681 0.37940451 0.39565273 0.40696861]
#
# cross validation results (STD)
#  [0.06563517 0.05674211 0.06614758 0.06119785 0.07874478 0.08591931
#  0.06820773 0.05840636 0.07511716 0.06698223 0.03915803 0.05256259
#  0.04933616 0.04479719 0.06889615 0.02738009 0.04488855 0.06097964
#  0.05770111 0.04436936 0.07170873 0.0840513  0.03831874 0.01814291
#  0.09253049 0.08918856 0.05169188 0.07427472 0.03157238 0.04105233
#  0.04524278 0.0433751  0.0804748  0.05610042 0.08857535 0.0352774 ]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 1.0000
#
# accuracy on development set: 0.4167
#
# precision on dev set: 0.3466
#
# recall on dev set: 0.3995
#
# fscore on dev set: 0.3636
# ------------------------------------------------------------
# 100_5_0_1
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
#
# final score for the tuned model
#  0.35978835978835977
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 4, 'max_features': 0.2, 'n_estimators': 100}
#
# cross validation results (MEAN)
#  [0.4108313  0.4440845  0.41884412 0.4222095  0.4048166  0.43080103
#  0.44368386 0.42947828 0.42498728 0.43776709 0.45704238 0.44219577
#  0.42510684 0.44456019 0.45337429 0.4625318  0.48515084 0.41739672
#  0.44490359 0.41427172 0.45069063 0.47206197 0.44984356 0.45395299
#  0.45842236 0.47398504 0.44902447 0.46505011 0.38650794 0.44936788
#  0.45852539 0.47495167 0.40787927 0.43474512 0.43787012 0.46751755]
#
# cross validation results (STD)
#  [0.04310933 0.0802922  0.04399341 0.06063221 0.08572919 0.11657622
#  0.08499374 0.08007326 0.0913731  0.0502633  0.07013784 0.05854132
#  0.09916633 0.05704514 0.0716679  0.06955575 0.06909949 0.06463321
#  0.07859954 0.06468142 0.11500297 0.09895301 0.06170967 0.05956185
#  0.07324817 0.11861625 0.07010165 0.0855656  0.07620904 0.06718542
#  0.08889112 0.07798937 0.08557185 0.06116809 0.09956409 0.08919885]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 1.0000
#
# accuracy on development set: 0.3667
#
# precision on dev set: 0.3589
#
# recall on dev set: 0.3598
#
# fscore on dev set: 0.3560
# ------------------------------------------------------------
# 100_10_5_0
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
#
# final score for the tuned model
#  0.373015873015873
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 8, 'max_features': 0.4, 'n_estimators': 800}
#
# cross validation results (MEAN)
#  [0.28662622 0.26178648 0.2942384  0.2942384  0.28796169 0.2774242
#  0.30357397 0.29458181 0.22754502 0.26116326 0.2746248  0.30976674
#  0.30139398 0.29752493 0.33476674 0.33378739 0.31124975 0.31295406
#  0.25430784 0.28944979 0.27168422 0.32879274 0.31607524 0.3000496
#  0.27428775 0.29652778 0.31090634 0.3105057  0.33736645 0.31635506
#  0.29774751 0.32298789 0.30604014 0.31910104 0.32803597 0.34502824]
#
# cross validation results (STD)
#  [0.07181036 0.0777709  0.07729436 0.10296515 0.06396938 0.07549641
#  0.0863825  0.09431854 0.04618591 0.06112871 0.0840777  0.09345874
#  0.12481129 0.12779818 0.09073935 0.09075453 0.06987505 0.08537375
#  0.0635575  0.07618387 0.11949097 0.1229748  0.14777844 0.10749091
#  0.09602172 0.06515263 0.07137222 0.09298312 0.09698666 0.05872789
#  0.08420599 0.108746   0.11431657 0.12093172 0.10745005 0.1115039 ]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 1.0000
#
# accuracy on development set: 0.3833
#
# precision on dev set: 0.3622
#
# recall on dev set: 0.3730
#
# fscore on dev set: 0.3502
# ------------------------------------------------------------
# 100_10_10_0
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
#
# final score for the tuned model
#  0.41005291005291006
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 8, 'max_features': 0.4, 'n_estimators': 200}
#
# cross validation results (MEAN)
#  [0.326904   0.30927579 0.34367369 0.35521215 0.37714947 0.33700524
#  0.35271037 0.32676664 0.37282764 0.35693936 0.37372176 0.35248779
#  0.30876068 0.35706019 0.38037749 0.36314993 0.35042735 0.34147589
#  0.3761485  0.36258394 0.3323985  0.34956883 0.33159722 0.34922543
#  0.37482575 0.34904736 0.35473647 0.37196403 0.35137108 0.34939077
#  0.3406339  0.34081197 0.34776531 0.38320996 0.34023326 0.34370167]
#
# cross validation results (STD)
#  [0.03367312 0.05553307 0.03105162 0.05888727 0.02077167 0.04883895
#  0.03651562 0.04392221 0.03651748 0.05029237 0.03659195 0.03011277
#  0.03840514 0.05032033 0.06665296 0.05760859 0.03812558 0.05687327
#  0.06615051 0.04906412 0.04752872 0.06457193 0.0674822  0.05137526
#  0.0329695  0.04618157 0.05186163 0.06937491 0.07577694 0.05297418
#  0.04941182 0.05418824 0.0667229  0.07649601 0.06877632 0.07750632]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 1.0000
#
# accuracy on development set: 0.4167
#
# precision on dev set: 0.4175
#
# recall on dev set: 0.4101
#
# fscore on dev set: 0.4067
# ------------------------------------------------------------
# 100_10_0_1
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
#
# final score for the tuned model
#  0.35714285714285715
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 4, 'max_features': 0.1, 'n_estimators': 200}
#
# cross validation results (MEAN)
#  [0.42375992 0.44196683 0.44178877 0.42381716 0.40183913 0.40658959
#  0.41506029 0.42347375 0.41227361 0.41540369 0.41055021 0.40779151
#  0.43568758 0.45696734 0.45484966 0.4409417  0.42040598 0.4273199
#  0.4412851  0.43138355 0.39366097 0.41455662 0.42411477 0.41495726
#  0.41633725 0.41792201 0.43252824 0.41455662 0.37409188 0.38897283
#  0.37615232 0.40614316 0.41633725 0.38440044 0.41112892 0.41896368]
#
# cross validation results (STD)
#  [0.11849559 0.10289748 0.11705917 0.10909161 0.13568902 0.07282458
#  0.1017851  0.09478564 0.08563178 0.10629449 0.09404096 0.09982748
#  0.12188179 0.11819226 0.06101016 0.08590886 0.12040189 0.09081971
#  0.10844107 0.13662995 0.10625155 0.10041116 0.11701805 0.12705971
#  0.15728743 0.10904963 0.10901618 0.08071423 0.09590506 0.10372017
#  0.10091684 0.12609118 0.09578215 0.09508739 0.1020059  0.09164803]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 1.0000
#
# accuracy on development set: 0.3667
#
# precision on dev set: 0.3685
#
# recall on dev set: 0.3571
#
# fscore on dev set: 0.3462
# ------------------------------------------------------------

# %%
line = '../RESULTS/PV-DBOW/' 
names = ['25_5_5_0', '25_5_10_0','25_5_0_1',
         '50_5_5_0', '50_5_10_0','50_5_0_1',
         '75_5_5_0', '75_5_10_0','75_5_0_1',
         '100_5_5_0', '100_5_10_0','100_5_0_1']

for i in names:
    print (i)
    path = os.path.join(line, i)
    X_train = np.load(os.path.join(path, 'vectors_train.npy'))
    X_dev = np.load(os.path.join(path, 'vectors_dev.npy'))
    y_train = np.load(os.path.join(path, 'labels_train.npy'))
    y_dev = np.load(os.path.join(path, 'labels_dev.npy'))
    y_train = np.ravel(y_train)
    y_dev = np.ravel(y_dev)
    
    feature_name = 'TEXT_'+str(i)
    save_dir = '../RESULTS/PV-DBOW/' 
    random_forest = RandomForestCV(feature_name, X_train, y_train, X_dev, y_dev, save_dir)
    random_forest.run()
    print ("------"  * 10)
# Out:
# 25_5_5_0
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
#
# final score for the tuned model
#  0.48412698412698413
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 4, 'max_features': 0.4, 'n_estimators': 100}
#
# cross validation results (MEAN)
#  [0.38046144 0.38400488 0.38440553 0.37541336 0.38500076 0.37342796
#  0.39524573 0.38568758 0.39746642 0.37899115 0.40652091 0.38894994
#  0.40582774 0.36575855 0.3712645  0.34864545 0.37979879 0.3968661
#  0.36142654 0.39628739 0.46898148 0.40301307 0.40237714 0.44003739
#  0.36278872 0.38814866 0.42430937 0.39419897 0.40856481 0.43216829
#  0.42569444 0.39540598 0.38217974 0.39065553 0.35905703 0.40039174]
#
# cross validation results (STD)
#  [0.07400516 0.07609741 0.0833356  0.07042404 0.10400655 0.07198909
#  0.09989018 0.07154257 0.07612881 0.10059399 0.1046911  0.08647301
#  0.06745409 0.06773895 0.08097887 0.0988753  0.0923493  0.12106719
#  0.10118666 0.12061672 0.05830537 0.08070596 0.09838162 0.06770951
#  0.06882968 0.0638332  0.10130016 0.12195278 0.0883373  0.08805674
#  0.11943563 0.10075215 0.05393774 0.09021246 0.08186505 0.08698838]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 1.0000
#
# accuracy on development set: 0.5000
#
# precision on dev set: 0.4712
#
# recall on dev set: 0.4841
#
# fscore on dev set: 0.4598
# ------------------------------------------------------------
# 25_5_10_0
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
#
# final score for the tuned model
#  0.4708994708994709
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 8, 'max_features': 0.2, 'n_estimators': 400}
#
# cross validation results (MEAN)
#  [0.36867877 0.35185185 0.39500661 0.40244073 0.33245574 0.34710139
#  0.32701211 0.34894943 0.38144587 0.36537571 0.35696225 0.3579416
#  0.38964311 0.34168066 0.4049247  0.39651124 0.32933074 0.36737892
#  0.38414861 0.38414861 0.33568885 0.40051765 0.37722324 0.38449201
#  0.39971128 0.37382987 0.3665611  0.35403821 0.35954416 0.41525616
#  0.41774522 0.38409137 0.37489443 0.37613579 0.38489265 0.36846637]
#
# cross validation results (STD)
#  [0.08077222 0.07764195 0.10710582 0.10513805 0.05507546 0.09830615
#  0.07579312 0.06362454 0.09006776 0.11085783 0.11751395 0.10107832
#  0.07867095 0.05415579 0.10367289 0.09127445 0.06250717 0.07319395
#  0.08328678 0.08328678 0.08826585 0.12054033 0.11361154 0.10419057
#  0.12667506 0.10306585 0.1088876  0.09950264 0.0729896  0.07460874
#  0.09565366 0.10748516 0.07698754 0.09111212 0.09685699 0.08508867]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 1.0000
#
# accuracy on development set: 0.4833
#
# precision on dev set: 0.4572
#
# recall on dev set: 0.4709
#
# fscore on dev set: 0.4585
# ------------------------------------------------------------
# 25_5_0_1
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
#
# final score for the tuned model
#  0.3518518518518518
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 4, 'max_features': 0.4, 'n_estimators': 100}
#
# cross validation results (MEAN)
#  [0.3343254  0.37667888 0.3587645  0.39539454 0.38712988 0.38258547
#  0.34582952 0.35418574 0.34059956 0.35724842 0.33967745 0.33689077
#  0.39989952 0.36886701 0.36839133 0.37319902 0.36324023 0.39669439
#  0.37070996 0.38810287 0.41978912 0.35059269 0.33514576 0.33514576
#  0.35529736 0.3534824  0.36973062 0.38249389 0.36419795 0.35658578
#  0.38670126 0.39397003 0.34355922 0.35346078 0.35428368 0.36072955]
#
# cross validation results (STD)
#  [0.05788796 0.06535512 0.04830706 0.07673225 0.0957592  0.08033691
#  0.07362323 0.05397619 0.07976172 0.07743628 0.08433058 0.08429666
#  0.07180135 0.0512433  0.05163394 0.07851982 0.12037656 0.09596343
#  0.07205764 0.06231371 0.05909136 0.0702805  0.08607968 0.08443496
#  0.05670152 0.06164568 0.08281853 0.03657106 0.07965866 0.06932013
#  0.06274445 0.05828748 0.0969316  0.06579543 0.04628777 0.08389569]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 0.9904
#
# accuracy on development set: 0.3667
#
# precision on dev set: 0.3122
#
# recall on dev set: 0.3519
#
# fscore on dev set: 0.3274
# ------------------------------------------------------------
# 50_5_5_0
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
#
# final score for the tuned model
#  0.4074074074074074
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 4, 'max_features': 0.4, 'n_estimators': 200}
#
# cross validation results (MEAN)
#  [0.40923255 0.35281848 0.30125025 0.31801994 0.3346688  0.32511065
#  0.36826542 0.38583639 0.39738757 0.33281695 0.39244251 0.37545024
#  0.31958181 0.34928775 0.35038792 0.36844348 0.34621998 0.34634081
#  0.34928775 0.37917557 0.38428597 0.40992699 0.40111289 0.35827991
#  0.38078322 0.38500839 0.36628002 0.37677681 0.36803266 0.36779736
#  0.36721866 0.3799069  0.31446759 0.31781517 0.35295584 0.36628002]
#
# cross validation results (STD)
#  [0.0685907  0.07772857 0.09918519 0.10549324 0.07961292 0.05678704
#  0.09981249 0.10680915 0.07502204 0.10743743 0.10151281 0.08773963
#  0.01912218 0.08021376 0.12897225 0.11620829 0.06338402 0.08148249
#  0.08444655 0.08686148 0.07687458 0.06744349 0.08700256 0.06844033
#  0.0724437  0.10304923 0.09014498 0.08467697 0.04719585 0.0723505
#  0.06509935 0.08060392 0.07804246 0.04508491 0.07621077 0.09244886]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 1.0000
#
# accuracy on development set: 0.4167
#
# precision on dev set: 0.4069
#
# recall on dev set: 0.4074
#
# fscore on dev set: 0.3981
# ------------------------------------------------------------
# 50_5_10_0
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
#
# final score for the tuned model
#  0.42063492063492064
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 4, 'max_features': 0.1, 'n_estimators': 800}
#
# cross validation results (MEAN)
#  [0.34447497 0.37714947 0.37755011 0.39321963 0.3805899  0.36416361
#  0.3653083  0.3974041  0.35844017 0.34389627 0.37274242 0.36146724
#  0.33588345 0.35253231 0.41159188 0.41805937 0.34618564 0.39111467
#  0.36930199 0.36226852 0.35964209 0.36204594 0.34076618 0.35473138
#  0.32650336 0.38676486 0.38339947 0.36284722 0.33710317 0.36766
#  0.35260735 0.35631614 0.35849741 0.36428953 0.35903541 0.33716041]
#
# cross validation results (STD)
#  [0.07522458 0.05322492 0.05061156 0.05307006 0.12719273 0.0851836
#  0.08640855 0.11008681 0.10184315 0.08092416 0.10229546 0.09955381
#  0.07814995 0.06621088 0.0546798  0.07339304 0.07827629 0.06925762
#  0.04867132 0.05988658 0.04774019 0.09330387 0.06729319 0.07121621
#  0.06175841 0.028383   0.04038152 0.07233836 0.06366339 0.06336899
#  0.07131443 0.0799097  0.08638355 0.05346586 0.05868211 0.05575003]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 1.0000
#
# accuracy on development set: 0.4333
#
# precision on dev set: 0.4500
#
# recall on dev set: 0.4206
#
# fscore on dev set: 0.4014
# ------------------------------------------------------------
# 50_5_0_1
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
#
# final score for the tuned model
#  0.42063492063492064
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 8, 'max_features': 0.4, 'n_estimators': 200}
#
# cross validation results (MEAN)
#  [0.33640237 0.37251094 0.35148301 0.3667646  0.34510328 0.31709783
#  0.35131766 0.34250356 0.32464642 0.35973113 0.34268162 0.32625534
#  0.34376272 0.33501221 0.30233771 0.31040776 0.33278643 0.33106303
#  0.3019943  0.33302681 0.36830103 0.36828831 0.36324023 0.36724664
#  0.34870396 0.3482906  0.30756258 0.32780067 0.37982677 0.3108084
#  0.33547009 0.32780067 0.31640084 0.39090736 0.35350402 0.32575804]
#
# cross validation results (STD)
#  [0.04168647 0.06858437 0.03504209 0.0362712  0.0804311  0.05356208
#  0.03664064 0.040368   0.05118345 0.02149962 0.06092649 0.06030958
#  0.04385049 0.07456981 0.07704568 0.04892655 0.09034102 0.09608175
#  0.07652077 0.08492887 0.08353383 0.06612055 0.06391206 0.0672327
#  0.04665592 0.0442695  0.0446262  0.04968223 0.09150581 0.05417599
#  0.06581967 0.06841569 0.04821616 0.03297901 0.03571962 0.075182  ]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 1.0000
#
# accuracy on development set: 0.4333
#
# precision on dev set: 0.4077
#
# recall on dev set: 0.4206
#
# fscore on dev set: 0.4052
# ------------------------------------------------------------
# 75_5_5_0
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
# final score for the tuned model
#  0.36772486772486773
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 4, 'max_features': 0.2, 'n_estimators': 200}
#
# cross validation results (MEAN)
#  [0.40323947 0.40347477 0.40843127 0.41718814 0.37941595 0.38138863
#  0.40818707 0.40957596 0.34692842 0.3911948  0.36519765 0.37343305
#  0.33622685 0.34870905 0.38473621 0.38531492 0.34315222 0.44072421
#  0.40142196 0.36179792 0.35391738 0.36668066 0.37735551 0.364535
#  0.36289047 0.35479879 0.38166082 0.36824379 0.41025259 0.38019943
#  0.31759259 0.366846   0.36589082 0.30024929 0.32525438 0.34580662]
#
# cross validation results (STD)
#  [0.08628875 0.07077564 0.05074729 0.07713514 0.05962311 0.06896129
#  0.07128116 0.0524361  0.08640992 0.08699727 0.06205622 0.03342587
#  0.06337578 0.06456923 0.06132135 0.04755793 0.07803374 0.11639397
#  0.10235131 0.09034307 0.08892644 0.07011872 0.09930207 0.07747486
#  0.06446427 0.04618191 0.11079221 0.08795312 0.08934053 0.1022245
#  0.10701484 0.07665905 0.06207444 0.07819091 0.09031108 0.08183646]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 1.0000
#
# accuracy on development set: 0.3833
#
# precision on dev set: 0.3334
#
# recall on dev set: 0.3677
#
# fscore on dev set: 0.3314
# ------------------------------------------------------------
# 75_5_10_0
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
#
# final score for the tuned model
#  0.41534391534391535
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 2, 'max_features': 0.2, 'n_estimators': 200}
#
# cross validation results (MEAN)
#  [0.3298166  0.34279609 0.33552732 0.3192791  0.33754833 0.37358822
#  0.32042379 0.31967974 0.29041132 0.32795584 0.30167379 0.33933405
#  0.3028312  0.29581934 0.28740588 0.28757123 0.31452864 0.35227411
#  0.33853276 0.30968661 0.35908501 0.35518162 0.31489494 0.31850071
#  0.30615588 0.30097044 0.26825524 0.31867877 0.33458359 0.31375025
#  0.31008725 0.31810007 0.32488807 0.36225071 0.35720264 0.34878917]
#
# cross validation results (STD)
#  [0.06976225 0.05138897 0.06250358 0.03876495 0.05770118 0.04571885
#  0.02701212 0.03350306 0.03585629 0.05705244 0.06424619 0.04765794
#  0.03589372 0.0456133  0.05595843 0.04769028 0.04779239 0.07876477
#  0.04730825 0.06432298 0.05760262 0.06785562 0.09561558 0.09467448
#  0.03122914 0.05669935 0.09033461 0.04919929 0.08788587 0.10207495
#  0.0702857  0.06803211 0.06658384 0.02079056 0.04963622 0.05608187]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 0.9038
#
# accuracy on development set: 0.4333
#
# precision on dev set: 0.4617
#
# recall on dev set: 0.4153
#
# fscore on dev set: 0.3565
# ------------------------------------------------------------
# 75_5_0_1
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
#
# final score for the tuned model
#  0.5211640211640212
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 8, 'max_features': 0.2, 'n_estimators': 200}
#
# cross validation results (MEAN)
#  [0.33559091 0.34324761 0.35967389 0.37535613 0.33937856 0.35718483
#  0.40074023 0.38417023 0.35001908 0.41286248 0.39529151 0.364259
#  0.39545177 0.3665204  0.3778808  0.38663767 0.36954238 0.35305886
#  0.40484458 0.38721637 0.40382453 0.40081527 0.44152549 0.42335928
#  0.32763533 0.40378638 0.4365639  0.43638584 0.38611238 0.45086106
#  0.40416285 0.41454009 0.37818987 0.39123932 0.40504426 0.40945131]
#
# cross validation results (STD)
#  [0.10045777 0.06067874 0.05320268 0.05241632 0.07650985 0.04551169
#  0.03383316 0.04413699 0.07036901 0.10954833 0.12043768 0.10832596
#  0.08693411 0.07573052 0.07459169 0.05823613 0.09912312 0.10499406
#  0.0371325  0.06637333 0.10526867 0.09024466 0.07858848 0.06271573
#  0.04990777 0.08446494 0.11392246 0.07060467 0.0924945  0.07219184
#  0.0460225  0.06022333 0.06872786 0.03045761 0.07731723 0.09417068]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 1.0000
#
# accuracy on development set: 0.5333
#
# precision on dev set: 0.5575
#
# recall on dev set: 0.5212
#
# fscore on dev set: 0.5125
# ------------------------------------------------------------
# 100_5_5_0
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
#
# final score for the tuned model
#  0.3703703703703704
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 4, 'max_features': 0.1, 'n_estimators': 100}
#
# cross validation results (MEAN)
#  [0.30313899 0.29323743 0.30914225 0.34210292 0.31086564 0.3484852
#  0.32342287 0.35313263 0.30443249 0.31244531 0.33728505 0.35371133
#  0.43482397 0.37633038 0.37053826 0.33706247 0.33808633 0.37346357
#  0.34747914 0.3689535  0.36088345 0.36286884 0.36350478 0.35172594
#  0.33740079 0.35230464 0.39732397 0.38948921 0.36631436 0.32997176
#  0.3550786  0.40144994 0.36929691 0.31063797 0.3226394  0.33529965]
#
# cross validation results (STD)
#  [0.07227767 0.05105264 0.07235897 0.11906136 0.03861207 0.0701064
#  0.08886784 0.0831208  0.09669406 0.09504347 0.09815526 0.08205599
#  0.04783882 0.10211796 0.07864423 0.07488923 0.07715107 0.10558682
#  0.11010341 0.10935609 0.09393262 0.10750635 0.09167409 0.09370556
#  0.09302515 0.12874849 0.10117331 0.07281463 0.09053424 0.07637099
#  0.09870848 0.10518745 0.03409152 0.07285636 0.07987838 0.08104751]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 1.0000
#
# accuracy on development set: 0.3833
#
# precision on dev set: 0.3547
#
# recall on dev set: 0.3704
#
# fscore on dev set: 0.3495
# ------------------------------------------------------------
# 100_5_10_0
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
#
# final score for the tuned model
#  0.3703703703703704
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 4, 'max_features': 0.2, 'n_estimators': 100}
#
# cross validation results (MEAN)
#  [0.30819979 0.30851903 0.31767654 0.34303775 0.36040268 0.35238986
#  0.33596357 0.31953729 0.31881614 0.3531568  0.34628867 0.37971993
#  0.36866097 0.37535104 0.3121655  0.32949608 0.40650438 0.35103276
#  0.31365359 0.35465761 0.30961411 0.33674323 0.36056929 0.33021851
#  0.32709224 0.31876399 0.33905423 0.31553724 0.3406746  0.34043422
#  0.35958995 0.36818147 0.32487154 0.34594526 0.35936737 0.34254045]
#
# cross validation results (STD)
#  [0.07044824 0.04199685 0.04568737 0.10227373 0.10725207 0.09133039
#  0.08809233 0.10330799 0.09606518 0.10550482 0.07604596 0.06676471
#  0.02116059 0.04896109 0.06138102 0.06261687 0.05418274 0.0556805
#  0.09088343 0.09398317 0.0861559  0.07028207 0.08339394 0.08013883
#  0.064907   0.10157093 0.06559797 0.081644   0.07011416 0.06808009
#  0.07806808 0.05414491 0.07969796 0.09873242 0.07859435 0.08562108]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 1.0000
#
# accuracy on development set: 0.3833
#
# precision on dev set: 0.3526
#
# recall on dev set: 0.3704
#
# fscore on dev set: 0.3492
# ------------------------------------------------------------
# 100_5_0_1
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
#
# final score for the tuned model
#  0.3650793650793651
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 8, 'max_features': 0.2, 'n_estimators': 400}
#
# cross validation results (MEAN)
#  [0.32775616 0.3505291  0.36752137 0.38200168 0.33410282 0.30984178
#  0.3422937  0.34327305 0.36182336 0.34137159 0.33125382 0.32626806
#  0.36753409 0.38315909 0.35924145 0.35871998 0.35127315 0.30840456
#  0.34245905 0.37463116 0.35815146 0.37354879 0.40892603 0.32626806
#  0.37637235 0.37903821 0.39901175 0.40272054 0.33010277 0.38761701
#  0.41686381 0.37898097 0.32331604 0.36523835 0.35037012 0.3583257 ]
#
# cross validation results (STD)
#  [0.09502197 0.06280598 0.07730227 0.10922578 0.06834718 0.07157516
#  0.0884244  0.08720896 0.08974039 0.05825413 0.09407597 0.07097795
#  0.0838631  0.12523338 0.14117816 0.10177065 0.08520275 0.10758698
#  0.09080069 0.08913637 0.07566074 0.06283366 0.1029858  0.07097795
#  0.1300393  0.08475762 0.03876363 0.03752173 0.08027342 0.05574433
#  0.08146908 0.09010775 0.08806123 0.08853155 0.11589656 0.13434908]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 1.0000
#
# accuracy on development set: 0.3833
#
# precision on dev set: 0.2803
#
# recall on dev set: 0.3651
#
# fscore on dev set: 0.3150
# ------------------------------------------------------------

# %%
#combined model avg
models1 = [
    doc2vec.Doc2Vec(dm=1, vector_size=25, window=5, negative=5, hs=0, min_count=2, epochs=100, workers=cores,sample=0,alpha=0.05),
    doc2vec.Doc2Vec(dm=1, vector_size=25, window=5, negative=10, hs=0, min_count=2, epochs=100, workers=cores,sample=0,alpha=0.05),
    doc2vec.Doc2Vec(dm=1, vector_size=25, window=5, negative=0, hs=1, min_count=2, epochs=100, workers=cores,sample=0,alpha=0.05),
    doc2vec.Doc2Vec(dm=1, vector_size=25, window=10, negative=5, hs=0, min_count=2, epochs=100, workers=cores,sample=0,alpha=0.05),
    doc2vec.Doc2Vec(dm=1, vector_size=25, window=10, negative=10, hs=0, min_count=2, epochs=100, workers=cores,sample=0,alpha=0.05),
    doc2vec.Doc2Vec(dm=1, vector_size=25, window=10, negative=0, hs=1, min_count=2, epochs=100, workers=cores,sample=0,alpha=0.05),
    
    doc2vec.Doc2Vec(dm=1, vector_size=50, window=5, negative=5, hs=0, min_count=2, epochs=100, workers=cores,sample=0,alpha=0.05),
    doc2vec.Doc2Vec(dm=1, vector_size=50, window=5, negative=10, hs=0, min_count=2, epochs=100, workers=cores,sample=0,alpha=0.05),
    doc2vec.Doc2Vec(dm=1, vector_size=50, window=5, negative=0, hs=1, min_count=2, epochs=100, workers=cores,sample=0,alpha=0.05),
    doc2vec.Doc2Vec(dm=1, vector_size=50, window=10, negative=5, hs=0, min_count=2, epochs=100, workers=cores,sample=0,alpha=0.05),
    doc2vec.Doc2Vec(dm=1, vector_size=50, window=10, negative=10, hs=0, min_count=2, epochs=100, workers=cores,sample=0,alpha=0.05),
    doc2vec.Doc2Vec(dm=1, vector_size=50, window=10, negative=0, hs=1, min_count=2, epochs=100, workers=cores,sample=0,alpha=0.05),
    
    doc2vec.Doc2Vec(dm=1, vector_size=75, window=5, negative=5, hs=0, min_count=2, epochs=100, workers=cores,sample=0,alpha=0.05),
    doc2vec.Doc2Vec(dm=1, vector_size=75, window=5, negative=10, hs=0, min_count=2, epochs=100, workers=cores,sample=0,alpha=0.05),
    doc2vec.Doc2Vec(dm=1, vector_size=75, window=5, negative=0, hs=1, min_count=2, epochs=100, workers=cores,sample=0,alpha=0.05),
    doc2vec.Doc2Vec(dm=1, vector_size=75, window=10, negative=5, hs=0, min_count=2, epochs=100, workers=cores,sample=0,alpha=0.05),
    doc2vec.Doc2Vec(dm=1, vector_size=75, window=10, negative=10, hs=0, min_count=2, epochs=100, workers=cores,sample=0,alpha=0.05),
    doc2vec.Doc2Vec(dm=1, vector_size=75, window=10, negative=0, hs=1, min_count=2, epochs=100, workers=cores,sample=0,alpha=0.05),
    
    doc2vec.Doc2Vec(dm=1, vector_size=100, window=5, negative=5, hs=0, min_count=2, epochs=100, workers=cores,sample=0,alpha=0.05),
    doc2vec.Doc2Vec(dm=1, vector_size=100, window=5, negative=10, hs=0, min_count=2, epochs=100, workers=cores,sample=0,alpha=0.05),
    doc2vec.Doc2Vec(dm=1, vector_size=100, window=5, negative=0, hs=1, min_count=2, epochs=100, workers=cores,sample=0,alpha=0.05),
    doc2vec.Doc2Vec(dm=1, vector_size=100, window=10, negative=5, hs=0, min_count=2, epochs=100, workers=cores,sample=0,alpha=0.05),
    doc2vec.Doc2Vec(dm=1, vector_size=100, window=10, negative=10, hs=0, min_count=2, epochs=100, workers=cores,sample=0,alpha=0.05),
    doc2vec.Doc2Vec(dm=1, vector_size=100, window=10, negative=0, hs=1, min_count=2, epochs=100, workers=cores,sample=0,alpha=0.05)
]

models2 = [
    doc2vec.Doc2Vec(dm=0, vector_size=25, negative=5, hs=0, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=0, vector_size=25, negative=10, hs=0, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=0, vector_size=25, negative=0, hs=1, min_count=2, epochs=100, workers=cores,sample=0),
    
    doc2vec.Doc2Vec(dm=0, vector_size=50, negative=5, hs=0, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=0, vector_size=50, negative=10, hs=0, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=0, vector_size=50, negative=0, hs=1, min_count=2, epochs=100, workers=cores,sample=0),
    
    doc2vec.Doc2Vec(dm=0, vector_size=75, negative=5, hs=0, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=0, vector_size=75, negative=10, hs=0, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=0, vector_size=75, negative=0, hs=1, min_count=2, epochs=100, workers=cores,sample=0),
    
    doc2vec.Doc2Vec(dm=0, vector_size=100, negative=5, hs=0, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=0, vector_size=100, negative=10, hs=0, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=0, vector_size=100, negative=0, hs=1, min_count=2, epochs=100, workers=cores,sample=0),
    
]

# %%
count = 0
for model in models1:
    print("\nbuilding vocabulary for doc2vec model %i" %count)
    model.build_vocab(all_docs)
    print("\nvocabulary scanned & built.")
    count += 1
    
count = 0
for model in models2:
    print("\nbuilding vocabulary for doc2vec model %i" %count)
    model.build_vocab(all_docs)
    print("\nvocabulary scanned & built.")
    count += 1
# Out:
# building vocabulary for doc2vec model 0
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 1
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 2
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 3
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 4
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 5
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 6
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 7
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 8
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 9
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 10
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 11
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 12
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 13
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 14
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 15
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 16
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 17
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 18
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 19
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 20
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 21
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 22
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 23
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 0
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 1
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 2
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 3
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 4
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 5
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 6
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 7
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 8
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 9
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 10
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 11
#
# vocabulary scanned & built.

# %%
from gensim.test.test_doc2vec import ConcatenatedDoc2Vec

models = [
    ConcatenatedDoc2Vec([models2[0], models1[0]]),
    ConcatenatedDoc2Vec([models2[1], models1[1]]),
    ConcatenatedDoc2Vec([models2[2], models1[2]]),
    ConcatenatedDoc2Vec([models2[0], models1[3]]),
    ConcatenatedDoc2Vec([models2[1], models1[4]]),
    ConcatenatedDoc2Vec([models2[2], models1[5]]),
    
    ConcatenatedDoc2Vec([models2[3], models1[6]]),
    ConcatenatedDoc2Vec([models2[4], models1[7]]),
    ConcatenatedDoc2Vec([models2[5], models1[8]]),
    ConcatenatedDoc2Vec([models2[3], models1[9]]),
    ConcatenatedDoc2Vec([models2[4], models1[10]]),
    ConcatenatedDoc2Vec([models2[5], models1[11]]),
    
    ConcatenatedDoc2Vec([models2[6], models1[12]]),
    ConcatenatedDoc2Vec([models2[7], models1[13]]),
    ConcatenatedDoc2Vec([models2[8], models1[14]]),
    ConcatenatedDoc2Vec([models2[6], models1[15]]),
    ConcatenatedDoc2Vec([models2[7], models1[16]]),
    ConcatenatedDoc2Vec([models2[8], models1[17]]),
    
    ConcatenatedDoc2Vec([models2[9], models1[18]]),
    ConcatenatedDoc2Vec([models2[10], models1[19]]),
    ConcatenatedDoc2Vec([models2[11], models1[20]]),
    ConcatenatedDoc2Vec([models2[9], models1[21]]),
    ConcatenatedDoc2Vec([models2[10], models1[22]]),
    ConcatenatedDoc2Vec([models2[11], models1[23]])

]

# %%
from gensim.models.callbacks import CallbackAny2Vec
class EpochLogger(CallbackAny2Vec):
    '''Callback to log information about training'''
    
    def __init__(self):
        self.epoch = 0
    
    def on_epoch_begin(self, model):
        print("Epoch #{} start".format(self.epoch))
    
    def on_epoch_end(self, model):
        print("Epoch #{} end".format(self.epoch))
        self.epoch += 1
        
epoch_logger = EpochLogger()
count = 0
for model in models1:
    model.train(all_docs, total_examples=len(all_docs), epochs=100)
    print("\nmodel %i trained" %count)
    count += 1
    
count = 0
for model in models2:
    model.train(all_docs, total_examples=len(all_docs), epochs=100)
    print("\nmodel %i trained" %count)
    count += 1
# Out:
# model 0 trained
#
# model 1 trained
#
# model 2 trained
#
# model 3 trained
#
# model 4 trained
#
# model 5 trained
#
# model 6 trained
#
# model 7 trained
#
# model 8 trained
#
# model 9 trained
#
# model 10 trained
#
# model 11 trained
#
# model 12 trained
#
# model 13 trained
#
# model 14 trained
#
# model 15 trained
#
# model 16 trained
#
# model 17 trained
#
# model 18 trained
#
# model 19 trained
#
# model 20 trained
#
# model 21 trained
#
# model 22 trained
#
# model 23 trained
#
# model 0 trained
#
# model 1 trained
#
# model 2 trained
#
# model 3 trained
#
# model 4 trained
#
# model 5 trained
#
# model 6 trained
#
# model 7 trained
#
# model 8 trained
#
# model 9 trained
#
# model 10 trained
#
# model 11 trained

# %%
count = 0
for model in models:
    infer_embedding_combined(model, models1[count], 'train', 'PV-COMBINED-AV')
    infer_embedding_combined(model, models1[count], 'dev', 'PV-COMBINED-AV')
    print("\nembedding inffered for model %i" %count)
    count += 1
# Out:
# saving in  ../RESULTS/PV-COMBINED-AV
# Directory  ../RESULTS/PV-COMBINED-AV/25_5_5_0  Created
# /home/ceccarelli/.local/lib/python3.6/site-packages/smart_open/smart_open_lib.py:402: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# saving inferred vectors and labels to file
# saving in  ../RESULTS/PV-COMBINED-AV
# Directory  ../RESULTS/PV-COMBINED-AV/25_5_5_0  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 0
# saving in  ../RESULTS/PV-COMBINED-AV
# Directory  ../RESULTS/PV-COMBINED-AV/25_5_10_0  Created
#
# saving inferred vectors and labels to file
# saving in  ../RESULTS/PV-COMBINED-AV
# Directory  ../RESULTS/PV-COMBINED-AV/25_5_10_0  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 1
# saving in  ../RESULTS/PV-COMBINED-AV
# Directory  ../RESULTS/PV-COMBINED-AV/25_5_0_1  Created
#
# saving inferred vectors and labels to file
# saving in  ../RESULTS/PV-COMBINED-AV
# Directory  ../RESULTS/PV-COMBINED-AV/25_5_0_1  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 2
# saving in  ../RESULTS/PV-COMBINED-AV
# Directory  ../RESULTS/PV-COMBINED-AV/25_10_5_0  Created
#
# saving inferred vectors and labels to file
# saving in  ../RESULTS/PV-COMBINED-AV
# Directory  ../RESULTS/PV-COMBINED-AV/25_10_5_0  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 3
# saving in  ../RESULTS/PV-COMBINED-AV
# Directory  ../RESULTS/PV-COMBINED-AV/25_10_10_0  Created
#
# saving inferred vectors and labels to file
# saving in  ../RESULTS/PV-COMBINED-AV
# Directory  ../RESULTS/PV-COMBINED-AV/25_10_10_0  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 4
# saving in  ../RESULTS/PV-COMBINED-AV
# Directory  ../RESULTS/PV-COMBINED-AV/25_10_0_1  Created
#
# saving inferred vectors and labels to file
# saving in  ../RESULTS/PV-COMBINED-AV
# Directory  ../RESULTS/PV-COMBINED-AV/25_10_0_1  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 5
# saving in  ../RESULTS/PV-COMBINED-AV
# Directory  ../RESULTS/PV-COMBINED-AV/50_5_5_0  Created
#
# saving inferred vectors and labels to file
# saving in  ../RESULTS/PV-COMBINED-AV
# Directory  ../RESULTS/PV-COMBINED-AV/50_5_5_0  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 6
# saving in  ../RESULTS/PV-COMBINED-AV
# Directory  ../RESULTS/PV-COMBINED-AV/50_5_10_0  Created
#
# saving inferred vectors and labels to file
# saving in  ../RESULTS/PV-COMBINED-AV
# Directory  ../RESULTS/PV-COMBINED-AV/50_5_10_0  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 7
# saving in  ../RESULTS/PV-COMBINED-AV
# Directory  ../RESULTS/PV-COMBINED-AV/50_5_0_1  Created
#
# saving inferred vectors and labels to file
# saving in  ../RESULTS/PV-COMBINED-AV
# Directory  ../RESULTS/PV-COMBINED-AV/50_5_0_1  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 8
# saving in  ../RESULTS/PV-COMBINED-AV
# Directory  ../RESULTS/PV-COMBINED-AV/50_10_5_0  Created
#
# saving inferred vectors and labels to file
# saving in  ../RESULTS/PV-COMBINED-AV
# Directory  ../RESULTS/PV-COMBINED-AV/50_10_5_0  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 9
# saving in  ../RESULTS/PV-COMBINED-AV
# Directory  ../RESULTS/PV-COMBINED-AV/50_10_10_0  Created
#
# saving inferred vectors and labels to file
# saving in  ../RESULTS/PV-COMBINED-AV
# Directory  ../RESULTS/PV-COMBINED-AV/50_10_10_0  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 10
# saving in  ../RESULTS/PV-COMBINED-AV
# Directory  ../RESULTS/PV-COMBINED-AV/50_10_0_1  Created
#
# saving inferred vectors and labels to file
# saving in  ../RESULTS/PV-COMBINED-AV
# Directory  ../RESULTS/PV-COMBINED-AV/50_10_0_1  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 11
# saving in  ../RESULTS/PV-COMBINED-AV
# Directory  ../RESULTS/PV-COMBINED-AV/75_5_5_0  Created
#
# saving inferred vectors and labels to file
# saving in  ../RESULTS/PV-COMBINED-AV
# Directory  ../RESULTS/PV-COMBINED-AV/75_5_5_0  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 12
# saving in  ../RESULTS/PV-COMBINED-AV
# Directory  ../RESULTS/PV-COMBINED-AV/75_5_10_0  Created
#
# saving inferred vectors and labels to file
# saving in  ../RESULTS/PV-COMBINED-AV
# Directory  ../RESULTS/PV-COMBINED-AV/75_5_10_0  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 13
# saving in  ../RESULTS/PV-COMBINED-AV
# Directory  ../RESULTS/PV-COMBINED-AV/75_5_0_1  Created
#
# saving inferred vectors and labels to file
# saving in  ../RESULTS/PV-COMBINED-AV
# Directory  ../RESULTS/PV-COMBINED-AV/75_5_0_1  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 14
# saving in  ../RESULTS/PV-COMBINED-AV
# Directory  ../RESULTS/PV-COMBINED-AV/75_10_5_0  Created
#
# saving inferred vectors and labels to file
# saving in  ../RESULTS/PV-COMBINED-AV
# Directory  ../RESULTS/PV-COMBINED-AV/75_10_5_0  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 15
# saving in  ../RESULTS/PV-COMBINED-AV
# Directory  ../RESULTS/PV-COMBINED-AV/75_10_10_0  Created
#
# saving inferred vectors and labels to file
# saving in  ../RESULTS/PV-COMBINED-AV
# Directory  ../RESULTS/PV-COMBINED-AV/75_10_10_0  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 16
# saving in  ../RESULTS/PV-COMBINED-AV
# Directory  ../RESULTS/PV-COMBINED-AV/75_10_0_1  Created
#
# saving inferred vectors and labels to file
# saving in  ../RESULTS/PV-COMBINED-AV
# Directory  ../RESULTS/PV-COMBINED-AV/75_10_0_1  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 17
# saving in  ../RESULTS/PV-COMBINED-AV
# Directory  ../RESULTS/PV-COMBINED-AV/100_5_5_0  Created
#
# saving inferred vectors and labels to file
# saving in  ../RESULTS/PV-COMBINED-AV
# Directory  ../RESULTS/PV-COMBINED-AV/100_5_5_0  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 18
# saving in  ../RESULTS/PV-COMBINED-AV
# Directory  ../RESULTS/PV-COMBINED-AV/100_5_10_0  Created
#
# saving inferred vectors and labels to file
# saving in  ../RESULTS/PV-COMBINED-AV
# Directory  ../RESULTS/PV-COMBINED-AV/100_5_10_0  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 19
# saving in  ../RESULTS/PV-COMBINED-AV
# Directory  ../RESULTS/PV-COMBINED-AV/100_5_0_1  Created
#
# saving inferred vectors and labels to file
# saving in  ../RESULTS/PV-COMBINED-AV
# Directory  ../RESULTS/PV-COMBINED-AV/100_5_0_1  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 20
# saving in  ../RESULTS/PV-COMBINED-AV
# Directory  ../RESULTS/PV-COMBINED-AV/100_10_5_0  Created
#
# saving inferred vectors and labels to file
# saving in  ../RESULTS/PV-COMBINED-AV
# Directory  ../RESULTS/PV-COMBINED-AV/100_10_5_0  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 21
# saving in  ../RESULTS/PV-COMBINED-AV
# Directory  ../RESULTS/PV-COMBINED-AV/100_10_10_0  Created
#
# saving inferred vectors and labels to file
# saving in  ../RESULTS/PV-COMBINED-AV
# Directory  ../RESULTS/PV-COMBINED-AV/100_10_10_0  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 22
# saving in  ../RESULTS/PV-COMBINED-AV
# Directory  ../RESULTS/PV-COMBINED-AV/100_10_0_1  Created
#
# saving inferred vectors and labels to file
# saving in  ../RESULTS/PV-COMBINED-AV
# Directory  ../RESULTS/PV-COMBINED-AV/100_10_0_1  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 23

# %%
line = '../RESULTS/PV-COMBINED-AV/' 
names = ['25_5_5_0', '25_5_10_0','25_5_0_1','25_10_5_0','25_10_10_0','25_10_0_1',
         '50_5_5_0', '50_5_10_0','50_5_0_1','50_10_5_0','50_10_10_0','50_10_0_1',
         '75_5_5_0', '75_5_10_0','75_5_0_1','75_10_5_0','75_10_10_0','75_10_0_1',
         '100_5_5_0', '100_5_10_0','100_5_0_1','100_10_5_0','100_10_10_0','100_10_0_1']
for i in names:
    path = os.path.join(line, i)
    X_train = np.load(os.path.join(path, 'vectors_train.npy'))
    X_dev = np.load(os.path.join(path, 'vectors_dev.npy'))
    y_train = np.load(os.path.join(path, 'labels_train.npy'))
    y_dev = np.load(os.path.join(path, 'labels_dev.npy'))
    y_train = np.ravel(y_train)
    y_dev = np.ravel(y_dev)
    
    feature_name = 'TEXT_'+str(i)
    save_dir = '../RESULTS/PV-COMBINED-AV/' 
    random_forest = RandomForestCV(feature_name, X_train, y_train, X_dev, y_dev, save_dir)
    random_forest.run()
    print ("------"  * 10)
# Out:
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
#
# final score for the tuned model
#  0.41798941798941797
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 8, 'max_features': 0.1, 'n_estimators': 800}
#
# cross validation results (MEAN)
#  [0.39400565 0.42782484 0.41888991 0.44487434 0.36962378 0.39497227
#  0.36973189 0.38655881 0.41495854 0.39086284 0.38615817 0.40470849
#  0.41354421 0.42190044 0.39028414 0.41552452 0.39062754 0.41377951
#  0.42207341 0.40861187 0.36580052 0.396192   0.39683303 0.41093559
#  0.38402396 0.36097502 0.40843381 0.44655703 0.39887057 0.41313848
#  0.4211513  0.42932947 0.40085597 0.41712836 0.41086055 0.41250254]
#
# cross validation results (STD)
#  [0.09898925 0.09563343 0.06078618 0.05697607 0.08907156 0.08825231
#  0.10961651 0.09902808 0.07284685 0.09061424 0.10819788 0.11148745
#  0.08890736 0.12899902 0.08886897 0.0612755  0.09943719 0.06525882
#  0.10906441 0.10143414 0.13458159 0.14561434 0.13745066 0.12572159
#  0.05483093 0.07854974 0.10306987 0.07904094 0.05455183 0.06554003
#  0.07727093 0.09900747 0.04587418 0.08769507 0.12412589 0.12471752]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 1.0000
#
# accuracy on development set: 0.4333
#
# precision on dev set: 0.3910
#
# recall on dev set: 0.4180
#
# fscore on dev set: 0.3917
# ------------------------------------------------------------
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
#
# final score for the tuned model
#  0.3968253968253968
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 2, 'max_features': 0.1, 'n_estimators': 400}
#
# cross validation results (MEAN)
#  [0.35173102 0.41073336 0.41205612 0.40249796 0.35339718 0.36998881
#  0.38715914 0.41199888 0.36830103 0.36181064 0.37858033 0.34664988
#  0.38263762 0.40142196 0.40346459 0.37880291 0.39446352 0.39525209
#  0.39603047 0.40171958 0.36730006 0.33085953 0.32599334 0.36295533
#  0.36221128 0.36645808 0.40142196 0.40891331 0.36028821 0.36493564
#  0.3883954  0.39835419 0.40269892 0.37601623 0.35083308 0.3500318 ]
#
# cross validation results (STD)
#  [0.02946389 0.04763375 0.07277724 0.07823695 0.08895075 0.08825828
#  0.10008742 0.10460741 0.02827069 0.07240622 0.10367288 0.12322853
#  0.09339318 0.07908526 0.05135326 0.0647274  0.09534669 0.03756031
#  0.05101524 0.04234999 0.06937109 0.09813186 0.06537851 0.07250681
#  0.09061527 0.09073472 0.07187538 0.04142653 0.02379808 0.05844789
#  0.07832369 0.05967074 0.04501837 0.07670881 0.053878   0.07123119]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 0.8269
#
# accuracy on development set: 0.4167
#
# precision on dev set: 0.2783
#
# recall on dev set: 0.3968
#
# fscore on dev set: 0.3268
# ------------------------------------------------------------
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
# /home/ceccarelli/.local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# final score for the tuned model
#  0.41269841269841273
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 2, 'max_features': 0.2, 'n_estimators': 200}
#
# cross validation results (MEAN)
#  [0.34640822 0.34624288 0.37595772 0.37577966 0.35975402 0.42461844
#  0.42289504 0.37497838 0.36973062 0.37140822 0.37894536 0.35558735
#  0.35220035 0.38445258 0.38277371 0.39879935 0.38817791 0.38197243
#  0.37872278 0.38312983 0.3545813  0.35163818 0.34610551 0.35125661
#  0.3682616  0.33385099 0.37035384 0.37762261 0.36129045 0.34829187
#  0.40115868 0.34987663 0.38667201 0.39595035 0.37266865 0.33402905]
#
# cross validation results (STD)
#  [0.02470239 0.02625602 0.02753434 0.04130001 0.08748357 0.04203987
#  0.0464605  0.02963446 0.07404613 0.08608235 0.0536676  0.03361227
#  0.06360514 0.06466809 0.06909502 0.05050852 0.07959968 0.04135613
#  0.04533073 0.06002349 0.05865348 0.07201123 0.03859734 0.04156334
#  0.07099678 0.0337607  0.05426447 0.0504656  0.04804607 0.04362916
#  0.03815063 0.01973368 0.07510254 0.0331251  0.02031178 0.04641801]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 0.9038
#
# accuracy on development set: 0.4333
#
# precision on dev set: 0.3021
#
# recall on dev set: 0.4127
#
# fscore on dev set: 0.3479
# ------------------------------------------------------------
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
#
# final score for the tuned model
#  0.335978835978836
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 2, 'max_features': 0.4, 'n_estimators': 100}
#
# cross validation results (MEAN)
#  [0.35189637 0.38703831 0.42870498 0.42046958 0.39889092 0.35631995
#  0.3899738  0.38288309 0.43672924 0.37111696 0.42994124 0.38199786
#  0.38486976 0.37837938 0.38703322 0.37919846 0.40027218 0.37555199
#  0.37374975 0.38512286 0.30523504 0.35098825 0.35431293 0.38676486
#  0.38680556 0.35667735 0.34062882 0.38319979 0.35516636 0.34167048
#  0.37235958 0.35334631 0.35551613 0.38808761 0.38397817 0.37091728]
#
# cross validation results (STD)
#  [0.08859108 0.09203402 0.08023989 0.09927661 0.06537514 0.08101781
#  0.07464948 0.07277266 0.05505973 0.05084272 0.04782604 0.04768848
#  0.05551403 0.0744953  0.05937276 0.05149989 0.06584143 0.06458806
#  0.06942575 0.06470489 0.09017063 0.06157144 0.04322895 0.04812363
#  0.07250929 0.07453352 0.08955637 0.07792486 0.11289306 0.06911877
#  0.08133893 0.06962261 0.05626874 0.05386575 0.05773734 0.05171013]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 0.8942
#
# accuracy on development set: 0.3500
#
# precision on dev set: 0.3194
#
# recall on dev set: 0.3360
#
# fscore on dev set: 0.2998
# ------------------------------------------------------------
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
#
# final score for the tuned model
#  0.5158730158730158
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 8, 'max_features': 0.2, 'n_estimators': 800}
#
# cross validation results (MEAN)
#  [0.3778808  0.41107677 0.41222146 0.40420864 0.30256029 0.35218254
#  0.37896825 0.40346459 0.39465049 0.42063492 0.38755978 0.37840227
#  0.42883725 0.38441697 0.41376679 0.44068987 0.43639856 0.39677452
#  0.4347324  0.43113172 0.42441875 0.42261523 0.43699888 0.38345035
#  0.47476216 0.46280016 0.447558   0.43038767 0.41692104 0.46906797
#  0.50719628 0.51382402 0.40724842 0.41778592 0.48279151 0.44807438]
#
# cross validation results (STD)
#  [0.05330287 0.08635239 0.08677295 0.07244178 0.07773334 0.10713049
#  0.11576218 0.06781612 0.06725999 0.07646912 0.09772128 0.08977946
#  0.05931189 0.07052487 0.08998207 0.06953964 0.08114419 0.07252433
#  0.05322103 0.09322012 0.08941167 0.0498947  0.07259385 0.08778409
#  0.11479824 0.06307435 0.0818729  0.06072577 0.09491148 0.06414328
#  0.06128191 0.03295848 0.08762791 0.09811929 0.06660793 0.05238668]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 1.0000
#
# accuracy on development set: 0.5333
#
# precision on dev set: 0.5247
#
# recall on dev set: 0.5159
#
# fscore on dev set: 0.4861
# ------------------------------------------------------------
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
#
# final score for the tuned model
#  0.36772486772486773
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 8, 'max_features': 0.1, 'n_estimators': 100}
#
# cross validation results (MEAN)
#  [0.43239087 0.38855566 0.41454009 0.38648886 0.41662342 0.3656339
#  0.39572777 0.38657026 0.42226165 0.35589769 0.38807489 0.42083079
#  0.41209554 0.41341829 0.40470721 0.43738172 0.37775616 0.39194394
#  0.42033094 0.42279838 0.41828831 0.44068478 0.40614952 0.40638991
#  0.46900946 0.46203831 0.39931573 0.42658221 0.43296958 0.37339362
#  0.43098927 0.39779329 0.44161834 0.45728785 0.45688721 0.42768112]
#
# cross validation results (STD)
#  [0.07510001 0.0655015  0.05224501 0.01826412 0.05588756 0.05192944
#  0.05314885 0.04358404 0.06635539 0.05209185 0.05093191 0.07186895
#  0.07835315 0.05356035 0.03368246 0.03903786 0.07739515 0.04469561
#  0.03622112 0.03026807 0.0827389  0.07037339 0.07830922 0.03443758
#  0.0446966  0.08245576 0.03601551 0.03473883 0.00835182 0.03134773
#  0.06557162 0.04717962 0.02711247 0.05364543 0.04756092 0.03230453]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 1.0000
#
# accuracy on development set: 0.3833
#
# precision on dev set: 0.3241
#
# recall on dev set: 0.3677
#
# fscore on dev set: 0.3378
# ------------------------------------------------------------
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
#
# final score for the tuned model
#  0.4365079365079365
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 8, 'max_features': 0.2, 'n_estimators': 400}
#
# cross validation results (MEAN)
#  [0.39866835 0.39494302 0.37731481 0.36775666 0.41277091 0.41294897
#  0.39510836 0.40254248 0.39691061 0.38416514 0.38712988 0.3951427
#  0.41345772 0.40800392 0.40373423 0.39572141 0.34654558 0.3727704
#  0.37168295 0.38885328 0.35834096 0.35114723 0.37144765 0.38827457
#  0.36559829 0.34310516 0.42267247 0.40722553 0.42240919 0.41914683
#  0.43284366 0.40386014 0.41425392 0.39504604 0.38668981 0.38611111]
#
# cross validation results (STD)
#  [0.05793287 0.03589165 0.04873201 0.04392544 0.04452218 0.04566825
#  0.07526419 0.08645895 0.08143565 0.05391387 0.05953492 0.05690445
#  0.05078546 0.03792503 0.02855154 0.02431933 0.08484523 0.051131
#  0.07053807 0.06072251 0.082846   0.05668957 0.07419366 0.05380787
#  0.07780596 0.04240434 0.06233104 0.03883968 0.04649059 0.06600447
#  0.06311261 0.04207359 0.07502724 0.03565462 0.0418451  0.05761148]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 1.0000
#
# accuracy on development set: 0.4500
#
# precision on dev set: 0.4244
#
# recall on dev set: 0.4365
#
# fscore on dev set: 0.4176
# ------------------------------------------------------------
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
#
# final score for the tuned model
#  0.41798941798941797
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 8, 'max_features': 0.1, 'n_estimators': 100}
#
# cross validation results (MEAN)
#  [0.33713624 0.34308226 0.32603276 0.30886243 0.37891102 0.32906619
#  0.3019943  0.3019943  0.34446225 0.33603607 0.33621413 0.29243615
#  0.31980057 0.36043066 0.31155245 0.31040776 0.3452063  0.35139906
#  0.35059778 0.34258496 0.34259768 0.31545584 0.36355566 0.33070309
#  0.40308684 0.37920355 0.34502824 0.33679284 0.35780805 0.32649064
#  0.33555149 0.36237663 0.39678724 0.34083995 0.31978785 0.33531619]
#
# cross validation results (STD)
#  [0.08700981 0.07957281 0.10857378 0.09068795 0.12533009 0.11834161
#  0.06555845 0.06555845 0.07042805 0.0380995  0.05431587 0.07763584
#  0.10807274 0.09277046 0.05494329 0.05589547 0.06946554 0.07944551
#  0.09234174 0.10606222 0.08551475 0.06812261 0.10621213 0.09523105
#  0.09143666 0.09916678 0.06500443 0.06344026 0.0854958  0.06585248
#  0.07471309 0.10575025 0.07130748 0.07759226 0.07701734 0.06614758]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 1.0000
#
# accuracy on development set: 0.4333
#
# precision on dev set: 0.4074
#
# recall on dev set: 0.4180
#
# fscore on dev set: 0.3889
# ------------------------------------------------------------
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
# final score for the tuned model
#  0.4682539682539682
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 8, 'max_features': 0.2, 'n_estimators': 100}
#
# cross validation results (MEAN)
#  [0.3638253  0.31363706 0.35546907 0.33120803 0.32614723 0.35563441
#  0.35489036 0.33102997 0.35260735 0.32895172 0.36498652 0.35429004
#  0.3117356  0.35497176 0.35675748 0.34834402 0.31518747 0.33826949
#  0.36304691 0.33271266 0.31049934 0.32881436 0.33935185 0.32618793
#  0.28413334 0.35328907 0.35062704 0.36036325 0.37254782 0.36721357
#  0.34220849 0.33578042 0.34533857 0.32544388 0.34896088 0.34691824]
#
# cross validation results (STD)
#  [0.06845308 0.05236207 0.06991181 0.08369373 0.05290243 0.07748764
#  0.09682403 0.08053591 0.06510199 0.07314808 0.02181762 0.08687452
#  0.11923196 0.10741581 0.0760869  0.06276231 0.04268125 0.026653
#  0.04728227 0.03591697 0.03304009 0.04794924 0.04969848 0.05198965
#  0.08418472 0.10273881 0.05658226 0.05863942 0.0639882  0.09265139
#  0.1164663  0.09560346 0.06921746 0.04809615 0.05599094 0.06152807]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 1.0000
#
# accuracy on development set: 0.4833
#
# precision on dev set: 0.4710
#
# recall on dev set: 0.4683
#
# fscore on dev set: 0.4453
# ------------------------------------------------------------
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
#
# final score for the tuned model
#  0.3968253968253968
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 2, 'max_features': 0.1, 'n_estimators': 100}
#
# cross validation results (MEAN)
#  [0.41684473 0.41095594 0.40883191 0.40975402 0.37863757 0.41073336
#  0.38422746 0.37633547 0.37680606 0.38571556 0.36163258 0.345785
#  0.35200448 0.36890135 0.39528643 0.35265313 0.3437182  0.40096281
#  0.37920355 0.36277727 0.33480744 0.37623881 0.37176943 0.36317791
#  0.3670813  0.36790039 0.36806064 0.37079009 0.36337759 0.36764728
#  0.32461335 0.36644536 0.36864443 0.39998347 0.39713446 0.34502824]
#
# cross validation results (STD)
#  [0.07835923 0.08878352 0.08881348 0.09303202 0.11649931 0.09278252
#  0.10032918 0.09239574 0.12034144 0.13605032 0.11694345 0.11983431
#  0.12679016 0.09112973 0.09564355 0.0777265  0.07194563 0.15317547
#  0.10698068 0.10108676 0.07072488 0.10070767 0.13187281 0.12438758
#  0.04616047 0.06467193 0.060256   0.09119355 0.07858148 0.05870873
#  0.08644315 0.08818874 0.11730716 0.16862829 0.10582907 0.13665151]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 0.8750
#
# accuracy on development set: 0.4167
#
# precision on dev set: 0.2805
#
# recall on dev set: 0.3968
#
# fscore on dev set: 0.3234
# ------------------------------------------------------------
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
#
# final score for the tuned model
#  0.5185185185185185
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 8, 'max_features': 0.2, 'n_estimators': 400}
#
# cross validation results (MEAN)
#  [0.32323591 0.35591041 0.35396444 0.34377035 0.31075244 0.35258445
#  0.35350656 0.33863833 0.33463065 0.32553673 0.33044745 0.32243463
#  0.37532942 0.34912241 0.363866   0.35603124 0.35743284 0.35080001
#  0.36212098 0.38027066 0.32315705 0.32506741 0.37554818 0.37882835
#  0.34646037 0.36581197 0.3573985  0.37127849 0.36308252 0.35757657
#  0.38908476 0.3753256  0.3195729  0.35405093 0.36204594 0.3639474 ]
#
# cross validation results (STD)
#  [0.07658979 0.05429022 0.01597736 0.04365375 0.02168638 0.05065759
#  0.04971088 0.05122183 0.0763225  0.02922743 0.05295476 0.08113988
#  0.1300335  0.1204929  0.06081986 0.0564583  0.08867149 0.08040601
#  0.09657792 0.07300722 0.04532804 0.08459735 0.06662828 0.0955011
#  0.09966486 0.1107314  0.09251604 0.0677543  0.05672705 0.0599528
#  0.05601045 0.05793014 0.06469769 0.07888305 0.03859808 0.05073959]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 1.0000
#
# accuracy on development set: 0.5333
#
# precision on dev set: 0.5487
#
# recall on dev set: 0.5185
#
# fscore on dev set: 0.5005
# ------------------------------------------------------------
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
#
# final score for the tuned model
#  0.3968253968253968
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 2, 'max_features': 0.4, 'n_estimators': 100}
#
# cross validation results (MEAN)
#  [0.32106481 0.33055428 0.28505927 0.3110437  0.37032204 0.33144205
#  0.34820665 0.29193376 0.38017781 0.3351801  0.31949786 0.35251577
#  0.36599384 0.35866784 0.37379045 0.32475198 0.33336004 0.35696352
#  0.3190349  0.35434219 0.32522767 0.33324049 0.32843279 0.35904686
#  0.37324735 0.31090125 0.31743106 0.31444979 0.36173051 0.33578678
#  0.36752264 0.32791132 0.35510277 0.36523962 0.33610221 0.35349512]
#
# cross validation results (STD)
#  [0.04935297 0.05537286 0.05151465 0.05054674 0.06978743 0.05746611
#  0.07131915 0.05934909 0.05352088 0.06117433 0.05384827 0.08377255
#  0.04459656 0.04848112 0.07779382 0.05912576 0.03663385 0.08383492
#  0.08365775 0.10325034 0.07759104 0.08486539 0.08658367 0.07880961
#  0.03318554 0.02842276 0.06321607 0.0550358  0.03181079 0.07884352
#  0.06912192 0.06897266 0.0968323  0.08088308 0.06735566 0.07455016]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 0.9231
#
# accuracy on development set: 0.4167
#
# precision on dev set: 0.2964
#
# recall on dev set: 0.3968
#
# fscore on dev set: 0.3367
# ------------------------------------------------------------
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
#
# final score for the tuned model
#  0.3968253968253968
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 2, 'max_features': 0.1, 'n_estimators': 200}
#
# cross validation results (MEAN)
#  [0.45278795 0.49279991 0.46978022 0.48284112 0.44123168 0.44924451
#  0.45056726 0.42612815 0.45898072 0.48438645 0.47597299 0.45880266
#  0.48241885 0.41173433 0.45643442 0.46757224 0.45120319 0.4646075
#  0.47187627 0.42630622 0.4682705  0.43151455 0.43942435 0.42596281
#  0.39806802 0.44613222 0.43245319 0.43397563 0.44749949 0.42081171
#  0.44233186 0.4427325  0.40879248 0.45814001 0.47069724 0.43512032]
#
# cross validation results (STD)
#  [0.03452839 0.04938445 0.03017899 0.02602062 0.02173109 0.02872605
#  0.02198975 0.03967721 0.02989988 0.01461606 0.02260806 0.03359575
#  0.04365711 0.01288464 0.06943336 0.05460036 0.05279742 0.06380181
#  0.05706341 0.02441574 0.07230631 0.06164504 0.08558051 0.06583345
#  0.07454702 0.06062632 0.04538987 0.04102042 0.05335987 0.07877922
#  0.04816352 0.03421993 0.07821422 0.060591   0.03789925 0.03643104]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 0.8365
#
# accuracy on development set: 0.4167
#
# precision on dev set: 0.2750
#
# recall on dev set: 0.3968
#
# fscore on dev set: 0.3241
# ------------------------------------------------------------
# /home/ceccarelli/.local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
#
# final score for the tuned model
#  0.41534391534391535
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 4, 'max_features': 0.1, 'n_estimators': 100}
#
# cross validation results (MEAN)
#  [0.34901557 0.3838141  0.34776277 0.34908552 0.29653795 0.31405169
#  0.33203602 0.36609051 0.3433748  0.32825855 0.37695869 0.3846281
#  0.38604243 0.36836717 0.33242394 0.35115232 0.33390313 0.35584809
#  0.35609737 0.33358135 0.31649242 0.31831247 0.3089769  0.31641102
#  0.34224155 0.37030296 0.36938085 0.34908552 0.37802961 0.35152498
#  0.32522512 0.36973698 0.32627315 0.32324481 0.33790827 0.3686368 ]
#
# cross validation results (STD)
#  [0.05084415 0.0475688  0.06224279 0.07679146 0.07190102 0.06174754
#  0.03779445 0.05703485 0.04313688 0.03932303 0.07498445 0.05057959
#  0.08243271 0.07046889 0.06511878 0.06138472 0.04354478 0.0862992
#  0.04130637 0.03525632 0.02875531 0.03657511 0.02591557 0.02111121
#  0.0606213  0.02957783 0.06695042 0.02913141 0.08074812 0.04691879
#  0.03594472 0.05179731 0.05271582 0.05433727 0.08469863 0.06665448]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 1.0000
#
# accuracy on development set: 0.4333
#
# precision on dev set: 0.3886
#
# recall on dev set: 0.4153
#
# fscore on dev set: 0.3726
# ------------------------------------------------------------
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
#
# final score for the tuned model
#  0.4444444444444444
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 2, 'max_features': 0.2, 'n_estimators': 200}
#
# cross validation results (MEAN)
#  [0.38795406 0.37931802 0.35384234 0.36986798 0.38138482 0.4060465
#  0.37108262 0.3624911  0.32999466 0.38881894 0.34682158 0.38064077
#  0.33931751 0.35540039 0.32763533 0.34348291 0.35562296 0.3383954
#  0.38326084 0.38172823 0.3466308  0.32694851 0.37989672 0.373372
#  0.39791921 0.40111798 0.36265644 0.39590965 0.38767425 0.35311101
#  0.34584224 0.36168981 0.35614443 0.35596637 0.34778821 0.34664352]
#
# cross validation results (STD)
#  [0.06118582 0.02397499 0.04963034 0.03971935 0.07581476 0.04675056
#  0.04820254 0.05094559 0.06696147 0.05213133 0.06200038 0.05108696
#  0.03843793 0.03710648 0.04083841 0.03075681 0.05602116 0.04984735
#  0.0472184  0.05648886 0.06078604 0.06321288 0.07657276 0.07156052
#  0.07353982 0.03374891 0.0332281  0.05937413 0.03448254 0.04328985
#  0.05079975 0.04467137 0.03151092 0.0485343  0.07878721 0.06311812]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 0.8942
#
# accuracy on development set: 0.4667
#
# precision on dev set: 0.3098
#
# recall on dev set: 0.4444
#
# fscore on dev set: 0.3642
# ------------------------------------------------------------
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
# /home/ceccarelli/.local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# final score for the tuned model
#  0.3650793650793651
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 4, 'max_features': 0.2, 'n_estimators': 100}
#
# cross validation results (MEAN)
#  [0.34193758 0.33375941 0.33530474 0.33650666 0.37136879 0.36209046
#  0.3280932  0.34606481 0.35866784 0.38683354 0.35243564 0.34098876
#  0.31081985 0.33377722 0.41069394 0.39272232 0.41846637 0.35540039
#  0.3645579  0.36107168 0.31861645 0.35243564 0.32033985 0.34516687
#  0.29068096 0.30212149 0.31712836 0.35275488 0.38917379 0.35129095
#  0.3849448  0.37040725 0.4088866  0.33791082 0.35300163 0.32800926]
#
# cross validation results (STD)
#  [0.05390996 0.04979156 0.05957396 0.05111309 0.07576072 0.04749638
#  0.05769966 0.04746633 0.05510119 0.03608023 0.04129244 0.07570731
#  0.08120232 0.0626888  0.02803752 0.07242244 0.04991397 0.02366139
#  0.04131722 0.05529063 0.02707125 0.04567963 0.06697069 0.03608023
#  0.03049293 0.01041296 0.05201823 0.04233957 0.02161574 0.044411
#  0.04230307 0.05729944 0.07725185 0.03880162 0.0504215  0.06311344]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 1.0000
#
# accuracy on development set: 0.3833
#
# precision on dev set: 0.2840
#
# recall on dev set: 0.3651
#
# fscore on dev set: 0.3194
# ------------------------------------------------------------
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
#
# final score for the tuned model
#  0.373015873015873
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 4, 'max_features': 0.4, 'n_estimators': 100}
#
# cross validation results (MEAN)
#  [0.30875432 0.33456069 0.29140593 0.30759692 0.3589998  0.32843661
#  0.33420457 0.3078195  0.34239545 0.35253231 0.32654787 0.29329467
#  0.32341015 0.32929894 0.34768391 0.3089769  0.35553775 0.34784417
#  0.3192791  0.37661528 0.38532636 0.33221917 0.35071225 0.31905652
#  0.31286248 0.316977   0.34271724 0.34007173 0.38253968 0.34434142
#  0.36629146 0.35884463 0.35349893 0.33314128 0.34552045 0.35003053]
#
# cross validation results (STD)
#  [0.0578421  0.05806804 0.03597073 0.03791913 0.04035101 0.03863124
#  0.0494243  0.04084751 0.03977759 0.03753836 0.02109973 0.04523101
#  0.05396571 0.05096591 0.0245115  0.03593014 0.0737833  0.05344626
#  0.03695732 0.05099697 0.07926544 0.07340377 0.06080597 0.08283234
#  0.08494523 0.06945796 0.06854436 0.09100959 0.07953197 0.06604197
#  0.07339978 0.07722558 0.08799652 0.03293144 0.06979394 0.06175765]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 1.0000
#
# accuracy on development set: 0.3833
#
# precision on dev set: 0.3676
#
# recall on dev set: 0.3730
#
# fscore on dev set: 0.3546
# ------------------------------------------------------------
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
#
# final score for the tuned model
#  0.39947089947089953
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 4, 'max_features': 0.2, 'n_estimators': 100}
#
# cross validation results (MEAN)
#  [0.2709796  0.28489393 0.29445208 0.33570538 0.36844857 0.31160969
#  0.27744709 0.29519612 0.2789479  0.2633229  0.28225478 0.31837607
#  0.40011701 0.35175392 0.3827241  0.34303775 0.4125814  0.30823921
#  0.32735551 0.31837607 0.30162419 0.33240359 0.34768519 0.29468101
#  0.32312653 0.29785307 0.30652218 0.33136193 0.28863197 0.33967745
#  0.31837607 0.32032204 0.36819928 0.32486645 0.31128536 0.32833486]
#
# cross validation results (STD)
#  [0.07164232 0.03742289 0.08252748 0.02715958 0.09020959 0.04800915
#  0.03362838 0.06783967 0.04404171 0.05087465 0.04790337 0.06315583
#  0.04180054 0.04784308 0.09291711 0.07839807 0.06662492 0.0627056
#  0.0892339  0.05400811 0.07997138 0.03998794 0.03017445 0.05876705
#  0.04352088 0.06914358 0.04060122 0.05610467 0.02678344 0.08175348
#  0.0700866  0.05793922 0.07412243 0.1189001  0.09775095 0.04602278]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 1.0000
#
# accuracy on development set: 0.4167
#
# precision on dev set: 0.3516
#
# recall on dev set: 0.3995
#
# fscore on dev set: 0.3605
# ------------------------------------------------------------
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
#
# final score for the tuned model
#  0.38359788359788355
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 4, 'max_features': 0.1, 'n_estimators': 100}
#
# cross validation results (MEAN)
#  [0.4082265  0.35229701 0.36030983 0.36030983 0.34268162 0.31824252
#  0.3607677  0.34394078 0.37022283 0.40340608 0.37655805 0.38184142
#  0.43624975 0.36668066 0.38036477 0.39644765 0.41319063 0.37337581
#  0.38408501 0.38146368 0.3644358  0.35716702 0.36377315 0.36433913
#  0.3679856  0.37902549 0.36800214 0.3685058  0.34744353 0.33118259
#  0.37793295 0.36776175 0.32441875 0.36502595 0.39062118 0.35523886]
#
# cross validation results (STD)
#  [0.09351377 0.10129398 0.07889461 0.07889461 0.06608368 0.06305799
#  0.0710361  0.05841118 0.07488997 0.05907972 0.04403241 0.06274055
#  0.10293443 0.12804562 0.07277892 0.11774513 0.07934521 0.11616412
#  0.12137941 0.11098109 0.10038173 0.04649766 0.08308093 0.0961692
#  0.07152889 0.07612155 0.11152981 0.0927362  0.08631191 0.13008307
#  0.11186719 0.10397904 0.12705991 0.1153744  0.07306382 0.12759072]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 1.0000
#
# accuracy on development set: 0.4000
#
# precision on dev set: 0.3577
#
# recall on dev set: 0.3836
#
# fscore on dev set: 0.3432
# ------------------------------------------------------------
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
#
# final score for the tuned model
#  0.3862433862433862
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 8, 'max_features': 0.1, 'n_estimators': 100}
#
# cross validation results (MEAN)
#  [0.37476852 0.38300392 0.39348418 0.36790039 0.38467008 0.35983033
#  0.35221815 0.37745854 0.33401124 0.34300341 0.35101623 0.36726445
#  0.28787012 0.32332621 0.35245345 0.34868742 0.37176689 0.3835203
#  0.33832799 0.34770808 0.364535   0.37412749 0.36134768 0.3781746
#  0.44139321 0.41380113 0.35519943 0.39933354 0.32953678 0.36998372
#  0.38681064 0.34845213 0.39791412 0.37821912 0.36544439 0.35857626]
#
# cross validation results (STD)
#  [0.09171365 0.05995979 0.07802152 0.07736363 0.08116964 0.07308086
#  0.06586851 0.06576004 0.07329288 0.08574168 0.09973208 0.08828936
#  0.10881369 0.10115003 0.0501816  0.06253263 0.1107383  0.06679874
#  0.09359392 0.0632758  0.0657672  0.02358193 0.0734706  0.07559406
#  0.09275719 0.06235683 0.05574898 0.06546129 0.066378   0.05866722
#  0.03889693 0.07922612 0.05039366 0.07025588 0.0927861  0.0678128 ]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 1.0000
#
# accuracy on development set: 0.4000
#
# precision on dev set: 0.3824
#
# recall on dev set: 0.3862
#
# fscore on dev set: 0.3605
# ------------------------------------------------------------
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
#
# final score for the tuned model
#  0.521164021164021
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 8, 'max_features': 0.4, 'n_estimators': 200}
#
# cross validation results (MEAN)
#  [0.316977   0.36467618 0.34175951 0.36796652 0.31698972 0.36467618
#  0.32567664 0.32493259 0.34572522 0.34842796 0.34670457 0.31726318
#  0.41077788 0.37948336 0.35327635 0.36071047 0.38346688 0.34233822
#  0.35798611 0.30279558 0.37322828 0.37707443 0.34325524 0.3249275
#  0.3346917  0.35792379 0.33701542 0.38789683 0.32611289 0.33211742
#  0.33354701 0.36852361 0.3784417  0.43799476 0.37821912 0.37729701]
#
# cross validation results (STD)
#  [0.03926714 0.03448265 0.02498743 0.0607702  0.05082512 0.05314436
#  0.06230904 0.06075303 0.04490681 0.06310284 0.06037535 0.0737265
#  0.00961776 0.02222412 0.02422991 0.05797184 0.06767893 0.06768267
#  0.07213125 0.06066099 0.05506217 0.07451945 0.06808971 0.03900939
#  0.04849072 0.03208978 0.02440994 0.04766037 0.0344227  0.05297183
#  0.05470785 0.02797407 0.03479873 0.08248786 0.03835694 0.03684328]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 1.0000
#
# accuracy on development set: 0.5333
#
# precision on dev set: 0.5116
#
# recall on dev set: 0.5212
#
# fscore on dev set: 0.5097
# ------------------------------------------------------------
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
# final score for the tuned model
#  0.41269841269841273
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 2, 'max_features': 0.1, 'n_estimators': 800}
#
# cross validation results (MEAN)
#  [0.35510786 0.3799476  0.39562983 0.43808506 0.36087581 0.37770274
#  0.41244404 0.38645961 0.37061203 0.37193478 0.388183   0.39585241
#  0.42216372 0.3835521  0.37793803 0.395509   0.31984509 0.35832443
#  0.37960419 0.37217008 0.38959224 0.39248703 0.39851445 0.38579696
#  0.41438492 0.36954874 0.38418803 0.36846128 0.40164454 0.3992585
#  0.4026684  0.36335597 0.36937068 0.38999796 0.38857855 0.36804792]
#
# cross validation results (STD)
#  [0.09453258 0.10761062 0.10354913 0.09286511 0.08173312 0.07915234
#  0.06628236 0.06211113 0.04399172 0.0846136  0.0818289  0.06266996
#  0.09425845 0.08922064 0.0740769  0.06748198 0.06298169 0.09384666
#  0.07852704 0.08003568 0.03171583 0.07223441 0.07940734 0.08095477
#  0.10437249 0.09601506 0.11022617 0.09538729 0.05946223 0.06313946
#  0.08604745 0.07971479 0.07935235 0.0417448  0.06707447 0.08233009]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 0.9231
#
# accuracy on development set: 0.4333
#
# precision on dev set: 0.2955
#
# recall on dev set: 0.4127
#
# fscore on dev set: 0.3365
# ------------------------------------------------------------
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
# /home/ceccarelli/.local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# final score for the tuned model
#  0.42857142857142855
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 2, 'max_features': 0.1, 'n_estimators': 100}
#
# cross validation results (MEAN)
#  [0.40060668 0.37193478 0.34635099 0.32283399 0.36183354 0.37866046
#  0.38382937 0.33869429 0.32663436 0.33406848 0.37449379 0.3182209
#  0.35841092 0.36762566 0.3503981  0.34460597 0.36051079 0.32579365
#  0.34420533 0.34983211 0.34955103 0.34792557 0.33093839 0.3372062
#  0.30091829 0.39132072 0.36567969 0.34999746 0.37143239 0.36221764
#  0.35574379 0.34221993 0.33949557 0.36153083 0.38917506 0.36319063]
#
# cross validation results (STD)
#  [0.10738234 0.08315513 0.07981802 0.08922152 0.06404693 0.04646075
#  0.07469708 0.0883596  0.03812269 0.0743048  0.04961605 0.05931656
#  0.09060262 0.04187506 0.05664318 0.07296563 0.02309703 0.10258928
#  0.07212424 0.06348686 0.05328879 0.03301911 0.04149917 0.04337529
#  0.08957698 0.03423905 0.0517858  0.06804709 0.03097045 0.07382884
#  0.08159531 0.05065342 0.03039547 0.05301727 0.03650961 0.03957087]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 0.8750
#
# accuracy on development set: 0.4500
#
# precision on dev set: 0.2990
#
# recall on dev set: 0.4286
#
# fscore on dev set: 0.3499
# ------------------------------------------------------------
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
# /home/ceccarelli/.local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# final score for the tuned model
#  0.4444444444444444
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 2, 'max_features': 0.1, 'n_estimators': 200}
#
# cross validation results (MEAN)
#  [0.30524395 0.40096281 0.36121922 0.3273428  0.34613222 0.3019943
#  0.30371769 0.29374618 0.352035   0.3239507  0.31026659 0.33515084
#  0.37905601 0.26285231 0.27104319 0.36894205 0.34463395 0.33348469
#  0.3483313  0.34414683 0.38344526 0.3562818  0.38338294 0.34961335
#  0.3354828  0.37916412 0.39502951 0.37591321 0.37786427 0.36024751
#  0.3124911  0.37188899 0.34810872 0.32819623 0.34327941 0.36863935]
#
# cross validation results (STD)
#  [0.14073206 0.07863415 0.092058   0.11645886 0.0930913  0.05967647
#  0.08210576 0.10240101 0.04570146 0.08998969 0.11836935 0.09737946
#  0.13532149 0.06306186 0.08761858 0.09160088 0.09238921 0.02139077
#  0.03342972 0.07957909 0.05631452 0.0821502  0.10007142 0.05482036
#  0.06094855 0.11441883 0.1274533  0.06495086 0.08415721 0.05772394
#  0.10377061 0.05960024 0.11747701 0.12997873 0.10297594 0.10972808]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 0.9519
#
# accuracy on development set: 0.4667
#
# precision on dev set: 0.3155
#
# recall on dev set: 0.4444
#
# fscore on dev set: 0.3677
# ------------------------------------------------------------

# %%
models1 = [
    doc2vec.Doc2Vec(dm=1, dm_concat=1, vector_size=25, window=5, negative=5, hs=0, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=1, dm_concat=1, vector_size=25, window=5, negative=10, hs=0, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=1, dm_concat=1, vector_size=25, window=5, negative=0, hs=1, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=1, dm_concat=1, vector_size=25, window=10, negative=5, hs=0, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=1, dm_concat=1, vector_size=25, window=10, negative=10, hs=0, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=1, dm_concat=1, vector_size=25, window=10, negative=0, hs=1, min_count=2, epochs=100, workers=cores,sample=0),
    
    doc2vec.Doc2Vec(dm=1, dm_concat=1, vector_size=50, window=5, negative=5, hs=0, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=1, dm_concat=1, vector_size=50, window=5, negative=10, hs=0, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=1, dm_concat=1, vector_size=50, window=5, negative=0, hs=1, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=1, dm_concat=1, vector_size=50, window=10, negative=5, hs=0, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=1, dm_concat=1, vector_size=50, window=10, negative=10, hs=0, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=1, dm_concat=1, vector_size=50, window=10, negative=0, hs=1, min_count=2, epochs=100, workers=cores,sample=0),
    
    doc2vec.Doc2Vec(dm=1, dm_concat=1, vector_size=75, window=5, negative=5, hs=0, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=1, dm_concat=1, vector_size=75, window=5, negative=10, hs=0, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=1, dm_concat=1, vector_size=75, window=5, negative=0, hs=1, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=1, dm_concat=1, vector_size=75, window=10, negative=5, hs=0, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=1, dm_concat=1, vector_size=75, window=10, negative=10, hs=0, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=1, dm_concat=1, vector_size=75, window=10, negative=0, hs=1, min_count=2, epochs=100, workers=cores,sample=0),
    
    doc2vec.Doc2Vec(dm=1, dm_concat=1, vector_size=100, window=5, negative=5, hs=0, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=1, dm_concat=1, vector_size=100, window=5, negative=10, hs=0, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=1, dm_concat=1, vector_size=100, window=5, negative=0, hs=1, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=1, dm_concat=1, vector_size=100, window=10, negative=5, hs=0, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=1, dm_concat=1, vector_size=100, window=10, negative=10, hs=0, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=1, dm_concat=1, vector_size=100, window=10, negative=0, hs=1, min_count=2, epochs=100, workers=cores,sample=0)
]

models2 = [
    doc2vec.Doc2Vec(dm=0, vector_size=25, negative=5, hs=0, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=0, vector_size=25, negative=10, hs=0, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=0, vector_size=25, negative=0, hs=1, min_count=2, epochs=100, workers=cores,sample=0),
    
    doc2vec.Doc2Vec(dm=0, vector_size=50, negative=5, hs=0, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=0, vector_size=50, negative=10, hs=0, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=0, vector_size=50, negative=0, hs=1, min_count=2, epochs=100, workers=cores,sample=0),
    
    doc2vec.Doc2Vec(dm=0, vector_size=75, negative=5, hs=0, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=0, vector_size=75, negative=10, hs=0, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=0, vector_size=75, negative=0, hs=1, min_count=2, epochs=100, workers=cores,sample=0),
    
    doc2vec.Doc2Vec(dm=0, vector_size=100, negative=5, hs=0, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=0, vector_size=100, negative=10, hs=0, min_count=2, epochs=100, workers=cores,sample=0),
    doc2vec.Doc2Vec(dm=0, vector_size=100, negative=0, hs=1, min_count=2, epochs=100, workers=cores,sample=0),
    
]

# %%
from gensim.test.test_doc2vec import ConcatenatedDoc2Vec

models = [
    ConcatenatedDoc2Vec([models2[0], models1[0]]),
    ConcatenatedDoc2Vec([models2[1], models1[1]]),
    ConcatenatedDoc2Vec([models2[2], models1[2]]),
    ConcatenatedDoc2Vec([models2[0], models1[3]]),
    ConcatenatedDoc2Vec([models2[1], models1[4]]),
    ConcatenatedDoc2Vec([models2[2], models1[5]]),
    
    ConcatenatedDoc2Vec([models2[3], models1[6]]),
    ConcatenatedDoc2Vec([models2[4], models1[7]]),
    ConcatenatedDoc2Vec([models2[5], models1[8]]),
    ConcatenatedDoc2Vec([models2[3], models1[9]]),
    ConcatenatedDoc2Vec([models2[4], models1[10]]),
    ConcatenatedDoc2Vec([models2[5], models1[11]]),
    
    ConcatenatedDoc2Vec([models2[6], models1[12]]),
    ConcatenatedDoc2Vec([models2[7], models1[13]]),
    ConcatenatedDoc2Vec([models2[8], models1[14]]),
    ConcatenatedDoc2Vec([models2[6], models1[15]]),
    ConcatenatedDoc2Vec([models2[7], models1[16]]),
    ConcatenatedDoc2Vec([models2[8], models1[17]]),
    
    ConcatenatedDoc2Vec([models2[9], models1[18]]),
    ConcatenatedDoc2Vec([models2[10], models1[19]]),
    ConcatenatedDoc2Vec([models2[11], models1[20]]),
    ConcatenatedDoc2Vec([models2[9], models1[21]]),
    ConcatenatedDoc2Vec([models2[10], models1[22]]),
    ConcatenatedDoc2Vec([models2[11], models1[23]])

]

# %%
count = 0
for model in models1:
    print("\nbuilding vocabulary for doc2vec model %i" %count)
    model.build_vocab(all_docs)
    print("\nvocabulary scanned & built.")
    count += 1
    
count = 0
for model in models2:
    print("\nbuilding vocabulary for doc2vec model %i" %count)
    model.build_vocab(all_docs)
    print("\nvocabulary scanned & built.")
    count += 1
# Out:
# building vocabulary for doc2vec model 0
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 1
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 2
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 3
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 4
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 5
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 6
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 7
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 8
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 9
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 10
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 11
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 12
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 13
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 14
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 15
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 16
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 17
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 18
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 19
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 20
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 21
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 22
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 23
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 0
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 1
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 2
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 3
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 4
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 5
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 6
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 7
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 8
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 9
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 10
#
# vocabulary scanned & built.
#
# building vocabulary for doc2vec model 11
#
# vocabulary scanned & built.

# %%
from gensim.models.callbacks import CallbackAny2Vec
class EpochLogger(CallbackAny2Vec):
    '''Callback to log information about training'''
    
    def __init__(self):
        self.epoch = 0
    
    def on_epoch_begin(self, model):
        print("Epoch #{} start".format(self.epoch))
    
    def on_epoch_end(self, model):
        print("Epoch #{} end".format(self.epoch))
        self.epoch += 1
        
epoch_logger = EpochLogger()
count = 0
for model in models1:
    model.train(all_docs, total_examples=len(all_docs), epochs=100)
    print("\nmodel %i trained" %count)
    count += 1
    
epoch_logger = EpochLogger()
count = 0
for model in models2:
    model.train(all_docs, total_examples=len(all_docs), epochs=100)
    print("\nmodel %i trained" %count)
    count += 1
# Out:
# model 0 trained
#
# model 1 trained
#
# model 2 trained
#
# model 3 trained
#
# model 4 trained
#
# model 5 trained
#
# model 6 trained
#
# model 7 trained
#
# model 8 trained
#
# model 9 trained
#
# model 10 trained
#
# model 11 trained
#
# model 12 trained
#
# model 13 trained
#
# model 14 trained
#
# model 15 trained
#
# model 16 trained
#
# model 17 trained
#
# model 18 trained
#
# model 19 trained
#
# model 20 trained
#
# model 21 trained
#
# model 22 trained
#
# model 23 trained
#
# model 0 trained
#
# model 1 trained
#
# model 2 trained
#
# model 3 trained
#
# model 4 trained
#
# model 5 trained
#
# model 6 trained
#
# model 7 trained
#
# model 8 trained
#
# model 9 trained
#
# model 10 trained
#
# model 11 trained

# %%
count = 0
for model in models:
    infer_embedding_combined(model, models1[count], 'train', 'PV-COMBINED-CONC')
    infer_embedding_combined(model, models1[count], 'dev', 'PV-COMBINED-CONC')
    print("\nembedding inffered for model %i" %count)
    count += 1
# Out:
# saving in  ../RESULTS/PV-COMBINED-CONC
# Directory  ../RESULTS/PV-COMBINED-CONC/25_5_5_0  Created
# /home/ceccarelli/.local/lib/python3.6/site-packages/smart_open/smart_open_lib.py:402: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# saving inferred vectors and labels to file
# saving in  ../RESULTS/PV-COMBINED-CONC
# Directory  ../RESULTS/PV-COMBINED-CONC/25_5_5_0  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 0
# saving in  ../RESULTS/PV-COMBINED-CONC
# Directory  ../RESULTS/PV-COMBINED-CONC/25_5_10_0  Created
#
# saving inferred vectors and labels to file
# saving in  ../RESULTS/PV-COMBINED-CONC
# Directory  ../RESULTS/PV-COMBINED-CONC/25_5_10_0  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 1
# saving in  ../RESULTS/PV-COMBINED-CONC
# Directory  ../RESULTS/PV-COMBINED-CONC/25_5_0_1  Created
#
# saving inferred vectors and labels to file
# saving in  ../RESULTS/PV-COMBINED-CONC
# Directory  ../RESULTS/PV-COMBINED-CONC/25_5_0_1  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 2
# saving in  ../RESULTS/PV-COMBINED-CONC
# Directory  ../RESULTS/PV-COMBINED-CONC/25_10_5_0  Created
#
# saving inferred vectors and labels to file
# saving in  ../RESULTS/PV-COMBINED-CONC
# Directory  ../RESULTS/PV-COMBINED-CONC/25_10_5_0  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 3
# saving in  ../RESULTS/PV-COMBINED-CONC
# Directory  ../RESULTS/PV-COMBINED-CONC/25_10_10_0  Created
#
# saving inferred vectors and labels to file
# saving in  ../RESULTS/PV-COMBINED-CONC
# Directory  ../RESULTS/PV-COMBINED-CONC/25_10_10_0  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 4
# saving in  ../RESULTS/PV-COMBINED-CONC
# Directory  ../RESULTS/PV-COMBINED-CONC/25_10_0_1  Created
#
# saving inferred vectors and labels to file
# saving in  ../RESULTS/PV-COMBINED-CONC
# Directory  ../RESULTS/PV-COMBINED-CONC/25_10_0_1  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 5
# saving in  ../RESULTS/PV-COMBINED-CONC
# Directory  ../RESULTS/PV-COMBINED-CONC/50_5_5_0  Created
#
# saving inferred vectors and labels to file
# saving in  ../RESULTS/PV-COMBINED-CONC
# Directory  ../RESULTS/PV-COMBINED-CONC/50_5_5_0  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 6
# saving in  ../RESULTS/PV-COMBINED-CONC
# Directory  ../RESULTS/PV-COMBINED-CONC/50_5_10_0  Created
#
# saving inferred vectors and labels to file
# saving in  ../RESULTS/PV-COMBINED-CONC
# Directory  ../RESULTS/PV-COMBINED-CONC/50_5_10_0  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 7
# saving in  ../RESULTS/PV-COMBINED-CONC
# Directory  ../RESULTS/PV-COMBINED-CONC/50_5_0_1  Created
#
# saving inferred vectors and labels to file
# saving in  ../RESULTS/PV-COMBINED-CONC
# Directory  ../RESULTS/PV-COMBINED-CONC/50_5_0_1  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 8
# saving in  ../RESULTS/PV-COMBINED-CONC
# Directory  ../RESULTS/PV-COMBINED-CONC/50_10_5_0  Created
#
# saving inferred vectors and labels to file
# saving in  ../RESULTS/PV-COMBINED-CONC
# Directory  ../RESULTS/PV-COMBINED-CONC/50_10_5_0  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 9
# saving in  ../RESULTS/PV-COMBINED-CONC
# Directory  ../RESULTS/PV-COMBINED-CONC/50_10_10_0  Created
#
# saving inferred vectors and labels to file
# saving in  ../RESULTS/PV-COMBINED-CONC
# Directory  ../RESULTS/PV-COMBINED-CONC/50_10_10_0  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 10
# saving in  ../RESULTS/PV-COMBINED-CONC
# Directory  ../RESULTS/PV-COMBINED-CONC/50_10_0_1  Created
#
# saving inferred vectors and labels to file
# saving in  ../RESULTS/PV-COMBINED-CONC
# Directory  ../RESULTS/PV-COMBINED-CONC/50_10_0_1  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 11
# saving in  ../RESULTS/PV-COMBINED-CONC
# Directory  ../RESULTS/PV-COMBINED-CONC/75_5_5_0  Created
#
# saving inferred vectors and labels to file
# saving in  ../RESULTS/PV-COMBINED-CONC
# Directory  ../RESULTS/PV-COMBINED-CONC/75_5_5_0  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 12
# saving in  ../RESULTS/PV-COMBINED-CONC
# Directory  ../RESULTS/PV-COMBINED-CONC/75_5_10_0  Created
#
# saving inferred vectors and labels to file
# saving in  ../RESULTS/PV-COMBINED-CONC
# Directory  ../RESULTS/PV-COMBINED-CONC/75_5_10_0  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 13
# saving in  ../RESULTS/PV-COMBINED-CONC
# Directory  ../RESULTS/PV-COMBINED-CONC/75_5_0_1  Created
#
# saving inferred vectors and labels to file
# saving in  ../RESULTS/PV-COMBINED-CONC
# Directory  ../RESULTS/PV-COMBINED-CONC/75_5_0_1  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 14
# saving in  ../RESULTS/PV-COMBINED-CONC
# Directory  ../RESULTS/PV-COMBINED-CONC/75_10_5_0  Created
#
# saving inferred vectors and labels to file
# saving in  ../RESULTS/PV-COMBINED-CONC
# Directory  ../RESULTS/PV-COMBINED-CONC/75_10_5_0  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 15
# saving in  ../RESULTS/PV-COMBINED-CONC
# Directory  ../RESULTS/PV-COMBINED-CONC/75_10_10_0  Created
#
# saving inferred vectors and labels to file
# saving in  ../RESULTS/PV-COMBINED-CONC
# Directory  ../RESULTS/PV-COMBINED-CONC/75_10_10_0  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 16
# saving in  ../RESULTS/PV-COMBINED-CONC
# Directory  ../RESULTS/PV-COMBINED-CONC/75_10_0_1  Created
#
# saving inferred vectors and labels to file
# saving in  ../RESULTS/PV-COMBINED-CONC
# Directory  ../RESULTS/PV-COMBINED-CONC/75_10_0_1  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 17
# saving in  ../RESULTS/PV-COMBINED-CONC
# Directory  ../RESULTS/PV-COMBINED-CONC/100_5_5_0  Created
#
# saving inferred vectors and labels to file
# saving in  ../RESULTS/PV-COMBINED-CONC
# Directory  ../RESULTS/PV-COMBINED-CONC/100_5_5_0  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 18
# saving in  ../RESULTS/PV-COMBINED-CONC
# Directory  ../RESULTS/PV-COMBINED-CONC/100_5_10_0  Created
#
# saving inferred vectors and labels to file
# saving in  ../RESULTS/PV-COMBINED-CONC
# Directory  ../RESULTS/PV-COMBINED-CONC/100_5_10_0  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 19
# saving in  ../RESULTS/PV-COMBINED-CONC
# Directory  ../RESULTS/PV-COMBINED-CONC/100_5_0_1  Created
#
# saving inferred vectors and labels to file
# saving in  ../RESULTS/PV-COMBINED-CONC
# Directory  ../RESULTS/PV-COMBINED-CONC/100_5_0_1  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 20
# saving in  ../RESULTS/PV-COMBINED-CONC
# Directory  ../RESULTS/PV-COMBINED-CONC/100_10_5_0  Created
#
# saving inferred vectors and labels to file
# saving in  ../RESULTS/PV-COMBINED-CONC
# Directory  ../RESULTS/PV-COMBINED-CONC/100_10_5_0  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 21
# saving in  ../RESULTS/PV-COMBINED-CONC
# Directory  ../RESULTS/PV-COMBINED-CONC/100_10_10_0  Created
#
# saving inferred vectors and labels to file
# saving in  ../RESULTS/PV-COMBINED-CONC
# Directory  ../RESULTS/PV-COMBINED-CONC/100_10_10_0  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 22
# saving in  ../RESULTS/PV-COMBINED-CONC
# Directory  ../RESULTS/PV-COMBINED-CONC/100_10_0_1  Created
#
# saving inferred vectors and labels to file
# saving in  ../RESULTS/PV-COMBINED-CONC
# Directory  ../RESULTS/PV-COMBINED-CONC/100_10_0_1  already exists
#
# saving inferred vectors and labels to file
#
# embedding inffered for model 23

# %%
line = '../RESULTS/PV-COMBINED-CONC/' 
names = ['25_5_5_0', '25_5_10_0','25_5_0_1','25_10_5_0','25_10_10_0','25_10_0_1',
         '50_5_5_0', '50_5_10_0','50_5_0_1','50_10_5_0','50_10_10_0','50_10_0_1',
         '75_5_5_0', '75_5_10_0','75_5_0_1','75_10_5_0','75_10_10_0','75_10_0_1',
         '100_5_5_0', '100_5_10_0','100_5_0_1','100_10_5_0','100_10_10_0','100_10_0_1']
for i in names:
    path = os.path.join(line, i)
    X_train = np.load(os.path.join(path, 'vectors_train.npy'))
    X_dev = np.load(os.path.join(path, 'vectors_dev.npy'))
    y_train = np.load(os.path.join(path, 'labels_train.npy'))
    y_dev = np.load(os.path.join(path, 'labels_dev.npy'))
    y_train = np.ravel(y_train)
    y_dev = np.ravel(y_dev)
    
    feature_name = 'TEXT_'+str(i)
    save_dir = '../RESULTS/PV-COMBINED-CONC/' 
    random_forest = RandomForestCV(feature_name, X_train, y_train, X_dev, y_dev, save_dir)
    random_forest.run()
    print ("------"  * 10)
# Out:
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
#
# final score for the tuned model
#  0.41798941798941797
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 8, 'max_features': 0.1, 'n_estimators': 800}
#
# cross validation results (MEAN)
#  [0.34795228 0.33643671 0.3534417  0.33621413 0.36608923 0.34532585
#  0.37922009 0.37195131 0.36649751 0.34733415 0.35592567 0.35460292
#  0.33853276 0.3549247  0.37930149 0.40304106 0.34802859 0.38675214
#  0.40432311 0.38284875 0.39336335 0.38150438 0.36420177 0.38012439
#  0.37443529 0.37700448 0.36532357 0.43936203 0.42796602 0.36744251
#  0.37517933 0.39264728 0.40862714 0.39779838 0.37303368 0.42397741]
#
# cross validation results (STD)
#  [0.06275309 0.08641618 0.07264612 0.0737927  0.03721165 0.07650113
#  0.12791404 0.11852791 0.08210765 0.09214296 0.09725729 0.09531692
#  0.06556302 0.14635146 0.1337718  0.14182271 0.08308475 0.06816625
#  0.07548971 0.07339079 0.06614477 0.05739646 0.07261679 0.08955158
#  0.06841027 0.03761192 0.08169683 0.09105866 0.07944454 0.10349072
#  0.09001012 0.0899371  0.09578998 0.13574011 0.09084253 0.1054138 ]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 1.0000
#
# accuracy on development set: 0.4333
#
# precision on dev set: 0.3909
#
# recall on dev set: 0.4180
#
# fscore on dev set: 0.3911
# ------------------------------------------------------------
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
#
# final score for the tuned model
#  0.3333333333333333
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 4, 'max_features': 0.4, 'n_estimators': 200}
#
# cross validation results (MEAN)
#  [0.38645961 0.42927096 0.39487307 0.39230896 0.42241555 0.3964184
#  0.4182934  0.39363172 0.45379146 0.44405525 0.43622049 0.42484229
#  0.38614036 0.44027142 0.4186368  0.4182934  0.44247049 0.39810109
#  0.42408552 0.40634921 0.44763813 0.4671945  0.45495269 0.42449888
#  0.3617585  0.42334147 0.4182934  0.39265237 0.41205612 0.40164454
#  0.40987993 0.40987993 0.44196683 0.45020223 0.43239596 0.43512032]
#
# cross validation results (STD)
#  [0.05618426 0.08565182 0.08119661 0.05879757 0.05204074 0.06420412
#  0.0761058  0.08421348 0.07132681 0.05997052 0.06848128 0.06389207
#  0.07115389 0.05352108 0.06707782 0.06187852 0.07448124 0.06372816
#  0.07984771 0.04564955 0.07174838 0.07096788 0.05721036 0.06883996
#  0.07128789 0.06119622 0.0505208  0.05237594 0.03149014 0.04700588
#  0.06645711 0.04492385 0.08415917 0.09003005 0.06917743 0.06582102]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 1.0000
#
# accuracy on development set: 0.3500
#
# precision on dev set: 0.2553
#
# recall on dev set: 0.3333
#
# fscore on dev set: 0.2891
# ------------------------------------------------------------
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
#
# final score for the tuned model
#  0.4047619047619047
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 4, 'max_features': 0.4, 'n_estimators': 200}
#
# cross validation results (MEAN)
#  [0.40139779 0.39045966 0.40935338 0.40248525 0.45564459 0.41116835
#  0.4401862  0.38663767 0.40931395 0.39291692 0.37029787 0.44524573
#  0.40550341 0.38605896 0.39791921 0.43171042 0.38722782 0.44775387
#  0.43418931 0.44087938 0.40640135 0.47938161 0.47672466 0.47335419
#  0.38857982 0.3946861  0.38146495 0.40727132 0.45652727 0.45781441
#  0.43910511 0.44433125 0.47124924 0.44141738 0.4255698  0.43512795]
#
# cross validation results (STD)
#  [0.02608198 0.03259843 0.0758309  0.09261861 0.05727354 0.04494035
#  0.0910888  0.07907698 0.07824941 0.08118929 0.07043739 0.08607214
#  0.09843797 0.07153851 0.08233518 0.09695087 0.07999943 0.06635393
#  0.10497486 0.09436491 0.07663538 0.06490401 0.08856923 0.05659882
#  0.14005621 0.07639176 0.07958523 0.0591686  0.0607316  0.08346443
#  0.08098974 0.05950762 0.04509283 0.03754354 0.10980378 0.06916417]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 1.0000
#
# accuracy on development set: 0.4167
#
# precision on dev set: 0.3852
#
# recall on dev set: 0.4048
#
# fscore on dev set: 0.3857
# ------------------------------------------------------------
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
#
# final score for the tuned model
#  0.38888888888888884
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 8, 'max_features': 0.4, 'n_estimators': 400}
#
# cross validation results (MEAN)
#  [0.38663767 0.38385099 0.38821734 0.38787393 0.35682362 0.37982677
#  0.37044668 0.37293574 0.37492877 0.35281848 0.35505571 0.36421322
#  0.30030652 0.39390644 0.40171958 0.36772232 0.37491606 0.37446963
#  0.36981074 0.40074023 0.37080662 0.35613807 0.38202457 0.38282585
#  0.37784773 0.38118895 0.37590049 0.38391331 0.31704187 0.36435694
#  0.39466321 0.36321225 0.36910231 0.36657764 0.41077406 0.39715227]
#
# cross validation results (STD)
#  [0.06334885 0.09074952 0.06629895 0.0370625  0.09670663 0.08253728
#  0.06274185 0.09000535 0.07711934 0.06812685 0.07975215 0.07152324
#  0.03714213 0.07574789 0.09948689 0.07777537 0.11968081 0.11731586
#  0.06838822 0.09843153 0.10286402 0.0448562  0.09315407 0.09002713
#  0.09513206 0.09485828 0.08448147 0.07868533 0.07506535 0.05572438
#  0.09868376 0.0682164  0.09365416 0.06948344 0.07820874 0.07849599]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 1.0000
#
# accuracy on development set: 0.4000
#
# precision on dev set: 0.3685
#
# recall on dev set: 0.3889
#
# fscore on dev set: 0.3695
# ------------------------------------------------------------
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
#
# final score for the tuned model
#  0.42857142857142855
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 4, 'max_features': 0.2, 'n_estimators': 100}
#
# cross validation results (MEAN)
#  [0.35734509 0.34991097 0.35768849 0.35728785 0.35594348 0.34184091
#  0.37816188 0.38878332 0.36235882 0.36137948 0.3693923  0.35518671
#  0.34927503 0.37926587 0.41145961 0.36904889 0.42926587 0.35961157
#  0.37952279 0.38581858 0.39944037 0.33631716 0.33573845 0.34455255
#  0.39513635 0.39537673 0.41621006 0.3886803  0.30802554 0.39028287
#  0.38028973 0.40344678 0.36899166 0.3210292  0.35697243 0.33940146]
#
# cross validation results (STD)
#  [0.0977799  0.06643822 0.07512263 0.08964156 0.09829718 0.06233818
#  0.07568708 0.07541594 0.10613561 0.10938602 0.11661016 0.08943027
#  0.07142042 0.09372087 0.05458867 0.07641135 0.03524668 0.09983549
#  0.09903864 0.09113937 0.05325605 0.08668897 0.11403312 0.10461034
#  0.0617265  0.10294132 0.0884849  0.09951683 0.11954571 0.10345317
#  0.14314737 0.12702585 0.09347752 0.08492208 0.10052536 0.11766217]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 0.9904
#
# accuracy on development set: 0.4500
#
# precision on dev set: 0.3239
#
# recall on dev set: 0.4286
#
# fscore on dev set: 0.3679
# ------------------------------------------------------------
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
#
# final score for the tuned model
#  0.4523809523809524
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 8, 'max_features': 0.2, 'n_estimators': 400}
#
# cross validation results (MEAN)
#  [0.45594729 0.40490054 0.43054156 0.41297059 0.37931675 0.44005393
#  0.42975173 0.42895045 0.42027371 0.47382224 0.43025539 0.41268442
#  0.44148479 0.42980388 0.44457672 0.44023199 0.42621464 0.47687856
#  0.41487078 0.42851547 0.42204798 0.46005164 0.47568809 0.44291565
#  0.46347426 0.45985704 0.47796093 0.49525081 0.42444673 0.44742063
#  0.49841015 0.47311254 0.42164225 0.49523937 0.49133598 0.47885887]
#
# cross validation results (STD)
#  [0.06275589 0.08123982 0.05799749 0.05205116 0.03644129 0.0510795
#  0.07300874 0.08049797 0.06966732 0.11803834 0.06899981 0.08583164
#  0.07310804 0.06788706 0.07894751 0.06130116 0.09590354 0.10929853
#  0.06295231 0.04894684 0.05999803 0.0704481  0.06547022 0.09565934
#  0.12547474 0.07336125 0.08675528 0.06368538 0.09683319 0.10136478
#  0.10148741 0.08300508 0.03973325 0.10348415 0.0756977  0.07047538]
#
# evaluating the Random Forest Classifier ...
# accuracy on training set: 1.0000
#
# accuracy on development set: 0.4667
#
# precision on dev set: 0.4444
#
# recall on dev set: 0.4524
#
# fscore on dev set: 0.4304
# ------------------------------------------------------------
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
#
# final score for the tuned model
#  0.4021164021164021
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 4, 'max_features': 0.1, 'n_estimators': 100}
#
# cross validation results (MEAN)
#  [0.36984    0.36593661 0.35207443 0.36048789 0.32817333 0.34109687
#  0.34500025 0.38666692 0.38623194 0.36389398 0.38873372 0.3704187
#  0.40138889 0.3486251  0.34730235 0.38015491 0.37105973 0.36100427
#  0.38544338 0.35611645 0.33659951 0.35457112 0.38155652 0.35944114
#  0.3756105  0.36912012 0.36837607 0.38015491 0.33437882 0.32560541
#  0.34259768 0.33854548 0.36684854 0.39303266 0.37526709 0.36917735]
#
# cross validation results (STD)
#  [0.10063966 0.09156692 0.0616121  0.07185203 0.0879949  0.08669827
#  0.09205953 0.11122705 0.06212325 0.07329399 0.10787253 0.10559357
#  0.11029959 0.09917759 0.0814275  0.10154293 0.02094566 0.06868652
#  0.08582201 0.08851361 0.10804688 0.09452306 0.0515317  0.06060997
#  0.06882356 0.09179391 0.10328851 0.11191934 0.08047697 0.09094277
#  0.08087711 0.07642926 0.07064816 0.12543598 0.10369586 0.07802341]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 1.0000
#
# accuracy on development set: 0.4167
#
# precision on dev set: 0.3950
#
# recall on dev set: 0.4021
#
# fscore on dev set: 0.3748
# ------------------------------------------------------------
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
#
# final score for the tuned model
#  0.4338624338624338
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 4, 'max_features': 0.1, 'n_estimators': 200}
#
# cross validation results (MEAN)
#  [0.34464031 0.37659493 0.34614113 0.36353404 0.34538436 0.38836106
#  0.35546398 0.36783806 0.34692969 0.36261193 0.36335597 0.33852895
#  0.36864443 0.41535918 0.36840405 0.36858211 0.37699049 0.39247812
#  0.33550697 0.33795024 0.39717135 0.32186737 0.38172823 0.34936915
#  0.40808532 0.40564204 0.37437424 0.34524318 0.37784264 0.33731431
#  0.34374237 0.35091448 0.33969017 0.3501132  0.32006003 0.35932794]
#
# cross validation results (STD)
#  [0.04659897 0.08799771 0.09712436 0.09130092 0.08210576 0.08529248
#  0.12324821 0.06834826 0.06146202 0.06612461 0.08396904 0.08065172
#  0.06148094 0.05305302 0.05742143 0.08163479 0.04199829 0.04720091
#  0.09424624 0.07193681 0.13151142 0.10182962 0.05795218 0.08570253
#  0.08163644 0.13704695 0.09757532 0.11483476 0.12749415 0.09116024
#  0.08162269 0.08360279 0.04166957 0.10345646 0.10571171 0.08140047]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 1.0000
#
# accuracy on development set: 0.4500
#
# precision on dev set: 0.4068
#
# recall on dev set: 0.4339
#
# fscore on dev set: 0.4009
# ------------------------------------------------------------
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
#
# final score for the tuned model
#  0.3862433862433863
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 8, 'max_features': 0.2, 'n_estimators': 100}
#
# cross validation results (MEAN)
#  [0.36014449 0.36832265 0.36048789 0.37576949 0.37755011 0.38804691
#  0.40135328 0.40169668 0.34717643 0.41539352 0.36991504 0.39624288
#  0.37509412 0.37617013 0.39339769 0.40565731 0.37378409 0.34058812
#  0.33978683 0.35621312 0.39683812 0.37338345 0.36462658 0.35503409
#  0.41777447 0.37226165 0.38736518 0.38201949 0.46657255 0.36490639
#  0.38844755 0.38037749 0.43662241 0.37456375 0.40834224 0.40754095]
#
# cross validation results (STD)
#  [0.10138639 0.04297704 0.0777978  0.06995273 0.07425189 0.10826559
#  0.07742876 0.10467278 0.08548361 0.09080409 0.08602737 0.09493461
#  0.09353128 0.06262593 0.08143936 0.08581731 0.0955682  0.07440593
#  0.07144806 0.0468975  0.09351528 0.07995587 0.11089345 0.0671161
#  0.06146227 0.01895398 0.03168356 0.04751556 0.09010225 0.07856654
#  0.09929828 0.06985392 0.14518178 0.09430898 0.07266399 0.06206756]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 1.0000
#
# accuracy on development set: 0.4000
#
# precision on dev set: 0.3632
#
# recall on dev set: 0.3862
#
# fscore on dev set: 0.3610
# ------------------------------------------------------------
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
#
# final score for the tuned model
#  0.41798941798941797
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 2, 'max_features': 0.4, 'n_estimators': 200}
#
# cross validation results (MEAN)
#  [0.34735195 0.29298051 0.34026124 0.33070309 0.33624847 0.33871591
#  0.36008725 0.32172365 0.35512057 0.40849105 0.40636701 0.3529215
#  0.33067893 0.33530474 0.3110437  0.33679284 0.35866784 0.3918867
#  0.32946174 0.35436381 0.3386485  0.34623143 0.3742585  0.39182947
#  0.26788894 0.32803597 0.32813899 0.3299247  0.39368895 0.32411605
#  0.36897003 0.35634412 0.36573693 0.37696123 0.37052808 0.34141865]
#
# cross validation results (STD)
#  [0.02954466 0.03929612 0.04259923 0.04353572 0.04914732 0.04143177
#  0.03962978 0.06593748 0.07237698 0.07452244 0.08193117 0.09220651
#  0.08876685 0.04449202 0.04663407 0.02806527 0.0520885  0.09145597
#  0.080362   0.03517952 0.1103888  0.12181224 0.09852284 0.07947348
#  0.09396882 0.03371105 0.0578828  0.03833237 0.07794295 0.13162677
#  0.08764424 0.08021964 0.07106841 0.09771078 0.070964   0.05783795]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 0.9135
#
# accuracy on development set: 0.4333
#
# precision on dev set: 0.4141
#
# recall on dev set: 0.4180
#
# fscore on dev set: 0.3912
# ------------------------------------------------------------
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
#
# final score for the tuned model
#  0.38095238095238093
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 2, 'max_features': 0.1, 'n_estimators': 400}
#
# cross validation results (MEAN)
#  [0.38020452 0.39835419 0.40446556 0.40446556 0.39895452 0.38430886
#  0.33170406 0.36615919 0.37538665 0.39791158 0.36558048 0.35872507
#  0.3577241  0.34638533 0.329215   0.36435694 0.38803928 0.36148886
#  0.36303419 0.33820716 0.37014398 0.36499288 0.35617877 0.34776531
#  0.37897589 0.38198514 0.34850936 0.38192791 0.38194063 0.33993056
#  0.32270299 0.32252493 0.31533501 0.37969577 0.37128231 0.36533628]
#
# cross validation results (STD)
#  [0.03819088 0.04216079 0.04160788 0.03951615 0.0754426  0.05862647
#  0.04557592 0.04492431 0.07586426 0.09973126 0.05863645 0.05794223
#  0.04420531 0.07341728 0.07160907 0.06507503 0.09587263 0.04161181
#  0.07778367 0.05324291 0.06162585 0.05474391 0.05473388 0.05431846
#  0.06601274 0.02348066 0.03733773 0.04167102 0.0937856  0.05755208
#  0.06386347 0.05321296 0.05305347 0.03662252 0.05729338 0.07663869]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 0.8269
#
# accuracy on development set: 0.4000
#
# precision on dev set: 0.2775
#
# recall on dev set: 0.3810
#
# fscore on dev set: 0.3182
# ------------------------------------------------------------
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
#
# final score for the tuned model
#  0.44973544973544977
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 8, 'max_features': 0.4, 'n_estimators': 400}
#
# cross validation results (MEAN)
#  [0.34608771 0.3738515  0.36994811 0.37241555 0.3392323  0.37884361
#  0.38645579 0.38942053 0.4073807  0.38160231 0.36854141 0.38541412
#  0.37499746 0.40514728 0.38140771 0.37265084 0.40138889 0.38204365
#  0.35720391 0.37982295 0.33080739 0.36857702 0.3568605  0.39311915
#  0.36319063 0.36060363 0.39554589 0.41173179 0.38356609 0.39741555
#  0.35650565 0.35906466 0.3839273  0.40694063 0.42875839 0.40149191]
#
# cross validation results (STD)
#  [0.08463871 0.12492188 0.10022366 0.11441251 0.10081177 0.09125314
#  0.11032239 0.11269744 0.08483269 0.07858265 0.07471257 0.08646527
#  0.07661135 0.07200532 0.12446413 0.10743647 0.10276836 0.09501073
#  0.09460999 0.08010907 0.04763682 0.07770429 0.05196303 0.11870669
#  0.10900507 0.08146435 0.09029892 0.0981456  0.09278174 0.07201639
#  0.10067754 0.12010701 0.10001756 0.06465285 0.09612304 0.08354712]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 1.0000
#
# accuracy on development set: 0.4667
#
# precision on dev set: 0.4205
#
# recall on dev set: 0.4497
#
# fscore on dev set: 0.4168
# ------------------------------------------------------------
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
# final score for the tuned model
#  0.35714285714285715
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 8, 'max_features': 0.4, 'n_estimators': 400}
#
# cross validation results (MEAN)
#  [0.37261523 0.38841829 0.39330103 0.3624911  0.39312296 0.37635328
#  0.37653134 0.3843661  0.36581578 0.40277778 0.38733084 0.38658679
#  0.40634921 0.40119302 0.38773148 0.39277956 0.37266229 0.3573807
#  0.40722553 0.37555199 0.4088052  0.42158501 0.3957443  0.40415776
#  0.36294516 0.35778134 0.38262108 0.39023326 0.38035969 0.37148326
#  0.39119989 0.38204238 0.42328678 0.40960648 0.43404558 0.42667379]
#
# cross validation results (STD)
#  [0.05890461 0.05889727 0.06238021 0.05000062 0.07041375 0.08320892
#  0.06538069 0.07320707 0.04534485 0.07896636 0.08353806 0.1002099
#  0.02555427 0.04771963 0.02796276 0.07467823 0.04282901 0.04952024
#  0.04361504 0.04409022 0.07440494 0.10122546 0.06185249 0.06984438
#  0.08304844 0.05548102 0.07028581 0.06957733 0.05407223 0.06223591
#  0.06135258 0.06501255 0.11027565 0.11272165 0.07974334 0.09633103]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 1.0000
#
# accuracy on development set: 0.3667
#
# precision on dev set: 0.3627
#
# recall on dev set: 0.3571
#
# fscore on dev set: 0.3452
# ------------------------------------------------------------
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
#
# final score for the tuned model
#  0.42063492063492064
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 4, 'max_features': 0.2, 'n_estimators': 100}
#
# cross validation results (MEAN)
#  [0.3843839  0.37044668 0.37891738 0.40277778 0.37004604 0.35418574
#  0.36127646 0.37043396 0.35077457 0.37181395 0.37083461 0.36322243
#  0.41596459 0.44938314 0.39368895 0.39995676 0.4497558  0.37537393
#  0.38729014 0.37379426 0.42898479 0.36291336 0.3488108  0.35424298
#  0.36186788 0.42984458 0.39659137 0.35220035 0.40055708 0.3866949
#  0.39016331 0.37546042 0.38612383 0.40566748 0.38659824 0.37620447]
#
# cross validation results (STD)
#  [0.06044843 0.04187724 0.04933269 0.04006134 0.04545753 0.04197802
#  0.03744842 0.04941675 0.03986752 0.04520774 0.05767627 0.04359729
#  0.05287916 0.04654546 0.04630597 0.05667512 0.06493016 0.05705028
#  0.05173638 0.04658364 0.06063765 0.07726604 0.05085295 0.06889964
#  0.04999111 0.06796378 0.06305541 0.04119838 0.02738933 0.05288834
#  0.03447561 0.0159436  0.09480685 0.03669806 0.03336838 0.03980807]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 1.0000
#
# accuracy on development set: 0.4333
#
# precision on dev set: 0.4066
#
# recall on dev set: 0.4206
#
# fscore on dev set: 0.4046
# ------------------------------------------------------------
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
#
# final score for the tuned model
#  0.43650793650793646
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 8, 'max_features': 0.2, 'n_estimators': 200}
#
# cross validation results (MEAN)
#  [0.35045279 0.31657636 0.36814459 0.35148301 0.35604014 0.31938721
#  0.36219857 0.35304106 0.3765695  0.39150768 0.34795228 0.39997838
#  0.40514601 0.37672339 0.36876781 0.36706858 0.35271037 0.39759743
#  0.415901   0.39677452 0.4208079  0.39538945 0.36922695 0.41640466
#  0.30797594 0.33547009 0.34951033 0.3738693  0.39095442 0.43751908
#  0.41205484 0.42638126 0.31725427 0.39650488 0.38246464 0.39486798]
#
# cross validation results (STD)
#  [0.0796582  0.05276698 0.06920735 0.03618994 0.12083756 0.09903391
#  0.08034955 0.06328381 0.08947024 0.07785493 0.10369045 0.09156784
#  0.09855094 0.07516006 0.06406886 0.07691399 0.1301496  0.04585213
#  0.07271636 0.051316   0.087692   0.07869217 0.09776935 0.05530852
#  0.04730212 0.04721085 0.04522507 0.05336873 0.05502937 0.030152
#  0.11633186 0.04149348 0.09343783 0.10077958 0.08892561 0.03273325]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 1.0000
#
# accuracy on development set: 0.4500
#
# precision on dev set: 0.4259
#
# recall on dev set: 0.4365
#
# fscore on dev set: 0.4185
# ------------------------------------------------------------
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
#
# final score for the tuned model
#  0.3386243386243386
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 4, 'max_features': 0.2, 'n_estimators': 100}
#
# cross validation results (MEAN)
#  [0.3386078  0.34211055 0.34113121 0.3374275  0.33484178 0.32356024
#  0.31532484 0.32999339 0.35030143 0.36967974 0.34699837 0.34641967
#  0.39680886 0.33051486 0.29749695 0.33165954 0.39778821 0.33740588
#  0.36223291 0.3127442  0.33359407 0.3456133  0.33648377 0.32766967
#  0.31250382 0.34790776 0.35417557 0.34025107 0.35805734 0.34525336
#  0.32035638 0.30515364 0.3192473  0.37766585 0.35859916 0.3450753 ]
#
# cross validation results (STD)
#  [0.03740861 0.07607676 0.08681252 0.11005559 0.13097084 0.10388257
#  0.12504248 0.10206223 0.13950229 0.06307431 0.08454662 0.08770962
#  0.08399968 0.10248026 0.10309399 0.13353087 0.10673746 0.12731128
#  0.13657166 0.12537403 0.11792547 0.11677112 0.09836209 0.1158435
#  0.1456301  0.11185997 0.11086329 0.12215662 0.11601146 0.07184388
#  0.11525891 0.12365448 0.09701285 0.12416182 0.13275887 0.10449112]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 0.9904
#
# accuracy on development set: 0.3500
#
# precision on dev set: 0.3217
#
# recall on dev set: 0.3386
#
# fscore on dev set: 0.3201
# ------------------------------------------------------------
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
#
# final score for the tuned model
#  0.42063492063492064
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 4, 'max_features': 0.1, 'n_estimators': 100}
#
# cross validation results (MEAN)
#  [0.3243895  0.31207138 0.32998575 0.3303864  0.31434676 0.30601725
#  0.30578195 0.31477411 0.33967109 0.32342287 0.32178088 0.3011078
#  0.3425608  0.29237765 0.28801129 0.26545075 0.30236696 0.32424832
#  0.25921856 0.26705332 0.27838192 0.30331197 0.28672034 0.28051486
#  0.23191138 0.27833359 0.25846179 0.26368793 0.28211742 0.24291311
#  0.23884819 0.27448743 0.27819114 0.26977768 0.28620396 0.28910638]
#
# cross validation results (STD)
#  [0.04453687 0.04028299 0.07588327 0.06293085 0.04852553 0.05484667
#  0.06708668 0.05064822 0.04089984 0.05802736 0.07371379 0.06982763
#  0.06520013 0.12222411 0.06805593 0.06182964 0.0509456  0.08123117
#  0.02765684 0.01795069 0.09417634 0.07737791 0.10991328 0.07501599
#  0.0817339  0.08601641 0.08649962 0.07445128 0.07912422 0.07736212
#  0.101266   0.07896439 0.08701436 0.08309188 0.09983268 0.0937481 ]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 1.0000
#
# accuracy on development set: 0.4333
#
# precision on dev set: 0.4116
#
# recall on dev set: 0.4206
#
# fscore on dev set: 0.4037
# ------------------------------------------------------------
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
#
# final score for the tuned model
#  0.38888888888888884
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 8, 'max_features': 0.4, 'n_estimators': 100}
#
# cross validation results (MEAN)
#  [0.36966702 0.34637261 0.33739316 0.36297695 0.39348799 0.36457952
#  0.38174985 0.38936203 0.37583817 0.38743895 0.41965049 0.42005113
#  0.38420584 0.34921271 0.34846866 0.35332214 0.37405245 0.37206705
#  0.34565273 0.36243386 0.36832265 0.40459783 0.36307489 0.36856939
#  0.35900616 0.40134692 0.35446683 0.3887617  0.41894714 0.3582672
#  0.37613579 0.40396825 0.45350529 0.33987714 0.4086106  0.39296271]
#
# cross validation results (STD)
#  [0.10731704 0.0921375  0.06614429 0.06411475 0.07119553 0.07251624
#  0.05534731 0.07722459 0.08795947 0.08078343 0.07672663 0.10961163
#  0.05069931 0.09123741 0.07450478 0.07283276 0.04607756 0.03395275
#  0.08366856 0.03239077 0.12481562 0.11369784 0.09154059 0.10452855
#  0.0145762  0.04231663 0.05048507 0.05614375 0.02737458 0.07454551
#  0.07964966 0.05831996 0.04658111 0.03989549 0.05465098 0.06379161]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 1.0000
#
# accuracy on development set: 0.4000
#
# precision on dev set: 0.3743
#
# recall on dev set: 0.3889
#
# fscore on dev set: 0.3762
# ------------------------------------------------------------
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
# final score for the tuned model
#  0.4021164021164021
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 8, 'max_features': 0.1, 'n_estimators': 200}
#
# cross validation results (MEAN)
#  [0.36214133 0.31978785 0.33679284 0.31541005 0.3099855  0.32629095
#  0.33430377 0.32002315 0.32742292 0.33010277 0.31160969 0.31713345
#  0.36377824 0.30627671 0.32531161 0.32777905 0.33099562 0.30459783
#  0.32274751 0.35616606 0.35252213 0.32875839 0.31020808 0.32686966
#  0.33840812 0.36944572 0.33190502 0.33150438 0.35196632 0.32895808
#  0.35748881 0.32176816 0.31206883 0.32734534 0.34270452 0.34049654]
#
# cross validation results (STD)
#  [0.09952215 0.07999854 0.06180823 0.05024051 0.06816735 0.04393327
#  0.05190584 0.02246744 0.0867697  0.09783986 0.08231219 0.04144021
#  0.09206697 0.05335652 0.08502516 0.08383169 0.05479643 0.08494486
#  0.06716688 0.06512481 0.08127841 0.06445947 0.07857012 0.0605003
#  0.10820713 0.08383169 0.09245372 0.08439032 0.06151741 0.06074369
#  0.05663035 0.08424241 0.10762383 0.08909752 0.07534106 0.07980091]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 1.0000
#
# accuracy on development set: 0.4167
#
# precision on dev set: 0.4123
#
# recall on dev set: 0.4021
#
# fscore on dev set: 0.3740
# ------------------------------------------------------------
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
#
# final score for the tuned model
#  0.39947089947089953
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 2, 'max_features': 0.4, 'n_estimators': 100}
#
# cross validation results (MEAN)
#  [0.33725071 0.3383954  0.34813161 0.36299985 0.39074201 0.36375661
#  0.34733033 0.33108211 0.39676943 0.35442104 0.35592186 0.30509768
#  0.37152905 0.36937068 0.32771673 0.31970391 0.34282026 0.32731609
#  0.33068147 0.32875839 0.35635684 0.36260684 0.34908806 0.33562653
#  0.32101521 0.33131741 0.37018976 0.36954874 0.31236645 0.33717186
#  0.34089718 0.33544846 0.35698006 0.30912062 0.32975936 0.37855744]
#
# cross validation results (STD)
#  [0.03124669 0.03030482 0.03530723 0.02452437 0.0209505  0.06173856
#  0.05866798 0.06719723 0.05269018 0.06599294 0.07389339 0.07202452
#  0.05260921 0.05046348 0.05580518 0.05396581 0.04166429 0.0702757
#  0.07008395 0.03961838 0.03808709 0.04339594 0.06136793 0.05578117
#  0.04787259 0.04876612 0.05386566 0.07076442 0.07427276 0.06109554
#  0.04339916 0.06032528 0.04381483 0.05042537 0.05770293 0.0372064 ]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 0.8846
#
# accuracy on development set: 0.4167
#
# precision on dev set: 0.3615
#
# recall on dev set: 0.3995
#
# fscore on dev set: 0.3592
# ------------------------------------------------------------
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
#
# final score for the tuned model
#  0.4523809523809524
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 4, 'max_features': 0.2, 'n_estimators': 100}
#
# cross validation results (MEAN)
#  [0.38630698 0.41073336 0.38514957 0.39418625 0.35736289 0.37228836
#  0.36409748 0.38933786 0.40522105 0.37715837 0.38184651 0.38737027
#  0.42250712 0.3778808  0.41135658 0.42051409 0.48437118 0.41219221
#  0.45199939 0.43415369 0.43314128 0.42947828 0.43993437 0.41840278
#  0.42825346 0.3915204  0.41698336 0.43381029 0.39766738 0.44835419
#  0.38505291 0.38292888 0.44300722 0.38332952 0.45147792 0.42574023]
#
# cross validation results (STD)
#  [0.09310427 0.07361634 0.10469201 0.09993313 0.08759189 0.06511037
#  0.0610167  0.06314182 0.08635544 0.0498842  0.04399514 0.03981641
#  0.06676084 0.10325524 0.088514   0.08016969 0.06029922 0.09659057
#  0.06340532 0.07943229 0.0861796  0.08496462 0.09707615 0.0814689
#  0.10798687 0.10635486 0.09349933 0.07462648 0.06260725 0.11090182
#  0.11831512 0.11835941 0.04142162 0.07528425 0.07842473 0.09896792]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 1.0000
#
# accuracy on development set: 0.4667
#
# precision on dev set: 0.4566
#
# recall on dev set: 0.4524
#
# fscore on dev set: 0.4296
# ------------------------------------------------------------
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
#
# final score for the tuned model
#  0.3862433862433862
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 8, 'max_features': 0.2, 'n_estimators': 200}
#
# cross validation results (MEAN)
#  [0.34328322 0.35229701 0.31064306 0.33530474 0.35687704 0.31984509
#  0.35439688 0.30994353 0.2819915  0.30936482 0.29289403 0.31882123
#  0.35435236 0.26708766 0.29050799 0.28952864 0.35235424 0.35207443
#  0.31268569 0.3386078  0.33117369 0.33191774 0.329491   0.33812704
#  0.35594348 0.33168244 0.29283171 0.3139334  0.34319292 0.36962251
#  0.35475936 0.35050621 0.36644027 0.33754833 0.3297759  0.32101903]
#
# cross validation results (STD)
#  [0.07432729 0.03424452 0.04230738 0.05065945 0.0698059  0.06122628
#  0.13371741 0.06838249 0.03654555 0.06406937 0.04473165 0.07185203
#  0.11148586 0.06121918 0.09931956 0.09991779 0.09528893 0.0918318
#  0.07185118 0.08859867 0.10224018 0.09040585 0.09824194 0.06545102
#  0.06413458 0.06496828 0.07265587 0.06202574 0.08582679 0.08110599
#  0.06523282 0.08593957 0.04841459 0.07772936 0.07052989 0.11845629]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 1.0000
#
# accuracy on development set: 0.4000
#
# precision on dev set: 0.3641
#
# recall on dev set: 0.3862
#
# fscore on dev set: 0.3608
# ------------------------------------------------------------
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
#
# final score for the tuned model
#  0.32275132275132273
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 8, 'max_features': 0.1, 'n_estimators': 100}
#
# cross validation results (MEAN)
#  [0.27822548 0.27255418 0.27662291 0.27662291 0.29210546 0.27668015
#  0.25963065 0.26020935 0.27583944 0.26471434 0.23152345 0.23657153
#  0.27733262 0.26094068 0.28167099 0.26604599 0.2781339  0.28948413
#  0.25316316 0.25935592 0.2345289  0.27469475 0.24236365 0.23418549
#  0.30714031 0.24961971 0.28265034 0.25855464 0.21526252 0.26602437
#  0.27652625 0.25152116 0.26540115 0.26027803 0.2328055  0.24823082]
#
# cross validation results (STD)
#  [0.07554713 0.05409867 0.062192   0.062192   0.04846846 0.04767872
#  0.06476361 0.08819401 0.07048446 0.06323954 0.05801608 0.08786144
#  0.06518613 0.06062286 0.08923231 0.08157633 0.09383245 0.09971043
#  0.05982485 0.0876732  0.1348375  0.12000736 0.09672491 0.09912919
#  0.03676927 0.0574917  0.08246455 0.06075125 0.06294211 0.06180597
#  0.09493347 0.09588364 0.09694792 0.1320295  0.10394095 0.09507986]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 1.0000
#
# accuracy on development set: 0.3333
#
# precision on dev set: 0.3074
#
# recall on dev set: 0.3228
#
# fscore on dev set: 0.3043
# ------------------------------------------------------------
#
# hyperparameters are not tuned yet
#
# running the Grid Search for Random Forest CV classifier ...
#
# final score for the tuned model
#  0.5026455026455027
#
# best hyperparameters for the tuned model
#  {'criterion': 'entropy', 'max_depth': 4, 'max_features': 0.1, 'n_estimators': 100}
#
# cross validation results (MEAN)
#  [0.36615919 0.34029558 0.32282764 0.34400438 0.36347553 0.40508496
#  0.36341829 0.36734966 0.31663996 0.3471688  0.35707036 0.36468254
#  0.43082901 0.34544668 0.39370676 0.42850529 0.39508674 0.34590456
#  0.39977869 0.40274344 0.42304513 0.41412164 0.38591651 0.36908959
#  0.41287393 0.38429233 0.38144714 0.39074201 0.42122507 0.36585648
#  0.39476496 0.39705433 0.36074608 0.42876221 0.38262617 0.39534366]
#
# cross validation results (STD)
#  [0.02945813 0.07826225 0.12468769 0.08575121 0.1216629  0.11371519
#  0.08538679 0.06718087 0.0707182  0.0972977  0.08024891 0.0802147
#  0.07120392 0.08056251 0.07064056 0.0694371  0.14003961 0.05534696
#  0.07404543 0.07352092 0.08783176 0.08401173 0.09039877 0.07754087
#  0.09077118 0.08088253 0.05218797 0.06496919 0.13049682 0.12002288
#  0.0813431  0.08699783 0.0990954  0.12828252 0.09741155 0.16026072]
#
# evaluating the Random Forest Classifier ...
#
# accuracy on training set: 1.0000
#
# accuracy on development set: 0.5167
#
# precision on dev set: 0.5556
#
# recall on dev set: 0.5026
#
# fscore on dev set: 0.4860
# ------------------------------------------------------------
